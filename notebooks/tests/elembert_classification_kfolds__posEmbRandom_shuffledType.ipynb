# %% [markdown]
# <a href="https://colab.research.google.com/github/dmamur/elembert/blob/main/notebooks/tests/elembert_classification_kfolds__posEmbRandom_shuffledType.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle,random
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Embedding,Dense,Dropout,Input,Lambda
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
import re, glob,os,sys
from collections import defaultdict
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical

def bert_module(query, key, value, i, config):
    # Multi headed self-attention
    attention_output = layers.MultiHeadAttention(
        num_heads=config.NUM_HEAD,
        key_dim=config.EMBED_DIM // config.NUM_HEAD,
        name="encoder_{}/multiheadattention".format(i),
        kernel_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed)
    )(query, key, value)
    attention_output = layers.Dropout(0.1, name="encoder_{}/att_dropout".format(i))(
        attention_output
    )
    attention_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/att_layernormalization".format(i)
    )(query + attention_output)

    # Feed-forward layer
    ffn = tf.keras.Sequential(
        [
            layers.Dense(config.FF_DIM, activation="relu",kernel_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed)),
            layers.Dense(config.EMBED_DIM,kernel_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed)),
        ],
        name="encoder_{}/ffn".format(i),
    )
    ffn_output = ffn(attention_output)
    ffn_output = layers.Dropout(0.1, name="encoder_{}/ffn_dropout".format(i))(
        ffn_output
    )
    sequence_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/ffn_layernormalization".format(i)
    )(attention_output + ffn_output)
    return sequence_output


def get_pos_encoding_matrix(max_len, d_emb):
    pos_enc = np.array(
        [
            [pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)]
            if pos != 0
            else np.zeros(d_emb)
            for pos in range(max_len)
        ]
    )
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2])  # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2])  # dim 2i+1
    return pos_enc

def create_elembert_model(inputs,config):
    word_embeddings = layers.Embedding(config.VOCAB_SIZE, config.EMBED_DIM, mask_zero=True,name="element_embdgs",
                                       embeddings_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed))(inputs)
    position_embeddings = layers.Embedding(input_dim=config.MAX_LEN,output_dim=config.EMBED_DIM,
                                           weights=[get_pos_encoding_matrix(config.MAX_LEN, config.EMBED_DIM)],
                                           embeddings_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed),
                                           name="position_embedding",)(tf.range(start=0, limit=config.MAX_LEN, delta=1))
    embeddings = word_embeddings + position_embeddings
    encoder_output = embeddings
    for i in range(config.NUM_LAYERS):
        encoder_output = bert_module(encoder_output, encoder_output, encoder_output, i, config)
    mlm_model = Model(inputs, encoder_output, name="masked_bert_model")

    return mlm_model

# %%
# !git clone https://github.com/dmamur/elementsem.git
# Out:
# fatal: destination path 'elementsem' already exists and is not an empty directory.

# %%
class Config:
    MAX_LEN = 256
    BATCH_SIZE = 32
    LR = 0.001
    VOCAB_SIZE = 128
    EMBED_DIM = 32
    NUM_HEAD = 2 # used in bert model
    FF_DIM = 32 # used in bert model
    NUM_LAYERS = 2
    MNAME = 'elembert_'
    MVER = 'V1'
    DSPATH="/content/elementsem/data/"
    PREPATH="/content/elementsem/models/pretrained/"
    PATH="/content/elementsem/models/"
config = Config()
seed=12345
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
#'sider_1','sider_2','sider_3','sider_4','sider_5', 'sider_6','sider_7', 'sider_8', 'sider_9', 'sider_10', 'sider_11', 'sider_12',
#'sider_13', 'sider_14', 'sider_15','sider_16','sider_17','sider_18','sider_19','sider_20','sider_21','sider_22','sider_23',
#'sider_24','sider_25','sider_26','sider_27','dimensionality','spacegroup','liquid_amorphous','BBBP','bace','clintox','nr-ahr',
#'nr-ar','sr-atad5','nr-er-lbd','sr-p53','nr-ar-lbd','nr-ppar-gamma','sr-hse','nr-er','sr-mmp','nr-aromatase','sr-are','HIV'
ds = 'toxic_sr-mmp'
mname=config.PATH+config.MNAME+ds+'_%s_E_%s_H_%s_L_%s' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS)

# %% [markdown]
# # Load vocabulary and types

# %%
if (ds=='HIV'):
  df = pd.read_csv(config.DSPATH+ds+config.MVER+'_ds.csv')
else:
  df = pd.read_csv(config.DSPATH+ds+'_ds.csv')

types = df['types'+config.MVER].apply(eval).apply(list)
labels  = to_categorical(np.asarray(df['labels']))
uniquelbls=len(np.unique(np.asarray(df['labels'])))

with open(config.PREPATH+'/el2id'+config.MVER+'.pkl', 'rb') as f:
    db = pickle.load(f)

element2id = db['el2id']
el2id = db['el2id']
config.VOCAB_SIZE = len(element2id)
print('vocabSize: ', config.VOCAB_SIZE)
# Out:
# vocabSize:  565

# %% [markdown]
# # Convert types to integers

# %%
[random.shuffle(types[i]) for i in range(len(types))]
types0=[['[CLS]']+i+['[SEP]'] for i in types]
typesNumerical=[]
for i in types0:
    typesNumerical.append([element2id[j] for j in i])

x3 = tf.keras.preprocessing.sequence.pad_sequences(typesNumerical,dtype='int32',padding= 'post',truncating='post',maxlen=config.MAX_LEN)

#z = load_model(config.PREPATH+'/elembert_%s_E_%s_H_%s_L_%s.h5' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS),compile=False)
#z.trainable = True

inputC = Input((config.MAX_LEN), dtype=tf.int32,name='types')

# %%
epochs=2*config.BATCH_SIZE

print('dataLen: ',x3.shape,labels.shape)
# Out:
# dataLen:  (7320, 256) (7320, 2)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report

# Assuming you have loaded your data into x3 and labels variables

# Define the number of folds
num_folds = 5

# Initialize Stratified K-Fold Cross-Validator
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Initialize lists to store results
all_histories = []
all_reports = []

# Iterate over folds
for fold, (train_idx, val_idx) in enumerate(kfold.split(x3, np.argmax(labels, axis=1))):
    print(f"\nTraining on Fold {fold + 1}...")
    config.seed = np.random.randint(10000,99999,1)[0]
    z = create_elembert_model(inputC,config)
    e = Lambda(lambda x: x[:,0],name='clsTokenEmb')(z.output)
    f = Dense(uniquelbls, activation="softmax",name='out_tox',kernel_initializer=tf.keras.initializers.GlorotUniform(config.seed))(e)
    # Create and compile the model (assuming create_elembert_model function is available)
    model = Model(inputs=z.input, outputs=f)

    optimizer = tf.keras.optimizers.Adam(learning_rate=config.LR)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=[tf.keras.metrics.AUC()])

    # Extract training and validation sets
    x_train, x_val = x3[train_idx], x3[val_idx]
    y_train, y_val = labels[train_idx], labels[val_idx]

    # Train the model
    history = model.fit(
        x=x_train,
        y=y_train,
        validation_data=(x_val, y_val),
        epochs=epochs,
        batch_size=config.BATCH_SIZE,
        verbose=2
    )

    # Evaluate the model on the validation set
    val_predictions = model.predict(x_val, batch_size=config.BATCH_SIZE)
    val_report = classification_report(np.argmax(y_val, axis=1), np.argmax(val_predictions, axis=1), output_dict=True)

    # Append results to lists
    all_histories.append(history)
    all_reports.append(val_report)

# Print the average classification report across folds
avg_report = pd.DataFrame(all_reports).mean().to_dict()
print("\nAverage Classification Report Across Folds:")
print(avg_report)
# Out:
# Training on Fold 1...
# Epoch 1/64
# 183/183 - 22s - loss: 0.4467 - auc: 0.8446 - val_loss: 0.4557 - val_auc: 0.8646 - 22s/epoch - 118ms/step
# Epoch 2/64
# 183/183 - 4s - loss: 0.4414 - auc: 0.8454 - val_loss: 0.4290 - val_auc: 0.8991 - 4s/epoch - 24ms/step
# Epoch 3/64
# 183/183 - 3s - loss: 0.4124 - auc: 0.8836 - val_loss: 0.3751 - val_auc: 0.9206 - 3s/epoch - 18ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.3647 - auc: 0.9158 - val_loss: 0.3562 - val_auc: 0.9219 - 2s/epoch - 13ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3538 - auc: 0.9214 - val_loss: 0.3512 - val_auc: 0.9236 - 2s/epoch - 10ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3573 - auc: 0.9193 - val_loss: 0.3513 - val_auc: 0.9246 - 2s/epoch - 13ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3482 - auc: 0.9241 - val_loss: 0.3577 - val_auc: 0.9259 - 2s/epoch - 10ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3419 - auc: 0.9269 - val_loss: 0.3524 - val_auc: 0.9239 - 2s/epoch - 9ms/step
# Epoch 9/64
# 183/183 - 2s - loss: 0.3423 - auc: 0.9273 - val_loss: 0.3444 - val_auc: 0.9272 - 2s/epoch - 10ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3380 - auc: 0.9285 - val_loss: 0.3516 - val_auc: 0.9268 - 2s/epoch - 10ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3385 - auc: 0.9282 - val_loss: 0.3415 - val_auc: 0.9280 - 2s/epoch - 10ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3305 - auc: 0.9320 - val_loss: 0.3797 - val_auc: 0.9271 - 2s/epoch - 12ms/step
# Epoch 13/64
# 183/183 - 2s - loss: 0.3290 - auc: 0.9326 - val_loss: 0.3422 - val_auc: 0.9285 - 2s/epoch - 10ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3242 - auc: 0.9347 - val_loss: 0.3435 - val_auc: 0.9273 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3248 - auc: 0.9342 - val_loss: 0.3406 - val_auc: 0.9283 - 2s/epoch - 10ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3192 - auc: 0.9363 - val_loss: 0.3440 - val_auc: 0.9301 - 2s/epoch - 10ms/step
# Epoch 17/64
# 183/183 - 2s - loss: 0.3175 - auc: 0.9376 - val_loss: 0.3379 - val_auc: 0.9294 - 2s/epoch - 10ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3157 - auc: 0.9381 - val_loss: 0.3400 - val_auc: 0.9289 - 2s/epoch - 12ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3122 - auc: 0.9394 - val_loss: 0.3395 - val_auc: 0.9293 - 2s/epoch - 10ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3117 - auc: 0.9400 - val_loss: 0.3584 - val_auc: 0.9292 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3075 - auc: 0.9416 - val_loss: 0.3634 - val_auc: 0.9301 - 2s/epoch - 10ms/step
# Epoch 22/64
# 183/183 - 2s - loss: 0.3068 - auc: 0.9419 - val_loss: 0.3593 - val_auc: 0.9272 - 2s/epoch - 10ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3095 - auc: 0.9406 - val_loss: 0.3634 - val_auc: 0.9289 - 2s/epoch - 10ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.3029 - auc: 0.9430 - val_loss: 0.3445 - val_auc: 0.9281 - 2s/epoch - 12ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.3006 - auc: 0.9444 - val_loss: 0.3389 - val_auc: 0.9326 - 2s/epoch - 11ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.2974 - auc: 0.9454 - val_loss: 0.3506 - val_auc: 0.9303 - 2s/epoch - 9ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.2962 - auc: 0.9458 - val_loss: 0.3417 - val_auc: 0.9280 - 2s/epoch - 10ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.2982 - auc: 0.9449 - val_loss: 0.3421 - val_auc: 0.9303 - 2s/epoch - 10ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.2945 - auc: 0.9464 - val_loss: 0.3329 - val_auc: 0.9328 - 2s/epoch - 10ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.2944 - auc: 0.9461 - val_loss: 0.3423 - val_auc: 0.9290 - 2s/epoch - 12ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.2897 - auc: 0.9481 - val_loss: 0.3455 - val_auc: 0.9287 - 2s/epoch - 10ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.2914 - auc: 0.9478 - val_loss: 0.3405 - val_auc: 0.9302 - 2s/epoch - 10ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.2891 - auc: 0.9483 - val_loss: 0.3855 - val_auc: 0.9296 - 2s/epoch - 10ms/step
# Epoch 34/64
# 183/183 - 2s - loss: 0.2858 - auc: 0.9495 - val_loss: 0.3576 - val_auc: 0.9222 - 2s/epoch - 10ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.2878 - auc: 0.9490 - val_loss: 0.3402 - val_auc: 0.9305 - 2s/epoch - 10ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.2801 - auc: 0.9516 - val_loss: 0.3466 - val_auc: 0.9284 - 2s/epoch - 10ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.2809 - auc: 0.9509 - val_loss: 0.3416 - val_auc: 0.9309 - 2s/epoch - 11ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.2774 - auc: 0.9528 - val_loss: 0.3578 - val_auc: 0.9281 - 2s/epoch - 10ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.2767 - auc: 0.9528 - val_loss: 0.3448 - val_auc: 0.9297 - 2s/epoch - 10ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.2758 - auc: 0.9532 - val_loss: 0.3518 - val_auc: 0.9266 - 2s/epoch - 10ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.2735 - auc: 0.9537 - val_loss: 0.3541 - val_auc: 0.9290 - 2s/epoch - 10ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.2767 - auc: 0.9526 - val_loss: 0.3476 - val_auc: 0.9296 - 2s/epoch - 10ms/step
# Epoch 43/64
# 183/183 - 2s - loss: 0.2671 - auc: 0.9561 - val_loss: 0.3414 - val_auc: 0.9280 - 2s/epoch - 12ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.2674 - auc: 0.9559 - val_loss: 0.3555 - val_auc: 0.9276 - 2s/epoch - 10ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2709 - auc: 0.9546 - val_loss: 0.3489 - val_auc: 0.9245 - 2s/epoch - 10ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2632 - auc: 0.9573 - val_loss: 0.3565 - val_auc: 0.9309 - 2s/epoch - 10ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.2640 - auc: 0.9569 - val_loss: 0.3633 - val_auc: 0.9304 - 2s/epoch - 12ms/step
# Epoch 48/64
# 183/183 - 3s - loss: 0.2668 - auc: 0.9561 - val_loss: 0.3462 - val_auc: 0.9303 - 3s/epoch - 16ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2559 - auc: 0.9595 - val_loss: 0.3765 - val_auc: 0.9192 - 2s/epoch - 11ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2666 - auc: 0.9560 - val_loss: 0.3827 - val_auc: 0.9311 - 2s/epoch - 10ms/step
# Epoch 51/64
# 183/183 - 2s - loss: 0.2574 - auc: 0.9590 - val_loss: 0.3678 - val_auc: 0.9254 - 2s/epoch - 10ms/step
# Epoch 52/64
# 183/183 - 2s - loss: 0.2589 - auc: 0.9582 - val_loss: 0.3581 - val_auc: 0.9292 - 2s/epoch - 10ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2539 - auc: 0.9603 - val_loss: 0.3554 - val_auc: 0.9253 - 2s/epoch - 10ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2477 - auc: 0.9621 - val_loss: 0.4084 - val_auc: 0.9212 - 2s/epoch - 12ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2530 - auc: 0.9605 - val_loss: 0.4107 - val_auc: 0.9282 - 2s/epoch - 11ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2455 - auc: 0.9630 - val_loss: 0.3883 - val_auc: 0.9168 - 2s/epoch - 9ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2498 - auc: 0.9614 - val_loss: 0.3756 - val_auc: 0.9257 - 2s/epoch - 10ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2432 - auc: 0.9638 - val_loss: 0.3766 - val_auc: 0.9276 - 2s/epoch - 10ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2497 - auc: 0.9617 - val_loss: 0.3558 - val_auc: 0.9271 - 2s/epoch - 10ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2400 - auc: 0.9643 - val_loss: 0.3650 - val_auc: 0.9253 - 2s/epoch - 10ms/step
# Epoch 61/64
# 183/183 - 2s - loss: 0.2432 - auc: 0.9636 - val_loss: 0.3836 - val_auc: 0.9244 - 2s/epoch - 12ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2445 - auc: 0.9631 - val_loss: 0.3814 - val_auc: 0.9181 - 2s/epoch - 10ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2415 - auc: 0.9644 - val_loss: 0.3754 - val_auc: 0.9254 - 2s/epoch - 9ms/step
# Epoch 64/64
# 183/183 - 2s - loss: 0.2375 - auc: 0.9651 - val_loss: 0.3775 - val_auc: 0.9190 - 2s/epoch - 10ms/step
# 46/46 [==============================] - 1s 8ms/step
#
# Training on Fold 2...
# Epoch 1/64
# 183/183 - 8s - loss: 0.4922 - auc_1: 0.8288 - val_loss: 0.4332 - val_auc_1: 0.8968 - 8s/epoch - 43ms/step
# Epoch 2/64
# 183/183 - 2s - loss: 0.4439 - auc_1: 0.8385 - val_loss: 0.4326 - val_auc_1: 0.8598 - 2s/epoch - 10ms/step
# Epoch 3/64
# 183/183 - 2s - loss: 0.4282 - auc_1: 0.8642 - val_loss: 0.4031 - val_auc_1: 0.9107 - 2s/epoch - 13ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.3879 - auc_1: 0.9047 - val_loss: 0.4015 - val_auc_1: 0.9191 - 2s/epoch - 10ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3767 - auc_1: 0.9107 - val_loss: 0.3592 - val_auc_1: 0.9215 - 2s/epoch - 10ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3690 - auc_1: 0.9151 - val_loss: 0.3549 - val_auc_1: 0.9236 - 2s/epoch - 10ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3597 - auc_1: 0.9193 - val_loss: 0.3808 - val_auc_1: 0.9272 - 2s/epoch - 10ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3540 - auc_1: 0.9221 - val_loss: 0.3388 - val_auc_1: 0.9348 - 2s/epoch - 10ms/step
# Epoch 9/64
# 183/183 - 3s - loss: 0.3444 - auc_1: 0.9267 - val_loss: 0.3539 - val_auc_1: 0.9337 - 3s/epoch - 14ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3414 - auc_1: 0.9275 - val_loss: 0.3230 - val_auc_1: 0.9368 - 2s/epoch - 10ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3329 - auc_1: 0.9314 - val_loss: 0.3252 - val_auc_1: 0.9374 - 2s/epoch - 10ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3340 - auc_1: 0.9312 - val_loss: 0.3264 - val_auc_1: 0.9354 - 2s/epoch - 10ms/step
# Epoch 13/64
# 183/183 - 2s - loss: 0.3306 - auc_1: 0.9320 - val_loss: 0.3293 - val_auc_1: 0.9336 - 2s/epoch - 10ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3296 - auc_1: 0.9329 - val_loss: 0.3206 - val_auc_1: 0.9370 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3293 - auc_1: 0.9328 - val_loss: 0.3298 - val_auc_1: 0.9352 - 2s/epoch - 13ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3264 - auc_1: 0.9345 - val_loss: 0.3187 - val_auc_1: 0.9388 - 2s/epoch - 10ms/step
# Epoch 17/64
# 183/183 - 2s - loss: 0.3222 - auc_1: 0.9358 - val_loss: 0.3176 - val_auc_1: 0.9387 - 2s/epoch - 10ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3214 - auc_1: 0.9361 - val_loss: 0.3211 - val_auc_1: 0.9396 - 2s/epoch - 10ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3173 - auc_1: 0.9378 - val_loss: 0.3258 - val_auc_1: 0.9338 - 2s/epoch - 10ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3163 - auc_1: 0.9379 - val_loss: 0.3178 - val_auc_1: 0.9377 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3144 - auc_1: 0.9393 - val_loss: 0.3354 - val_auc_1: 0.9381 - 2s/epoch - 13ms/step
# Epoch 22/64
# 183/183 - 2s - loss: 0.3131 - auc_1: 0.9398 - val_loss: 0.3342 - val_auc_1: 0.9378 - 2s/epoch - 10ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3121 - auc_1: 0.9395 - val_loss: 0.3282 - val_auc_1: 0.9354 - 2s/epoch - 10ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.3102 - auc_1: 0.9410 - val_loss: 0.3121 - val_auc_1: 0.9402 - 2s/epoch - 10ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.3093 - auc_1: 0.9411 - val_loss: 0.3320 - val_auc_1: 0.9335 - 2s/epoch - 10ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.3060 - auc_1: 0.9423 - val_loss: 0.3191 - val_auc_1: 0.9370 - 2s/epoch - 10ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.3077 - auc_1: 0.9418 - val_loss: 0.3176 - val_auc_1: 0.9380 - 2s/epoch - 11ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.3046 - auc_1: 0.9430 - val_loss: 0.3174 - val_auc_1: 0.9378 - 2s/epoch - 11ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.3034 - auc_1: 0.9436 - val_loss: 0.3212 - val_auc_1: 0.9358 - 2s/epoch - 10ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.3017 - auc_1: 0.9442 - val_loss: 0.3186 - val_auc_1: 0.9378 - 2s/epoch - 10ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.2964 - auc_1: 0.9462 - val_loss: 0.3295 - val_auc_1: 0.9352 - 2s/epoch - 10ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.2978 - auc_1: 0.9454 - val_loss: 0.3284 - val_auc_1: 0.9343 - 2s/epoch - 10ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.2959 - auc_1: 0.9463 - val_loss: 0.3311 - val_auc_1: 0.9321 - 2s/epoch - 10ms/step
# Epoch 34/64
# 183/183 - 2s - loss: 0.2984 - auc_1: 0.9454 - val_loss: 0.3285 - val_auc_1: 0.9338 - 2s/epoch - 12ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.2936 - auc_1: 0.9473 - val_loss: 0.3298 - val_auc_1: 0.9322 - 2s/epoch - 10ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.2916 - auc_1: 0.9479 - val_loss: 0.3242 - val_auc_1: 0.9350 - 2s/epoch - 10ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.2919 - auc_1: 0.9477 - val_loss: 0.3367 - val_auc_1: 0.9304 - 2s/epoch - 10ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.2900 - auc_1: 0.9485 - val_loss: 0.3291 - val_auc_1: 0.9358 - 2s/epoch - 10ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.2857 - auc_1: 0.9502 - val_loss: 0.3305 - val_auc_1: 0.9331 - 2s/epoch - 10ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.2872 - auc_1: 0.9496 - val_loss: 0.3537 - val_auc_1: 0.9307 - 2s/epoch - 13ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.2853 - auc_1: 0.9503 - val_loss: 0.3404 - val_auc_1: 0.9291 - 2s/epoch - 10ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.2810 - auc_1: 0.9517 - val_loss: 0.3525 - val_auc_1: 0.9244 - 2s/epoch - 10ms/step
# Epoch 43/64
# 183/183 - 2s - loss: 0.2822 - auc_1: 0.9513 - val_loss: 0.3399 - val_auc_1: 0.9293 - 2s/epoch - 10ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.2783 - auc_1: 0.9527 - val_loss: 0.3463 - val_auc_1: 0.9280 - 2s/epoch - 10ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2799 - auc_1: 0.9522 - val_loss: 0.3340 - val_auc_1: 0.9313 - 2s/epoch - 10ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2700 - auc_1: 0.9554 - val_loss: 0.3534 - val_auc_1: 0.9266 - 2s/epoch - 12ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.2725 - auc_1: 0.9546 - val_loss: 0.3381 - val_auc_1: 0.9298 - 2s/epoch - 10ms/step
# Epoch 48/64
# 183/183 - 2s - loss: 0.2705 - auc_1: 0.9553 - val_loss: 0.3473 - val_auc_1: 0.9323 - 2s/epoch - 10ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2747 - auc_1: 0.9540 - val_loss: 0.3357 - val_auc_1: 0.9335 - 2s/epoch - 10ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2720 - auc_1: 0.9547 - val_loss: 0.3453 - val_auc_1: 0.9267 - 2s/epoch - 9ms/step
# Epoch 51/64
# 183/183 - 2s - loss: 0.2702 - auc_1: 0.9554 - val_loss: 0.3438 - val_auc_1: 0.9286 - 2s/epoch - 10ms/step
# Epoch 52/64
# 183/183 - 2s - loss: 0.2672 - auc_1: 0.9565 - val_loss: 0.3327 - val_auc_1: 0.9349 - 2s/epoch - 13ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2687 - auc_1: 0.9560 - val_loss: 0.3451 - val_auc_1: 0.9336 - 2s/epoch - 10ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2656 - auc_1: 0.9569 - val_loss: 0.3274 - val_auc_1: 0.9345 - 2s/epoch - 10ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2633 - auc_1: 0.9576 - val_loss: 0.3415 - val_auc_1: 0.9324 - 2s/epoch - 10ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2607 - auc_1: 0.9586 - val_loss: 0.3432 - val_auc_1: 0.9288 - 2s/epoch - 10ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2615 - auc_1: 0.9583 - val_loss: 0.3513 - val_auc_1: 0.9334 - 2s/epoch - 10ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2547 - auc_1: 0.9605 - val_loss: 0.3566 - val_auc_1: 0.9318 - 2s/epoch - 13ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2586 - auc_1: 0.9591 - val_loss: 0.3599 - val_auc_1: 0.9252 - 2s/epoch - 11ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2570 - auc_1: 0.9596 - val_loss: 0.3605 - val_auc_1: 0.9245 - 2s/epoch - 10ms/step
# Epoch 61/64
# 183/183 - 2s - loss: 0.2512 - auc_1: 0.9615 - val_loss: 0.3497 - val_auc_1: 0.9261 - 2s/epoch - 10ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2538 - auc_1: 0.9607 - val_loss: 0.3696 - val_auc_1: 0.9239 - 2s/epoch - 10ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2484 - auc_1: 0.9623 - val_loss: 0.3498 - val_auc_1: 0.9275 - 2s/epoch - 10ms/step
# Epoch 64/64
# 183/183 - 2s - loss: 0.2467 - auc_1: 0.9629 - val_loss: 0.3514 - val_auc_1: 0.9294 - 2s/epoch - 11ms/step
# 46/46 [==============================] - 1s 8ms/step
#
# Training on Fold 3...
# Epoch 1/64
# 183/183 - 8s - loss: 0.4550 - auc_2: 0.8452 - val_loss: 0.4333 - val_auc_2: 0.8635 - 8s/epoch - 44ms/step
# Epoch 2/64
# 183/183 - 2s - loss: 0.4413 - auc_2: 0.8466 - val_loss: 0.4300 - val_auc_2: 0.8899 - 2s/epoch - 12ms/step
# Epoch 3/64
# 183/183 - 2s - loss: 0.4115 - auc_2: 0.8831 - val_loss: 0.3726 - val_auc_2: 0.9148 - 2s/epoch - 11ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.3674 - auc_2: 0.9156 - val_loss: 0.3615 - val_auc_2: 0.9202 - 2s/epoch - 11ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3566 - auc_2: 0.9203 - val_loss: 0.3602 - val_auc_2: 0.9203 - 2s/epoch - 10ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3496 - auc_2: 0.9235 - val_loss: 0.3541 - val_auc_2: 0.9224 - 2s/epoch - 10ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3455 - auc_2: 0.9255 - val_loss: 0.3607 - val_auc_2: 0.9232 - 2s/epoch - 10ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3444 - auc_2: 0.9264 - val_loss: 0.3526 - val_auc_2: 0.9240 - 2s/epoch - 11ms/step
# Epoch 9/64
# 183/183 - 2s - loss: 0.3398 - auc_2: 0.9283 - val_loss: 0.3478 - val_auc_2: 0.9251 - 2s/epoch - 11ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3362 - auc_2: 0.9303 - val_loss: 0.3992 - val_auc_2: 0.9019 - 2s/epoch - 11ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3376 - auc_2: 0.9295 - val_loss: 0.3542 - val_auc_2: 0.9269 - 2s/epoch - 10ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3323 - auc_2: 0.9315 - val_loss: 0.3435 - val_auc_2: 0.9271 - 2s/epoch - 10ms/step
# Epoch 13/64
# 183/183 - 2s - loss: 0.3286 - auc_2: 0.9330 - val_loss: 0.3444 - val_auc_2: 0.9266 - 2s/epoch - 10ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3278 - auc_2: 0.9335 - val_loss: 0.3612 - val_auc_2: 0.9278 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3209 - auc_2: 0.9365 - val_loss: 0.3447 - val_auc_2: 0.9280 - 2s/epoch - 12ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3158 - auc_2: 0.9383 - val_loss: 0.3465 - val_auc_2: 0.9289 - 2s/epoch - 10ms/step
# Epoch 17/64
# 183/183 - 2s - loss: 0.3145 - auc_2: 0.9389 - val_loss: 0.3543 - val_auc_2: 0.9243 - 2s/epoch - 10ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3120 - auc_2: 0.9397 - val_loss: 0.3460 - val_auc_2: 0.9272 - 2s/epoch - 10ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3105 - auc_2: 0.9404 - val_loss: 0.3412 - val_auc_2: 0.9296 - 2s/epoch - 10ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3086 - auc_2: 0.9411 - val_loss: 0.3572 - val_auc_2: 0.9302 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3059 - auc_2: 0.9423 - val_loss: 0.3395 - val_auc_2: 0.9287 - 2s/epoch - 14ms/step
# Epoch 22/64
# 183/183 - 2s - loss: 0.3043 - auc_2: 0.9426 - val_loss: 0.3594 - val_auc_2: 0.9255 - 2s/epoch - 10ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3006 - auc_2: 0.9441 - val_loss: 0.3559 - val_auc_2: 0.9241 - 2s/epoch - 10ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.2977 - auc_2: 0.9452 - val_loss: 0.3435 - val_auc_2: 0.9269 - 2s/epoch - 10ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.2990 - auc_2: 0.9447 - val_loss: 0.3500 - val_auc_2: 0.9253 - 2s/epoch - 10ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.2969 - auc_2: 0.9452 - val_loss: 0.3597 - val_auc_2: 0.9251 - 2s/epoch - 10ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.2957 - auc_2: 0.9458 - val_loss: 0.3581 - val_auc_2: 0.9278 - 2s/epoch - 13ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.2946 - auc_2: 0.9465 - val_loss: 0.3453 - val_auc_2: 0.9273 - 2s/epoch - 10ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.2862 - auc_2: 0.9495 - val_loss: 0.3487 - val_auc_2: 0.9278 - 2s/epoch - 10ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.2910 - auc_2: 0.9479 - val_loss: 0.3679 - val_auc_2: 0.9285 - 2s/epoch - 10ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.2829 - auc_2: 0.9506 - val_loss: 0.3697 - val_auc_2: 0.9213 - 2s/epoch - 10ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.2861 - auc_2: 0.9491 - val_loss: 0.3589 - val_auc_2: 0.9225 - 2s/epoch - 10ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.2792 - auc_2: 0.9515 - val_loss: 0.3732 - val_auc_2: 0.9164 - 2s/epoch - 13ms/step
# Epoch 34/64
# 183/183 - 2s - loss: 0.2828 - auc_2: 0.9507 - val_loss: 0.3637 - val_auc_2: 0.9281 - 2s/epoch - 10ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.2760 - auc_2: 0.9530 - val_loss: 0.3743 - val_auc_2: 0.9219 - 2s/epoch - 10ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.2748 - auc_2: 0.9534 - val_loss: 0.3811 - val_auc_2: 0.9152 - 2s/epoch - 10ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.2729 - auc_2: 0.9539 - val_loss: 0.3721 - val_auc_2: 0.9178 - 2s/epoch - 10ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.2716 - auc_2: 0.9546 - val_loss: 0.3563 - val_auc_2: 0.9266 - 2s/epoch - 10ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.2718 - auc_2: 0.9542 - val_loss: 0.3617 - val_auc_2: 0.9223 - 2s/epoch - 13ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.2705 - auc_2: 0.9549 - val_loss: 0.3543 - val_auc_2: 0.9241 - 2s/epoch - 10ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.2658 - auc_2: 0.9564 - val_loss: 0.3760 - val_auc_2: 0.9202 - 2s/epoch - 10ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.2661 - auc_2: 0.9558 - val_loss: 0.3651 - val_auc_2: 0.9241 - 2s/epoch - 10ms/step
# Epoch 43/64
# 183/183 - 2s - loss: 0.2633 - auc_2: 0.9570 - val_loss: 0.3591 - val_auc_2: 0.9244 - 2s/epoch - 10ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.2587 - auc_2: 0.9586 - val_loss: 0.3742 - val_auc_2: 0.9245 - 2s/epoch - 10ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2553 - auc_2: 0.9596 - val_loss: 0.3703 - val_auc_2: 0.9190 - 2s/epoch - 12ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2619 - auc_2: 0.9573 - val_loss: 0.3765 - val_auc_2: 0.9230 - 2s/epoch - 10ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.2540 - auc_2: 0.9598 - val_loss: 0.3724 - val_auc_2: 0.9223 - 2s/epoch - 10ms/step
# Epoch 48/64
# 183/183 - 2s - loss: 0.2560 - auc_2: 0.9595 - val_loss: 0.3778 - val_auc_2: 0.9187 - 2s/epoch - 10ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2579 - auc_2: 0.9586 - val_loss: 0.3694 - val_auc_2: 0.9257 - 2s/epoch - 10ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2475 - auc_2: 0.9623 - val_loss: 0.3887 - val_auc_2: 0.9136 - 2s/epoch - 10ms/step
# Epoch 51/64
# 183/183 - 2s - loss: 0.2493 - auc_2: 0.9618 - val_loss: 0.3918 - val_auc_2: 0.9284 - 2s/epoch - 11ms/step
# Epoch 52/64
# 183/183 - 2s - loss: 0.2483 - auc_2: 0.9618 - val_loss: 0.3684 - val_auc_2: 0.9223 - 2s/epoch - 11ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2449 - auc_2: 0.9627 - val_loss: 0.3763 - val_auc_2: 0.9263 - 2s/epoch - 10ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2446 - auc_2: 0.9629 - val_loss: 0.3868 - val_auc_2: 0.9243 - 2s/epoch - 10ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2429 - auc_2: 0.9635 - val_loss: 0.3734 - val_auc_2: 0.9222 - 2s/epoch - 10ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2389 - auc_2: 0.9647 - val_loss: 0.3859 - val_auc_2: 0.9194 - 2s/epoch - 10ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2378 - auc_2: 0.9647 - val_loss: 0.3591 - val_auc_2: 0.9252 - 2s/epoch - 10ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2414 - auc_2: 0.9640 - val_loss: 0.3945 - val_auc_2: 0.9234 - 2s/epoch - 13ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2377 - auc_2: 0.9649 - val_loss: 0.3692 - val_auc_2: 0.9205 - 2s/epoch - 10ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2380 - auc_2: 0.9648 - val_loss: 0.3884 - val_auc_2: 0.9177 - 2s/epoch - 10ms/step
# Epoch 61/64
# 183/183 - 2s - loss: 0.2342 - auc_2: 0.9659 - val_loss: 0.3762 - val_auc_2: 0.9218 - 2s/epoch - 10ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2328 - auc_2: 0.9663 - val_loss: 0.3757 - val_auc_2: 0.9228 - 2s/epoch - 10ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2278 - auc_2: 0.9678 - val_loss: 0.3685 - val_auc_2: 0.9204 - 2s/epoch - 10ms/step
# Epoch 64/64
# 183/183 - 2s - loss: 0.2259 - auc_2: 0.9684 - val_loss: 0.4022 - val_auc_2: 0.9204 - 2s/epoch - 12ms/step
# 46/46 [==============================] - 1s 6ms/step
#
# Training on Fold 4...
# Epoch 1/64
# 183/183 - 8s - loss: 0.4550 - auc_3: 0.8406 - val_loss: 0.4321 - val_auc_3: 0.8849 - 8s/epoch - 46ms/step
# Epoch 2/64
# 183/183 - 2s - loss: 0.4393 - auc_3: 0.8463 - val_loss: 0.4281 - val_auc_3: 0.8960 - 2s/epoch - 11ms/step
# Epoch 3/64
# 183/183 - 2s - loss: 0.4073 - auc_3: 0.8901 - val_loss: 0.3874 - val_auc_3: 0.9096 - 2s/epoch - 10ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.3642 - auc_3: 0.9166 - val_loss: 0.3646 - val_auc_3: 0.9167 - 2s/epoch - 10ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3552 - auc_3: 0.9206 - val_loss: 0.3608 - val_auc_3: 0.9173 - 2s/epoch - 12ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3450 - auc_3: 0.9252 - val_loss: 0.3616 - val_auc_3: 0.9175 - 2s/epoch - 10ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3484 - auc_3: 0.9239 - val_loss: 0.3920 - val_auc_3: 0.9205 - 2s/epoch - 10ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3431 - auc_3: 0.9265 - val_loss: 0.3561 - val_auc_3: 0.9212 - 2s/epoch - 10ms/step
# Epoch 9/64
# 183/183 - 2s - loss: 0.3394 - auc_3: 0.9281 - val_loss: 0.3696 - val_auc_3: 0.9214 - 2s/epoch - 10ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3371 - auc_3: 0.9293 - val_loss: 0.3535 - val_auc_3: 0.9213 - 2s/epoch - 10ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3329 - auc_3: 0.9307 - val_loss: 0.3568 - val_auc_3: 0.9211 - 2s/epoch - 12ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3297 - auc_3: 0.9327 - val_loss: 0.3596 - val_auc_3: 0.9230 - 2s/epoch - 10ms/step
# Epoch 13/64
# 183/183 - 2s - loss: 0.3252 - auc_3: 0.9345 - val_loss: 0.3604 - val_auc_3: 0.9202 - 2s/epoch - 10ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3218 - auc_3: 0.9360 - val_loss: 0.3558 - val_auc_3: 0.9225 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3190 - auc_3: 0.9370 - val_loss: 0.3687 - val_auc_3: 0.9208 - 2s/epoch - 10ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3165 - auc_3: 0.9380 - val_loss: 0.3641 - val_auc_3: 0.9242 - 2s/epoch - 10ms/step
# Epoch 17/64
# 183/183 - 2s - loss: 0.3210 - auc_3: 0.9363 - val_loss: 0.3614 - val_auc_3: 0.9212 - 2s/epoch - 13ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3144 - auc_3: 0.9390 - val_loss: 0.3601 - val_auc_3: 0.9208 - 2s/epoch - 10ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3082 - auc_3: 0.9410 - val_loss: 0.3622 - val_auc_3: 0.9208 - 2s/epoch - 10ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3056 - auc_3: 0.9422 - val_loss: 0.3654 - val_auc_3: 0.9214 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3058 - auc_3: 0.9420 - val_loss: 0.3675 - val_auc_3: 0.9216 - 2s/epoch - 10ms/step
# Epoch 22/64
# 183/183 - 2s - loss: 0.3080 - auc_3: 0.9416 - val_loss: 0.3523 - val_auc_3: 0.9240 - 2s/epoch - 10ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3038 - auc_3: 0.9431 - val_loss: 0.3641 - val_auc_3: 0.9226 - 2s/epoch - 13ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.3044 - auc_3: 0.9429 - val_loss: 0.3770 - val_auc_3: 0.9221 - 2s/epoch - 10ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.3039 - auc_3: 0.9431 - val_loss: 0.3613 - val_auc_3: 0.9228 - 2s/epoch - 10ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.2996 - auc_3: 0.9447 - val_loss: 0.3763 - val_auc_3: 0.9154 - 2s/epoch - 10ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.2981 - auc_3: 0.9451 - val_loss: 0.3704 - val_auc_3: 0.9230 - 2s/epoch - 10ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.2997 - auc_3: 0.9445 - val_loss: 0.4006 - val_auc_3: 0.9022 - 2s/epoch - 10ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.2951 - auc_3: 0.9465 - val_loss: 0.3558 - val_auc_3: 0.9229 - 2s/epoch - 11ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.2946 - auc_3: 0.9464 - val_loss: 0.3611 - val_auc_3: 0.9227 - 2s/epoch - 11ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.2990 - auc_3: 0.9450 - val_loss: 0.3650 - val_auc_3: 0.9225 - 2s/epoch - 9ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.2923 - auc_3: 0.9473 - val_loss: 0.3653 - val_auc_3: 0.9214 - 2s/epoch - 10ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.2909 - auc_3: 0.9477 - val_loss: 0.3698 - val_auc_3: 0.9183 - 2s/epoch - 10ms/step
# Epoch 34/64
# 183/183 - 2s - loss: 0.2920 - auc_3: 0.9470 - val_loss: 0.3783 - val_auc_3: 0.9220 - 2s/epoch - 10ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.2894 - auc_3: 0.9484 - val_loss: 0.3750 - val_auc_3: 0.9144 - 2s/epoch - 10ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.2893 - auc_3: 0.9481 - val_loss: 0.3713 - val_auc_3: 0.9222 - 2s/epoch - 12ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.2856 - auc_3: 0.9496 - val_loss: 0.3738 - val_auc_3: 0.9188 - 2s/epoch - 10ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.2868 - auc_3: 0.9489 - val_loss: 0.3917 - val_auc_3: 0.9106 - 2s/epoch - 10ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.2866 - auc_3: 0.9492 - val_loss: 0.3806 - val_auc_3: 0.9135 - 2s/epoch - 10ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.2802 - auc_3: 0.9516 - val_loss: 0.3919 - val_auc_3: 0.9113 - 2s/epoch - 10ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.2824 - auc_3: 0.9507 - val_loss: 0.3836 - val_auc_3: 0.9112 - 2s/epoch - 10ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.2799 - auc_3: 0.9517 - val_loss: 0.3716 - val_auc_3: 0.9199 - 2s/epoch - 12ms/step
# Epoch 43/64
# 183/183 - 2s - loss: 0.2836 - auc_3: 0.9505 - val_loss: 0.3734 - val_auc_3: 0.9239 - 2s/epoch - 10ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.2784 - auc_3: 0.9522 - val_loss: 0.4028 - val_auc_3: 0.9102 - 2s/epoch - 10ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2755 - auc_3: 0.9531 - val_loss: 0.3869 - val_auc_3: 0.9111 - 2s/epoch - 10ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2750 - auc_3: 0.9536 - val_loss: 0.3726 - val_auc_3: 0.9165 - 2s/epoch - 10ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.2704 - auc_3: 0.9547 - val_loss: 0.3800 - val_auc_3: 0.9191 - 2s/epoch - 10ms/step
# Epoch 48/64
# 183/183 - 2s - loss: 0.2706 - auc_3: 0.9549 - val_loss: 0.3792 - val_auc_3: 0.9211 - 2s/epoch - 11ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2670 - auc_3: 0.9559 - val_loss: 0.3902 - val_auc_3: 0.9168 - 2s/epoch - 10ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2684 - auc_3: 0.9554 - val_loss: 0.3959 - val_auc_3: 0.9191 - 2s/epoch - 10ms/step
# Epoch 51/64
# 183/183 - 2s - loss: 0.2665 - auc_3: 0.9564 - val_loss: 0.3750 - val_auc_3: 0.9209 - 2s/epoch - 10ms/step
# Epoch 52/64
# 183/183 - 2s - loss: 0.2660 - auc_3: 0.9562 - val_loss: 0.4007 - val_auc_3: 0.9107 - 2s/epoch - 10ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2621 - auc_3: 0.9576 - val_loss: 0.3886 - val_auc_3: 0.9122 - 2s/epoch - 10ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2588 - auc_3: 0.9583 - val_loss: 0.3800 - val_auc_3: 0.9142 - 2s/epoch - 12ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2590 - auc_3: 0.9585 - val_loss: 0.3873 - val_auc_3: 0.9144 - 2s/epoch - 11ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2579 - auc_3: 0.9589 - val_loss: 0.3806 - val_auc_3: 0.9191 - 2s/epoch - 10ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2579 - auc_3: 0.9589 - val_loss: 0.4170 - val_auc_3: 0.9104 - 2s/epoch - 10ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2559 - auc_3: 0.9595 - val_loss: 0.4260 - val_auc_3: 0.9138 - 2s/epoch - 10ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2532 - auc_3: 0.9602 - val_loss: 0.4101 - val_auc_3: 0.9125 - 2s/epoch - 10ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2539 - auc_3: 0.9600 - val_loss: 0.4293 - val_auc_3: 0.9059 - 2s/epoch - 12ms/step
# Epoch 61/64
# 183/183 - 2s - loss: 0.2508 - auc_3: 0.9609 - val_loss: 0.4145 - val_auc_3: 0.9192 - 2s/epoch - 11ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2484 - auc_3: 0.9620 - val_loss: 0.4070 - val_auc_3: 0.9180 - 2s/epoch - 10ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2453 - auc_3: 0.9628 - val_loss: 0.4007 - val_auc_3: 0.9197 - 2s/epoch - 10ms/step
# Epoch 64/64
# 183/183 - 2s - loss: 0.2457 - auc_3: 0.9626 - val_loss: 0.3957 - val_auc_3: 0.9184 - 2s/epoch - 10ms/step
# 46/46 [==============================] - 1s 6ms/step
#
# Training on Fold 5...
# Epoch 1/64
# 183/183 - 8s - loss: 0.4445 - auc_4: 0.8455 - val_loss: 0.4313 - val_auc_4: 0.8724 - 8s/epoch - 46ms/step
# Epoch 2/64
# 183/183 - 2s - loss: 0.4353 - auc_4: 0.8558 - val_loss: 0.3848 - val_auc_4: 0.9142 - 2s/epoch - 10ms/step
# Epoch 3/64
# 183/183 - 2s - loss: 0.3928 - auc_4: 0.9017 - val_loss: 0.3632 - val_auc_4: 0.9200 - 2s/epoch - 10ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.3725 - auc_4: 0.9133 - val_loss: 0.3492 - val_auc_4: 0.9250 - 2s/epoch - 10ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3587 - auc_4: 0.9198 - val_loss: 0.3409 - val_auc_4: 0.9273 - 2s/epoch - 10ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3523 - auc_4: 0.9232 - val_loss: 0.3412 - val_auc_4: 0.9275 - 2s/epoch - 10ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3454 - auc_4: 0.9257 - val_loss: 0.3387 - val_auc_4: 0.9281 - 2s/epoch - 12ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3408 - auc_4: 0.9281 - val_loss: 0.3340 - val_auc_4: 0.9305 - 2s/epoch - 10ms/step
# Epoch 9/64
# 183/183 - 2s - loss: 0.3392 - auc_4: 0.9286 - val_loss: 0.3633 - val_auc_4: 0.9293 - 2s/epoch - 10ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3328 - auc_4: 0.9312 - val_loss: 0.3302 - val_auc_4: 0.9320 - 2s/epoch - 11ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3272 - auc_4: 0.9338 - val_loss: 0.3623 - val_auc_4: 0.9312 - 2s/epoch - 10ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3283 - auc_4: 0.9330 - val_loss: 0.3472 - val_auc_4: 0.9308 - 2s/epoch - 10ms/step
# Epoch 13/64
# 183/183 - 3s - loss: 0.3219 - auc_4: 0.9359 - val_loss: 0.3301 - val_auc_4: 0.9321 - 3s/epoch - 14ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3185 - auc_4: 0.9373 - val_loss: 0.3327 - val_auc_4: 0.9329 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3229 - auc_4: 0.9353 - val_loss: 0.3292 - val_auc_4: 0.9342 - 2s/epoch - 10ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3189 - auc_4: 0.9369 - val_loss: 0.3287 - val_auc_4: 0.9327 - 2s/epoch - 10ms/step
# Epoch 17/64
# 183/183 - 2s - loss: 0.3179 - auc_4: 0.9374 - val_loss: 0.3285 - val_auc_4: 0.9333 - 2s/epoch - 10ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3132 - auc_4: 0.9393 - val_loss: 0.3305 - val_auc_4: 0.9323 - 2s/epoch - 10ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3087 - auc_4: 0.9412 - val_loss: 0.3295 - val_auc_4: 0.9324 - 2s/epoch - 11ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3038 - auc_4: 0.9426 - val_loss: 0.3352 - val_auc_4: 0.9326 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3058 - auc_4: 0.9422 - val_loss: 0.3352 - val_auc_4: 0.9335 - 2s/epoch - 10ms/step
# Epoch 22/64
# 183/183 - 2s - loss: 0.3034 - auc_4: 0.9434 - val_loss: 0.3289 - val_auc_4: 0.9343 - 2s/epoch - 10ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3005 - auc_4: 0.9441 - val_loss: 0.3365 - val_auc_4: 0.9302 - 2s/epoch - 10ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.2943 - auc_4: 0.9465 - val_loss: 0.3515 - val_auc_4: 0.9318 - 2s/epoch - 10ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.3001 - auc_4: 0.9446 - val_loss: 0.3266 - val_auc_4: 0.9347 - 2s/epoch - 12ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.2967 - auc_4: 0.9454 - val_loss: 0.3541 - val_auc_4: 0.9326 - 2s/epoch - 11ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.2919 - auc_4: 0.9474 - val_loss: 0.3460 - val_auc_4: 0.9327 - 2s/epoch - 10ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.2873 - auc_4: 0.9490 - val_loss: 0.3365 - val_auc_4: 0.9303 - 2s/epoch - 10ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.2903 - auc_4: 0.9481 - val_loss: 0.3316 - val_auc_4: 0.9329 - 2s/epoch - 10ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.2859 - auc_4: 0.9498 - val_loss: 0.3440 - val_auc_4: 0.9320 - 2s/epoch - 10ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.2874 - auc_4: 0.9490 - val_loss: 0.3322 - val_auc_4: 0.9330 - 2s/epoch - 10ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.2835 - auc_4: 0.9504 - val_loss: 0.3374 - val_auc_4: 0.9336 - 2s/epoch - 12ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.2835 - auc_4: 0.9507 - val_loss: 0.3294 - val_auc_4: 0.9336 - 2s/epoch - 10ms/step
# Epoch 34/64
# 183/183 - 2s - loss: 0.2815 - auc_4: 0.9512 - val_loss: 0.3341 - val_auc_4: 0.9351 - 2s/epoch - 10ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.2768 - auc_4: 0.9528 - val_loss: 0.3408 - val_auc_4: 0.9325 - 2s/epoch - 10ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.2780 - auc_4: 0.9525 - val_loss: 0.3380 - val_auc_4: 0.9315 - 2s/epoch - 10ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.2799 - auc_4: 0.9519 - val_loss: 0.3394 - val_auc_4: 0.9333 - 2s/epoch - 10ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.2718 - auc_4: 0.9546 - val_loss: 0.3477 - val_auc_4: 0.9318 - 2s/epoch - 12ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.2719 - auc_4: 0.9549 - val_loss: 0.3362 - val_auc_4: 0.9331 - 2s/epoch - 10ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.2728 - auc_4: 0.9545 - val_loss: 0.3506 - val_auc_4: 0.9296 - 2s/epoch - 10ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.2684 - auc_4: 0.9557 - val_loss: 0.3359 - val_auc_4: 0.9328 - 2s/epoch - 10ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.2703 - auc_4: 0.9551 - val_loss: 0.3595 - val_auc_4: 0.9218 - 2s/epoch - 10ms/step
# Epoch 43/64
# 183/183 - 2s - loss: 0.2691 - auc_4: 0.9558 - val_loss: 0.3420 - val_auc_4: 0.9327 - 2s/epoch - 10ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.2603 - auc_4: 0.9585 - val_loss: 0.3349 - val_auc_4: 0.9322 - 2s/epoch - 13ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2624 - auc_4: 0.9575 - val_loss: 0.3487 - val_auc_4: 0.9320 - 2s/epoch - 10ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2545 - auc_4: 0.9603 - val_loss: 0.3652 - val_auc_4: 0.9273 - 2s/epoch - 10ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.2584 - auc_4: 0.9589 - val_loss: 0.3592 - val_auc_4: 0.9232 - 2s/epoch - 10ms/step
# Epoch 48/64
# 183/183 - 2s - loss: 0.2573 - auc_4: 0.9595 - val_loss: 0.3508 - val_auc_4: 0.9298 - 2s/epoch - 10ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2549 - auc_4: 0.9601 - val_loss: 0.3814 - val_auc_4: 0.9247 - 2s/epoch - 10ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2548 - auc_4: 0.9601 - val_loss: 0.3628 - val_auc_4: 0.9250 - 2s/epoch - 12ms/step
# Epoch 51/64
# 183/183 - 2s - loss: 0.2531 - auc_4: 0.9606 - val_loss: 0.3642 - val_auc_4: 0.9264 - 2s/epoch - 10ms/step
# Epoch 52/64
# 183/183 - 2s - loss: 0.2523 - auc_4: 0.9611 - val_loss: 0.3413 - val_auc_4: 0.9293 - 2s/epoch - 10ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2502 - auc_4: 0.9615 - val_loss: 0.3427 - val_auc_4: 0.9322 - 2s/epoch - 10ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2479 - auc_4: 0.9624 - val_loss: 0.3352 - val_auc_4: 0.9336 - 2s/epoch - 10ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2483 - auc_4: 0.9622 - val_loss: 0.3466 - val_auc_4: 0.9312 - 2s/epoch - 10ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2452 - auc_4: 0.9631 - val_loss: 0.3406 - val_auc_4: 0.9284 - 2s/epoch - 11ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2396 - auc_4: 0.9647 - val_loss: 0.3781 - val_auc_4: 0.9202 - 2s/epoch - 11ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2440 - auc_4: 0.9635 - val_loss: 0.3705 - val_auc_4: 0.9264 - 2s/epoch - 10ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2395 - auc_4: 0.9647 - val_loss: 0.3581 - val_auc_4: 0.9252 - 2s/epoch - 10ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2327 - auc_4: 0.9668 - val_loss: 0.4194 - val_auc_4: 0.9220 - 2s/epoch - 10ms/step
# Epoch 61/64
# 183/183 - 2s - loss: 0.2366 - auc_4: 0.9654 - val_loss: 0.4028 - val_auc_4: 0.9082 - 2s/epoch - 10ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2305 - auc_4: 0.9674 - val_loss: 0.3853 - val_auc_4: 0.9260 - 2s/epoch - 12ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2306 - auc_4: 0.9675 - val_loss: 0.4003 - val_auc_4: 0.9204 - 2s/epoch - 11ms/step
# Epoch 64/64
# 183/183 - 2s - loss: 0.2327 - auc_4: 0.9669 - val_loss: 0.3898 - val_auc_4: 0.9101 - 2s/epoch - 10ms/step
# 46/46 [==============================] - 1s 6ms/step
#
# Average Classification Report Across Folds:
# {'accuracy': 0.8513661202185793}
# <ipython-input-8-80e24cbb214d>:52: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_report = pd.DataFrame(all_reports).mean().to_dict()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %% [markdown]
# # Save results

# %%
extractorEmb = Model(inputs=model.inputs,outputs=model.get_layer(name="clsTokenEmb").output)

preds = model.predict(x3,batch_size = config.BATCH_SIZE)

dbresults={}
dbresults['pred_emb'] = extractorEmb.predict(x3,batch_size = config.BATCH_SIZE)
dbresults['pred_cls'] = preds
dbresults['y_cls'] = labels
dbresults['formula'] = df['formula']
dbresults['ids'] = df['ids']
dbresults['types'] = types
dbresults['trainidx'] = train_idx
dbresults['testidx'] = val_idx
dbresults['validx'] = val_idx

with open(mname+'_results.pkl', 'wb') as f:
    pickle.dump(dbresults, f)
# Out:
# 229/229 [==============================] - 2s 7ms/step
# 229/229 [==============================] - 1s 5ms/step

# %% [markdown]
# # Postprocessing

# %%
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn import metrics
import seaborn as sns
tsne = TSNE(n_components=2, verbose=0, random_state=123)
z = tsne.fit_transform(dbresults['pred_emb'])

# %%
dfr = pd.DataFrame()
dfr["y"] = np.asarray(dbresults['y_cls'].argmax(axis=-1)).astype('bool')
dfr["yp"] = np.asarray(dbresults['pred_cls'].argmax(axis=-1)).astype('bool')
dfr["tSNE1"] = z[:,0]
dfr["tSNE2"] = z[:,1]

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
fig, axes = plt.subplots(1, 3, figsize=(15, 4.8))
y_pclasses = dbresults['pred_cls'][dbresults['testidx']].argmax(axis=-1).tolist()
y_classes = dbresults['y_cls'][dbresults['testidx']].argmax(axis=-1)
m = tf.keras.metrics.AUC()
m.update_state(dbresults['y_cls'][dbresults['testidx']], dbresults['pred_cls'][dbresults['testidx']])
print(mname,'binary tf-acc:',tf.keras.metrics.binary_accuracy(y_classes, y_pclasses, threshold=0.5).numpy(),'AUC:',m.result().numpy())
confusion_matrix = metrics.confusion_matrix(y_classes, y_pclasses)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix,
                                            display_labels=['False','True'])
cm_display.plot(ax=axes[0],cmap=plt.cm.Blues)

dfr=dfr.sort_values(by=['y'])
sns.scatterplot(ax=axes[1],x="tSNE1", y="tSNE2", hue=dfr.y.tolist(),data=dfr,alpha=0.4)#.set(title=title+" data T-SNE projection")
axes[1].set_xlabel('$tSNE_1$')
axes[1].set_ylabel('$tSNE_2$',labelpad=1)
axes[1].set_title('Reference')
dfr=dfr.sort_values(by=['yp'])
sns.scatterplot(ax=axes[2],x="tSNE1", y="tSNE2", hue=dfr.yp.tolist(),data=dfr,alpha=0.4)#.set(title=title+" data T-SNE projection")
axes[2].set_title('Predicted')
axes[2].set_xlabel('$tSNE_1$')
axes[2].set_ylabel('$tSNE_2$',labelpad=1)
axes[2].legend('',frameon=False)
fig.tight_layout()
plt.savefig(mname+'_tsne.png',format='png',dpi=800,bbox_inches = "tight")
plt.show()
# Out:
# /content/elementsem/models/elembert_toxic_sr-mmp_V1_E_32_H_2_L_2 binary tf-acc: 0.83811474 AUC: 0.9101162
