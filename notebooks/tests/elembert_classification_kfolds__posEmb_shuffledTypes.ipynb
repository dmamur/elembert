# %% [markdown]
# <a href="https://colab.research.google.com/github/dmamur/elembert/blob/main/notebooks/tests/elembert_classification_kfolds__posEmb_shuffledTypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle,random
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Embedding,Dense,Dropout,Input,Lambda
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
import re, glob,os,sys
from collections import defaultdict
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical

def bert_module(query, key, value, i, config):
    # Multi headed self-attention
    attention_output = layers.MultiHeadAttention(
        num_heads=config.NUM_HEAD,
        key_dim=config.EMBED_DIM // config.NUM_HEAD,
        name="encoder_{}/multiheadattention".format(i),
        kernel_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed)
    )(query, key, value)
    attention_output = layers.Dropout(0.1, name="encoder_{}/att_dropout".format(i))(
        attention_output
    )
    attention_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/att_layernormalization".format(i)
    )(query + attention_output)

    # Feed-forward layer
    ffn = tf.keras.Sequential(
        [
            layers.Dense(config.FF_DIM, activation="relu",kernel_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed)),
            layers.Dense(config.EMBED_DIM,kernel_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed)),
        ],
        name="encoder_{}/ffn".format(i),
    )
    ffn_output = ffn(attention_output)
    ffn_output = layers.Dropout(0.1, name="encoder_{}/ffn_dropout".format(i))(
        ffn_output
    )
    sequence_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/ffn_layernormalization".format(i)
    )(attention_output + ffn_output)
    return sequence_output


def get_pos_encoding_matrix(max_len, d_emb):
    pos_enc = np.array(
        [
            [pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)]
            if pos != 0
            else np.zeros(d_emb)
            for pos in range(max_len)
        ]
    )
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2])  # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2])  # dim 2i+1
    return pos_enc

def create_elembert_model(inputs,config):
    word_embeddings = layers.Embedding(config.VOCAB_SIZE, config.EMBED_DIM, mask_zero=True,name="element_embdgs",
                                       embeddings_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed))(inputs)
    position_embeddings = layers.Embedding(input_dim=config.MAX_LEN,output_dim=config.EMBED_DIM,
                                           weights=[get_pos_encoding_matrix(config.MAX_LEN, config.EMBED_DIM)],
                                           embeddings_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed),
                                           name="position_embedding",)(tf.range(start=0, limit=config.MAX_LEN, delta=1))
    embeddings = word_embeddings #+ position_embeddings
    encoder_output = embeddings
    for i in range(config.NUM_LAYERS):
        encoder_output = bert_module(encoder_output, encoder_output, encoder_output, i, config)
    mlm_model = Model(inputs, encoder_output, name="masked_bert_model")

    return mlm_model

# %%
# !git clone https://github.com/dmamur/elementsem.git
# Out:
# fatal: destination path 'elementsem' already exists and is not an empty directory.

# %%
class Config:
    MAX_LEN = 256
    BATCH_SIZE = 32
    LR = 0.001
    VOCAB_SIZE = 128
    EMBED_DIM = 32
    NUM_HEAD = 2 # used in bert model
    FF_DIM = 32 # used in bert model
    NUM_LAYERS = 2
    MNAME = 'elembert_'
    MVER = 'V1'
    DSPATH="/content/elementsem/data/"
    PREPATH="/content/elementsem/models/pretrained/"
    PATH="/content/elementsem/models/"
config = Config()
seed=12345
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
#'sider_1','sider_2','sider_3','sider_4','sider_5', 'sider_6','sider_7', 'sider_8', 'sider_9', 'sider_10', 'sider_11', 'sider_12',
#'sider_13', 'sider_14', 'sider_15','sider_16','sider_17','sider_18','sider_19','sider_20','sider_21','sider_22','sider_23',
#'sider_24','sider_25','sider_26','sider_27','dimensionality','spacegroup','liquid_amorphous','BBBP','bace','clintox','nr-ahr',
#'nr-ar','sr-atad5','nr-er-lbd','sr-p53','nr-ar-lbd','nr-ppar-gamma','sr-hse','nr-er','sr-mmp','nr-aromatase','sr-are','HIV'
ds = 'toxic_sr-mmp'
mname=config.PATH+config.MNAME+ds+'_%s_E_%s_H_%s_L_%s' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS)

# %% [markdown]
# # Load vocabulary and types

# %%
if (ds=='HIV'):
  df = pd.read_csv(config.DSPATH+ds+config.MVER+'_ds.csv')
else:
  df = pd.read_csv(config.DSPATH+ds+'_ds.csv')

types = df['types'+config.MVER].apply(eval).apply(list)
labels  = to_categorical(np.asarray(df['labels']))
uniquelbls=len(np.unique(np.asarray(df['labels'])))

with open(config.PREPATH+'/el2id'+config.MVER+'.pkl', 'rb') as f:
    db = pickle.load(f)

element2id = db['el2id']
el2id = db['el2id']
config.VOCAB_SIZE = len(element2id)
print('vocabSize: ', config.VOCAB_SIZE)
# Out:
# vocabSize:  565

# %% [markdown]
# # Convert types to integers

# %%
[random.shuffle(types[i]) for i in range(len(types))]
types0=[['[CLS]']+i+['[SEP]'] for i in types]
typesNumerical=[]
for i in types0:
    typesNumerical.append([element2id[j] for j in i])

x3 = tf.keras.preprocessing.sequence.pad_sequences(typesNumerical,dtype='int32',padding= 'post',truncating='post',maxlen=config.MAX_LEN)

#z = load_model(config.PREPATH+'/elembert_%s_E_%s_H_%s_L_%s.h5' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS),compile=False)
#z.trainable = True

inputC = Input((config.MAX_LEN), dtype=tf.int32,name='types')

# %%
epochs=4*config.BATCH_SIZE

print('dataLen: ',x3.shape,labels.shape)
# Out:
# dataLen:  (7320, 256) (7320, 2)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report

# Assuming you have loaded your data into x3 and labels variables

# Define the number of folds
num_folds = 5

# Initialize Stratified K-Fold Cross-Validator
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Initialize lists to store results
all_histories = []
all_reports = []

# Iterate over folds
for fold, (train_idx, val_idx) in enumerate(kfold.split(x3, np.argmax(labels, axis=1))):
    print(f"\nTraining on Fold {fold + 1}...")
    config.seed = np.random.randint(10000,99999,1)[0]
    z = create_elembert_model(inputC,config)
    e = Lambda(lambda x: x[:,0],name='clsTokenEmb')(z.output)
    f = Dense(uniquelbls, activation="softmax",name='out_tox',kernel_initializer=tf.keras.initializers.GlorotUniform(config.seed))(e)
    # Create and compile the model (assuming create_elembert_model function is available)
    model = Model(inputs=z.input, outputs=f)

    optimizer = tf.keras.optimizers.Adam(learning_rate=config.LR)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=[tf.keras.metrics.AUC()])

    # Extract training and validation sets
    x_train, x_val = x3[train_idx], x3[val_idx]
    y_train, y_val = labels[train_idx], labels[val_idx]

    # Train the model
    history = model.fit(
        x=x_train,
        y=y_train,
        validation_data=(x_val, y_val),
        epochs=epochs,
        batch_size=config.BATCH_SIZE,
        verbose=2
    )

    # Evaluate the model on the validation set
    val_predictions = model.predict(x_val, batch_size=config.BATCH_SIZE)
    val_report = classification_report(np.argmax(y_val, axis=1), np.argmax(val_predictions, axis=1), output_dict=True)

    # Append results to lists
    all_histories.append(history)
    all_reports.append(val_report)

# Print the average classification report across folds
avg_report = pd.DataFrame(all_reports).mean().to_dict()
print("\nAverage Classification Report Across Folds:")
print(avg_report)
# Out:
# Training on Fold 1...
# Epoch 1/128
# 183/183 - 26s - loss: 0.4642 - auc: 0.8580 - val_loss: 0.3646 - val_auc: 0.9211 - 26s/epoch - 144ms/step
# Epoch 2/128
# 183/183 - 2s - loss: 0.3683 - auc: 0.9153 - val_loss: 0.3489 - val_auc: 0.9268 - 2s/epoch - 13ms/step
# Epoch 3/128
# 183/183 - 2s - loss: 0.3557 - auc: 0.9211 - val_loss: 0.3363 - val_auc: 0.9320 - 2s/epoch - 10ms/step
# Epoch 4/128
# 183/183 - 2s - loss: 0.3490 - auc: 0.9244 - val_loss: 0.3346 - val_auc: 0.9323 - 2s/epoch - 11ms/step
# Epoch 5/128
# 183/183 - 2s - loss: 0.3432 - auc: 0.9270 - val_loss: 0.3294 - val_auc: 0.9332 - 2s/epoch - 10ms/step
# Epoch 6/128
# 183/183 - 2s - loss: 0.3454 - auc: 0.9258 - val_loss: 0.3351 - val_auc: 0.9318 - 2s/epoch - 11ms/step
# Epoch 7/128
# 183/183 - 2s - loss: 0.3374 - auc: 0.9296 - val_loss: 0.3361 - val_auc: 0.9339 - 2s/epoch - 10ms/step
# Epoch 8/128
# 183/183 - 2s - loss: 0.3340 - auc: 0.9305 - val_loss: 0.3728 - val_auc: 0.9166 - 2s/epoch - 12ms/step
# Epoch 9/128
# 183/183 - 2s - loss: 0.3280 - auc: 0.9333 - val_loss: 0.3180 - val_auc: 0.9381 - 2s/epoch - 10ms/step
# Epoch 10/128
# 183/183 - 2s - loss: 0.3275 - auc: 0.9339 - val_loss: 0.3229 - val_auc: 0.9365 - 2s/epoch - 10ms/step
# Epoch 11/128
# 183/183 - 2s - loss: 0.3235 - auc: 0.9352 - val_loss: 0.3264 - val_auc: 0.9362 - 2s/epoch - 10ms/step
# Epoch 12/128
# 183/183 - 2s - loss: 0.3224 - auc: 0.9358 - val_loss: 0.3397 - val_auc: 0.9350 - 2s/epoch - 10ms/step
# Epoch 13/128
# 183/183 - 2s - loss: 0.3208 - auc: 0.9364 - val_loss: 0.3193 - val_auc: 0.9374 - 2s/epoch - 10ms/step
# Epoch 14/128
# 183/183 - 2s - loss: 0.3143 - auc: 0.9392 - val_loss: 0.3272 - val_auc: 0.9354 - 2s/epoch - 12ms/step
# Epoch 15/128
# 183/183 - 2s - loss: 0.3161 - auc: 0.9385 - val_loss: 0.3220 - val_auc: 0.9367 - 2s/epoch - 10ms/step
# Epoch 16/128
# 183/183 - 2s - loss: 0.3092 - auc: 0.9410 - val_loss: 0.3223 - val_auc: 0.9367 - 2s/epoch - 10ms/step
# Epoch 17/128
# 183/183 - 2s - loss: 0.3109 - auc: 0.9404 - val_loss: 0.3222 - val_auc: 0.9373 - 2s/epoch - 10ms/step
# Epoch 18/128
# 183/183 - 2s - loss: 0.3051 - auc: 0.9425 - val_loss: 0.3197 - val_auc: 0.9375 - 2s/epoch - 10ms/step
# Epoch 19/128
# 183/183 - 2s - loss: 0.3096 - auc: 0.9409 - val_loss: 0.3166 - val_auc: 0.9391 - 2s/epoch - 10ms/step
# Epoch 20/128
# 183/183 - 2s - loss: 0.3080 - auc: 0.9417 - val_loss: 0.3258 - val_auc: 0.9378 - 2s/epoch - 12ms/step
# Epoch 21/128
# 183/183 - 2s - loss: 0.3029 - auc: 0.9433 - val_loss: 0.3433 - val_auc: 0.9357 - 2s/epoch - 10ms/step
# Epoch 22/128
# 183/183 - 2s - loss: 0.3055 - auc: 0.9425 - val_loss: 0.3256 - val_auc: 0.9367 - 2s/epoch - 10ms/step
# Epoch 23/128
# 183/183 - 2s - loss: 0.3050 - auc: 0.9426 - val_loss: 0.3298 - val_auc: 0.9389 - 2s/epoch - 10ms/step
# Epoch 24/128
# 183/183 - 2s - loss: 0.3020 - auc: 0.9438 - val_loss: 0.3204 - val_auc: 0.9388 - 2s/epoch - 10ms/step
# Epoch 25/128
# 183/183 - 2s - loss: 0.3022 - auc: 0.9436 - val_loss: 0.3197 - val_auc: 0.9377 - 2s/epoch - 10ms/step
# Epoch 26/128
# 183/183 - 2s - loss: 0.2980 - auc: 0.9452 - val_loss: 0.3217 - val_auc: 0.9379 - 2s/epoch - 11ms/step
# Epoch 27/128
# 183/183 - 2s - loss: 0.2973 - auc: 0.9457 - val_loss: 0.3286 - val_auc: 0.9347 - 2s/epoch - 11ms/step
# Epoch 28/128
# 183/183 - 2s - loss: 0.2972 - auc: 0.9453 - val_loss: 0.3224 - val_auc: 0.9382 - 2s/epoch - 11ms/step
# Epoch 29/128
# 183/183 - 2s - loss: 0.2910 - auc: 0.9480 - val_loss: 0.3203 - val_auc: 0.9377 - 2s/epoch - 10ms/step
# Epoch 30/128
# 183/183 - 2s - loss: 0.2913 - auc: 0.9477 - val_loss: 0.3171 - val_auc: 0.9395 - 2s/epoch - 10ms/step
# Epoch 31/128
# 183/183 - 2s - loss: 0.2896 - auc: 0.9485 - val_loss: 0.3153 - val_auc: 0.9395 - 2s/epoch - 10ms/step
# Epoch 32/128
# 183/183 - 2s - loss: 0.2857 - auc: 0.9500 - val_loss: 0.3243 - val_auc: 0.9393 - 2s/epoch - 13ms/step
# Epoch 33/128
# 183/183 - 2s - loss: 0.2884 - auc: 0.9487 - val_loss: 0.3143 - val_auc: 0.9410 - 2s/epoch - 10ms/step
# Epoch 34/128
# 183/183 - 2s - loss: 0.2835 - auc: 0.9506 - val_loss: 0.3169 - val_auc: 0.9388 - 2s/epoch - 10ms/step
# Epoch 35/128
# 183/183 - 2s - loss: 0.2846 - auc: 0.9503 - val_loss: 0.3173 - val_auc: 0.9393 - 2s/epoch - 10ms/step
# Epoch 36/128
# 183/183 - 2s - loss: 0.2812 - auc: 0.9516 - val_loss: 0.3139 - val_auc: 0.9398 - 2s/epoch - 10ms/step
# Epoch 37/128
# 183/183 - 2s - loss: 0.2821 - auc: 0.9512 - val_loss: 0.3262 - val_auc: 0.9410 - 2s/epoch - 10ms/step
# Epoch 38/128
# 183/183 - 2s - loss: 0.2816 - auc: 0.9514 - val_loss: 0.3114 - val_auc: 0.9408 - 2s/epoch - 13ms/step
# Epoch 39/128
# 183/183 - 2s - loss: 0.2767 - auc: 0.9531 - val_loss: 0.3160 - val_auc: 0.9397 - 2s/epoch - 11ms/step
# Epoch 40/128
# 183/183 - 2s - loss: 0.2782 - auc: 0.9527 - val_loss: 0.3087 - val_auc: 0.9422 - 2s/epoch - 10ms/step
# Epoch 41/128
# 183/183 - 2s - loss: 0.2780 - auc: 0.9527 - val_loss: 0.3044 - val_auc: 0.9440 - 2s/epoch - 10ms/step
# Epoch 42/128
# 183/183 - 2s - loss: 0.2808 - auc: 0.9516 - val_loss: 0.3065 - val_auc: 0.9444 - 2s/epoch - 10ms/step
# Epoch 43/128
# 183/183 - 2s - loss: 0.2672 - auc: 0.9564 - val_loss: 0.3063 - val_auc: 0.9429 - 2s/epoch - 10ms/step
# Epoch 44/128
# 183/183 - 2s - loss: 0.2702 - auc: 0.9555 - val_loss: 0.3236 - val_auc: 0.9398 - 2s/epoch - 12ms/step
# Epoch 45/128
# 183/183 - 2s - loss: 0.2741 - auc: 0.9541 - val_loss: 0.3179 - val_auc: 0.9391 - 2s/epoch - 11ms/step
# Epoch 46/128
# 183/183 - 2s - loss: 0.2702 - auc: 0.9552 - val_loss: 0.3207 - val_auc: 0.9441 - 2s/epoch - 10ms/step
# Epoch 47/128
# 183/183 - 2s - loss: 0.2665 - auc: 0.9566 - val_loss: 0.3076 - val_auc: 0.9441 - 2s/epoch - 10ms/step
# Epoch 48/128
# 183/183 - 2s - loss: 0.2642 - auc: 0.9574 - val_loss: 0.3142 - val_auc: 0.9425 - 2s/epoch - 10ms/step
# Epoch 49/128
# 183/183 - 2s - loss: 0.2635 - auc: 0.9577 - val_loss: 0.3128 - val_auc: 0.9413 - 2s/epoch - 10ms/step
# Epoch 50/128
# 183/183 - 2s - loss: 0.2612 - auc: 0.9585 - val_loss: 0.3169 - val_auc: 0.9405 - 2s/epoch - 13ms/step
# Epoch 51/128
# 183/183 - 3s - loss: 0.2625 - auc: 0.9580 - val_loss: 0.2990 - val_auc: 0.9456 - 3s/epoch - 14ms/step
# Epoch 52/128
# 183/183 - 2s - loss: 0.2685 - auc: 0.9560 - val_loss: 0.3065 - val_auc: 0.9440 - 2s/epoch - 12ms/step
# Epoch 53/128
# 183/183 - 2s - loss: 0.2617 - auc: 0.9582 - val_loss: 0.3080 - val_auc: 0.9433 - 2s/epoch - 10ms/step
# Epoch 54/128
# 183/183 - 2s - loss: 0.2615 - auc: 0.9582 - val_loss: 0.3203 - val_auc: 0.9441 - 2s/epoch - 10ms/step
# Epoch 55/128
# 183/183 - 2s - loss: 0.2650 - auc: 0.9572 - val_loss: 0.3013 - val_auc: 0.9461 - 2s/epoch - 10ms/step
# Epoch 56/128
# 183/183 - 2s - loss: 0.2573 - auc: 0.9597 - val_loss: 0.3147 - val_auc: 0.9427 - 2s/epoch - 12ms/step
# Epoch 57/128
# 183/183 - 2s - loss: 0.2533 - auc: 0.9608 - val_loss: 0.3044 - val_auc: 0.9445 - 2s/epoch - 10ms/step
# Epoch 58/128
# 183/183 - 2s - loss: 0.2547 - auc: 0.9604 - val_loss: 0.3126 - val_auc: 0.9447 - 2s/epoch - 10ms/step
# Epoch 59/128
# 183/183 - 2s - loss: 0.2600 - auc: 0.9587 - val_loss: 0.3161 - val_auc: 0.9414 - 2s/epoch - 10ms/step
# Epoch 60/128
# 183/183 - 2s - loss: 0.2556 - auc: 0.9601 - val_loss: 0.3155 - val_auc: 0.9445 - 2s/epoch - 10ms/step
# Epoch 61/128
# 183/183 - 2s - loss: 0.2529 - auc: 0.9609 - val_loss: 0.3143 - val_auc: 0.9409 - 2s/epoch - 10ms/step
# Epoch 62/128
# 183/183 - 2s - loss: 0.2551 - auc: 0.9602 - val_loss: 0.3073 - val_auc: 0.9444 - 2s/epoch - 12ms/step
# Epoch 63/128
# 183/183 - 2s - loss: 0.2479 - auc: 0.9626 - val_loss: 0.3143 - val_auc: 0.9430 - 2s/epoch - 10ms/step
# Epoch 64/128
# 183/183 - 2s - loss: 0.2511 - auc: 0.9615 - val_loss: 0.3267 - val_auc: 0.9388 - 2s/epoch - 10ms/step
# Epoch 65/128
# 183/183 - 2s - loss: 0.2547 - auc: 0.9604 - val_loss: 0.3039 - val_auc: 0.9460 - 2s/epoch - 11ms/step
# Epoch 66/128
# 183/183 - 2s - loss: 0.2481 - auc: 0.9626 - val_loss: 0.3196 - val_auc: 0.9381 - 2s/epoch - 10ms/step
# Epoch 67/128
# 183/183 - 2s - loss: 0.2454 - auc: 0.9633 - val_loss: 0.3165 - val_auc: 0.9418 - 2s/epoch - 10ms/step
# Epoch 68/128
# 183/183 - 2s - loss: 0.2490 - auc: 0.9622 - val_loss: 0.3062 - val_auc: 0.9458 - 2s/epoch - 12ms/step
# Epoch 69/128
# 183/183 - 2s - loss: 0.2451 - auc: 0.9635 - val_loss: 0.3292 - val_auc: 0.9379 - 2s/epoch - 10ms/step
# Epoch 70/128
# 183/183 - 2s - loss: 0.2460 - auc: 0.9632 - val_loss: 0.3110 - val_auc: 0.9420 - 2s/epoch - 10ms/step
# Epoch 71/128
# 183/183 - 2s - loss: 0.2436 - auc: 0.9638 - val_loss: 0.3095 - val_auc: 0.9461 - 2s/epoch - 10ms/step
# Epoch 72/128
# 183/183 - 2s - loss: 0.2458 - auc: 0.9632 - val_loss: 0.3107 - val_auc: 0.9455 - 2s/epoch - 10ms/step
# Epoch 73/128
# 183/183 - 2s - loss: 0.2375 - auc: 0.9655 - val_loss: 0.3120 - val_auc: 0.9441 - 2s/epoch - 10ms/step
# Epoch 74/128
# 183/183 - 2s - loss: 0.2410 - auc: 0.9646 - val_loss: 0.3154 - val_auc: 0.9437 - 2s/epoch - 12ms/step
# Epoch 75/128
# 183/183 - 2s - loss: 0.2368 - auc: 0.9658 - val_loss: 0.3084 - val_auc: 0.9468 - 2s/epoch - 10ms/step
# Epoch 76/128
# 183/183 - 2s - loss: 0.2422 - auc: 0.9643 - val_loss: 0.3059 - val_auc: 0.9437 - 2s/epoch - 10ms/step
# Epoch 77/128
# 183/183 - 2s - loss: 0.2365 - auc: 0.9658 - val_loss: 0.3092 - val_auc: 0.9453 - 2s/epoch - 11ms/step
# Epoch 78/128
# 183/183 - 2s - loss: 0.2417 - auc: 0.9644 - val_loss: 0.3281 - val_auc: 0.9411 - 2s/epoch - 10ms/step
# Epoch 79/128
# 183/183 - 2s - loss: 0.2340 - auc: 0.9665 - val_loss: 0.3279 - val_auc: 0.9433 - 2s/epoch - 10ms/step
# Epoch 80/128
# 183/183 - 2s - loss: 0.2352 - auc: 0.9663 - val_loss: 0.3082 - val_auc: 0.9462 - 2s/epoch - 12ms/step
# Epoch 81/128
# 183/183 - 2s - loss: 0.2337 - auc: 0.9666 - val_loss: 0.2953 - val_auc: 0.9486 - 2s/epoch - 10ms/step
# Epoch 82/128
# 183/183 - 2s - loss: 0.2310 - auc: 0.9675 - val_loss: 0.3055 - val_auc: 0.9467 - 2s/epoch - 10ms/step
# Epoch 83/128
# 183/183 - 2s - loss: 0.2335 - auc: 0.9665 - val_loss: 0.3160 - val_auc: 0.9433 - 2s/epoch - 10ms/step
# Epoch 84/128
# 183/183 - 2s - loss: 0.2357 - auc: 0.9663 - val_loss: 0.3097 - val_auc: 0.9417 - 2s/epoch - 10ms/step
# Epoch 85/128
# 183/183 - 2s - loss: 0.2295 - auc: 0.9680 - val_loss: 0.3113 - val_auc: 0.9454 - 2s/epoch - 10ms/step
# Epoch 86/128
# 183/183 - 2s - loss: 0.2250 - auc: 0.9692 - val_loss: 0.3195 - val_auc: 0.9408 - 2s/epoch - 12ms/step
# Epoch 87/128
# 183/183 - 2s - loss: 0.2379 - auc: 0.9654 - val_loss: 0.3058 - val_auc: 0.9464 - 2s/epoch - 10ms/step
# Epoch 88/128
# 183/183 - 2s - loss: 0.2298 - auc: 0.9678 - val_loss: 0.3157 - val_auc: 0.9458 - 2s/epoch - 10ms/step
# Epoch 89/128
# 183/183 - 2s - loss: 0.2324 - auc: 0.9671 - val_loss: 0.3125 - val_auc: 0.9446 - 2s/epoch - 10ms/step
# Epoch 90/128
# 183/183 - 2s - loss: 0.2276 - auc: 0.9684 - val_loss: 0.3218 - val_auc: 0.9426 - 2s/epoch - 10ms/step
# Epoch 91/128
# 183/183 - 2s - loss: 0.2253 - auc: 0.9689 - val_loss: 0.3093 - val_auc: 0.9442 - 2s/epoch - 10ms/step
# Epoch 92/128
# 183/183 - 2s - loss: 0.2278 - auc: 0.9683 - val_loss: 0.3304 - val_auc: 0.9408 - 2s/epoch - 12ms/step
# Epoch 93/128
# 183/183 - 2s - loss: 0.2248 - auc: 0.9692 - val_loss: 0.3193 - val_auc: 0.9456 - 2s/epoch - 10ms/step
# Epoch 94/128
# 183/183 - 2s - loss: 0.2241 - auc: 0.9694 - val_loss: 0.3060 - val_auc: 0.9454 - 2s/epoch - 10ms/step
# Epoch 95/128
# 183/183 - 2s - loss: 0.2172 - auc: 0.9712 - val_loss: 0.3224 - val_auc: 0.9427 - 2s/epoch - 10ms/step
# Epoch 96/128
# 183/183 - 2s - loss: 0.2199 - auc: 0.9706 - val_loss: 0.3241 - val_auc: 0.9435 - 2s/epoch - 10ms/step
# Epoch 97/128
# 183/183 - 2s - loss: 0.2224 - auc: 0.9698 - val_loss: 0.3246 - val_auc: 0.9450 - 2s/epoch - 10ms/step
# Epoch 98/128
# 183/183 - 2s - loss: 0.2258 - auc: 0.9690 - val_loss: 0.3163 - val_auc: 0.9457 - 2s/epoch - 12ms/step
# Epoch 99/128
# 183/183 - 2s - loss: 0.2214 - auc: 0.9701 - val_loss: 0.3847 - val_auc: 0.9186 - 2s/epoch - 10ms/step
# Epoch 100/128
# 183/183 - 2s - loss: 0.2294 - auc: 0.9677 - val_loss: 0.3093 - val_auc: 0.9471 - 2s/epoch - 10ms/step
# Epoch 101/128
# 183/183 - 2s - loss: 0.2184 - auc: 0.9709 - val_loss: 0.3181 - val_auc: 0.9433 - 2s/epoch - 10ms/step
# Epoch 102/128
# 183/183 - 2s - loss: 0.2146 - auc: 0.9719 - val_loss: 0.3152 - val_auc: 0.9456 - 2s/epoch - 10ms/step
# Epoch 103/128
# 183/183 - 2s - loss: 0.2155 - auc: 0.9716 - val_loss: 0.3321 - val_auc: 0.9404 - 2s/epoch - 10ms/step
# Epoch 104/128
# 183/183 - 2s - loss: 0.2112 - auc: 0.9728 - val_loss: 0.3344 - val_auc: 0.9384 - 2s/epoch - 14ms/step
# Epoch 105/128
# 183/183 - 2s - loss: 0.2180 - auc: 0.9710 - val_loss: 0.3299 - val_auc: 0.9402 - 2s/epoch - 10ms/step
# Epoch 106/128
# 183/183 - 2s - loss: 0.2169 - auc: 0.9713 - val_loss: 0.3292 - val_auc: 0.9415 - 2s/epoch - 10ms/step
# Epoch 107/128
# 183/183 - 2s - loss: 0.2085 - auc: 0.9734 - val_loss: 0.3309 - val_auc: 0.9427 - 2s/epoch - 10ms/step
# Epoch 108/128
# 183/183 - 2s - loss: 0.2114 - auc: 0.9727 - val_loss: 0.3526 - val_auc: 0.9396 - 2s/epoch - 10ms/step
# Epoch 109/128
# 183/183 - 2s - loss: 0.2105 - auc: 0.9728 - val_loss: 0.3226 - val_auc: 0.9457 - 2s/epoch - 10ms/step
# Epoch 110/128
# 183/183 - 3s - loss: 0.2153 - auc: 0.9717 - val_loss: 0.3145 - val_auc: 0.9445 - 3s/epoch - 14ms/step
# Epoch 111/128
# 183/183 - 2s - loss: 0.2160 - auc: 0.9714 - val_loss: 0.3255 - val_auc: 0.9452 - 2s/epoch - 10ms/step
# Epoch 112/128
# 183/183 - 2s - loss: 0.2106 - auc: 0.9726 - val_loss: 0.3216 - val_auc: 0.9435 - 2s/epoch - 10ms/step
# Epoch 113/128
# 183/183 - 2s - loss: 0.2146 - auc: 0.9718 - val_loss: 0.3273 - val_auc: 0.9427 - 2s/epoch - 10ms/step
# Epoch 114/128
# 183/183 - 2s - loss: 0.2104 - auc: 0.9729 - val_loss: 0.3637 - val_auc: 0.9432 - 2s/epoch - 10ms/step
# Epoch 115/128
# 183/183 - 2s - loss: 0.2212 - auc: 0.9700 - val_loss: 0.3316 - val_auc: 0.9423 - 2s/epoch - 10ms/step
# Epoch 116/128
# 183/183 - 2s - loss: 0.2079 - auc: 0.9735 - val_loss: 0.3361 - val_auc: 0.9407 - 2s/epoch - 12ms/step
# Epoch 117/128
# 183/183 - 2s - loss: 0.2074 - auc: 0.9738 - val_loss: 0.3294 - val_auc: 0.9419 - 2s/epoch - 10ms/step
# Epoch 118/128
# 183/183 - 2s - loss: 0.2089 - auc: 0.9734 - val_loss: 0.3480 - val_auc: 0.9388 - 2s/epoch - 10ms/step
# Epoch 119/128
# 183/183 - 2s - loss: 0.2110 - auc: 0.9729 - val_loss: 0.3404 - val_auc: 0.9402 - 2s/epoch - 10ms/step
# Epoch 120/128
# 183/183 - 2s - loss: 0.2088 - auc: 0.9733 - val_loss: 0.3208 - val_auc: 0.9427 - 2s/epoch - 10ms/step
# Epoch 121/128
# 183/183 - 2s - loss: 0.2025 - auc: 0.9749 - val_loss: 0.3504 - val_auc: 0.9412 - 2s/epoch - 10ms/step
# Epoch 122/128
# 183/183 - 3s - loss: 0.2029 - auc: 0.9749 - val_loss: 0.3653 - val_auc: 0.9383 - 3s/epoch - 14ms/step
# Epoch 123/128
# 183/183 - 2s - loss: 0.2162 - auc: 0.9715 - val_loss: 0.3239 - val_auc: 0.9439 - 2s/epoch - 10ms/step
# Epoch 124/128
# 183/183 - 2s - loss: 0.2056 - auc: 0.9742 - val_loss: 0.3288 - val_auc: 0.9433 - 2s/epoch - 10ms/step
# Epoch 125/128
# 183/183 - 2s - loss: 0.2026 - auc: 0.9750 - val_loss: 0.3559 - val_auc: 0.9390 - 2s/epoch - 10ms/step
# Epoch 126/128
# 183/183 - 2s - loss: 0.2016 - auc: 0.9749 - val_loss: 0.3410 - val_auc: 0.9346 - 2s/epoch - 10ms/step
# Epoch 127/128
# 183/183 - 2s - loss: 0.2041 - auc: 0.9745 - val_loss: 0.3298 - val_auc: 0.9422 - 2s/epoch - 10ms/step
# Epoch 128/128
# 183/183 - 3s - loss: 0.2011 - auc: 0.9753 - val_loss: 0.3513 - val_auc: 0.9369 - 3s/epoch - 14ms/step
# 46/46 [==============================] - 1s 6ms/step
#
# Training on Fold 2...
# Epoch 1/128
# 183/183 - 8s - loss: 0.4498 - auc_1: 0.8661 - val_loss: 0.3705 - val_auc_1: 0.9208 - 8s/epoch - 44ms/step
# Epoch 2/128
# 183/183 - 2s - loss: 0.3736 - auc_1: 0.9118 - val_loss: 0.3519 - val_auc_1: 0.9276 - 2s/epoch - 13ms/step
# Epoch 3/128
# 183/183 - 2s - loss: 0.3600 - auc_1: 0.9189 - val_loss: 0.3410 - val_auc_1: 0.9323 - 2s/epoch - 11ms/step
# Epoch 4/128
# 183/183 - 2s - loss: 0.3506 - auc_1: 0.9238 - val_loss: 0.3700 - val_auc_1: 0.9307 - 2s/epoch - 10ms/step
# Epoch 5/128
# 183/183 - 2s - loss: 0.3519 - auc_1: 0.9228 - val_loss: 0.3279 - val_auc_1: 0.9357 - 2s/epoch - 10ms/step
# Epoch 6/128
# 183/183 - 2s - loss: 0.3506 - auc_1: 0.9237 - val_loss: 0.3255 - val_auc_1: 0.9357 - 2s/epoch - 10ms/step
# Epoch 7/128
# 183/183 - 2s - loss: 0.3364 - auc_1: 0.9295 - val_loss: 0.3377 - val_auc_1: 0.9371 - 2s/epoch - 10ms/step
# Epoch 8/128
# 183/183 - 2s - loss: 0.3390 - auc_1: 0.9285 - val_loss: 0.3316 - val_auc_1: 0.9364 - 2s/epoch - 12ms/step
# Epoch 9/128
# 183/183 - 2s - loss: 0.3283 - auc_1: 0.9327 - val_loss: 0.3126 - val_auc_1: 0.9405 - 2s/epoch - 10ms/step
# Epoch 10/128
# 183/183 - 2s - loss: 0.3306 - auc_1: 0.9322 - val_loss: 0.3114 - val_auc_1: 0.9416 - 2s/epoch - 10ms/step
# Epoch 11/128
# 183/183 - 2s - loss: 0.3249 - auc_1: 0.9344 - val_loss: 0.3148 - val_auc_1: 0.9402 - 2s/epoch - 10ms/step
# Epoch 12/128
# 183/183 - 2s - loss: 0.3201 - auc_1: 0.9364 - val_loss: 0.3170 - val_auc_1: 0.9375 - 2s/epoch - 10ms/step
# Epoch 13/128
# 183/183 - 2s - loss: 0.3183 - auc_1: 0.9369 - val_loss: 0.3283 - val_auc_1: 0.9349 - 2s/epoch - 10ms/step
# Epoch 14/128
# 183/183 - 2s - loss: 0.3153 - auc_1: 0.9386 - val_loss: 0.3139 - val_auc_1: 0.9390 - 2s/epoch - 12ms/step
# Epoch 15/128
# 183/183 - 2s - loss: 0.3127 - auc_1: 0.9393 - val_loss: 0.3087 - val_auc_1: 0.9416 - 2s/epoch - 10ms/step
# Epoch 16/128
# 183/183 - 2s - loss: 0.3124 - auc_1: 0.9402 - val_loss: 0.3191 - val_auc_1: 0.9364 - 2s/epoch - 10ms/step
# Epoch 17/128
# 183/183 - 2s - loss: 0.3087 - auc_1: 0.9413 - val_loss: 0.3095 - val_auc_1: 0.9430 - 2s/epoch - 10ms/step
# Epoch 18/128
# 183/183 - 2s - loss: 0.3059 - auc_1: 0.9423 - val_loss: 0.2997 - val_auc_1: 0.9458 - 2s/epoch - 10ms/step
# Epoch 19/128
# 183/183 - 2s - loss: 0.3042 - auc_1: 0.9428 - val_loss: 0.3047 - val_auc_1: 0.9435 - 2s/epoch - 10ms/step
# Epoch 20/128
# 183/183 - 2s - loss: 0.2998 - auc_1: 0.9445 - val_loss: 0.3025 - val_auc_1: 0.9437 - 2s/epoch - 12ms/step
# Epoch 21/128
# 183/183 - 2s - loss: 0.2949 - auc_1: 0.9466 - val_loss: 0.3091 - val_auc_1: 0.9442 - 2s/epoch - 10ms/step
# Epoch 22/128
# 183/183 - 2s - loss: 0.2962 - auc_1: 0.9460 - val_loss: 0.3077 - val_auc_1: 0.9460 - 2s/epoch - 10ms/step
# Epoch 23/128
# 183/183 - 2s - loss: 0.2901 - auc_1: 0.9482 - val_loss: 0.3156 - val_auc_1: 0.9388 - 2s/epoch - 10ms/step
# Epoch 24/128
# 183/183 - 2s - loss: 0.2895 - auc_1: 0.9484 - val_loss: 0.2994 - val_auc_1: 0.9467 - 2s/epoch - 10ms/step
# Epoch 25/128
# 183/183 - 2s - loss: 0.2877 - auc_1: 0.9489 - val_loss: 0.2920 - val_auc_1: 0.9490 - 2s/epoch - 10ms/step
# Epoch 26/128
# 183/183 - 2s - loss: 0.2865 - auc_1: 0.9496 - val_loss: 0.3078 - val_auc_1: 0.9466 - 2s/epoch - 12ms/step
# Epoch 27/128
# 183/183 - 2s - loss: 0.2845 - auc_1: 0.9502 - val_loss: 0.2952 - val_auc_1: 0.9487 - 2s/epoch - 11ms/step
# Epoch 28/128
# 183/183 - 2s - loss: 0.2822 - auc_1: 0.9509 - val_loss: 0.3171 - val_auc_1: 0.9386 - 2s/epoch - 11ms/step
# Epoch 29/128
# 183/183 - 2s - loss: 0.2772 - auc_1: 0.9526 - val_loss: 0.2949 - val_auc_1: 0.9472 - 2s/epoch - 10ms/step
# Epoch 30/128
# 183/183 - 2s - loss: 0.2772 - auc_1: 0.9527 - val_loss: 0.2872 - val_auc_1: 0.9508 - 2s/epoch - 10ms/step
# Epoch 31/128
# 183/183 - 2s - loss: 0.2709 - auc_1: 0.9549 - val_loss: 0.3112 - val_auc_1: 0.9420 - 2s/epoch - 10ms/step
# Epoch 32/128
# 183/183 - 2s - loss: 0.2720 - auc_1: 0.9543 - val_loss: 0.3107 - val_auc_1: 0.9440 - 2s/epoch - 12ms/step
# Epoch 33/128
# 183/183 - 2s - loss: 0.2719 - auc_1: 0.9545 - val_loss: 0.3052 - val_auc_1: 0.9434 - 2s/epoch - 10ms/step
# Epoch 34/128
# 183/183 - 2s - loss: 0.2716 - auc_1: 0.9547 - val_loss: 0.2936 - val_auc_1: 0.9505 - 2s/epoch - 10ms/step
# Epoch 35/128
# 183/183 - 2s - loss: 0.2709 - auc_1: 0.9549 - val_loss: 0.3067 - val_auc_1: 0.9436 - 2s/epoch - 10ms/step
# Epoch 36/128
# 183/183 - 2s - loss: 0.2694 - auc_1: 0.9548 - val_loss: 0.3035 - val_auc_1: 0.9452 - 2s/epoch - 10ms/step
# Epoch 37/128
# 183/183 - 3s - loss: 0.2671 - auc_1: 0.9559 - val_loss: 0.3000 - val_auc_1: 0.9452 - 3s/epoch - 18ms/step
# Epoch 38/128
# 183/183 - 3s - loss: 0.2639 - auc_1: 0.9572 - val_loss: 0.2903 - val_auc_1: 0.9486 - 3s/epoch - 19ms/step
# Epoch 39/128
# 183/183 - 3s - loss: 0.2633 - auc_1: 0.9572 - val_loss: 0.2940 - val_auc_1: 0.9478 - 3s/epoch - 16ms/step
# Epoch 40/128
# 183/183 - 2s - loss: 0.2632 - auc_1: 0.9573 - val_loss: 0.2807 - val_auc_1: 0.9526 - 2s/epoch - 10ms/step
# Epoch 41/128
# 183/183 - 2s - loss: 0.2641 - auc_1: 0.9569 - val_loss: 0.3164 - val_auc_1: 0.9386 - 2s/epoch - 10ms/step
# Epoch 42/128
# 183/183 - 2s - loss: 0.2641 - auc_1: 0.9568 - val_loss: 0.3049 - val_auc_1: 0.9433 - 2s/epoch - 11ms/step
# Epoch 43/128
# 183/183 - 2s - loss: 0.2616 - auc_1: 0.9580 - val_loss: 0.3185 - val_auc_1: 0.9409 - 2s/epoch - 12ms/step
# Epoch 44/128
# 183/183 - 2s - loss: 0.2604 - auc_1: 0.9582 - val_loss: 0.3256 - val_auc_1: 0.9404 - 2s/epoch - 10ms/step
# Epoch 45/128
# 183/183 - 2s - loss: 0.2563 - auc_1: 0.9594 - val_loss: 0.2972 - val_auc_1: 0.9459 - 2s/epoch - 10ms/step
# Epoch 46/128
# 183/183 - 2s - loss: 0.2561 - auc_1: 0.9594 - val_loss: 0.2975 - val_auc_1: 0.9471 - 2s/epoch - 10ms/step
# Epoch 47/128
# 183/183 - 2s - loss: 0.2519 - auc_1: 0.9607 - val_loss: 0.2977 - val_auc_1: 0.9456 - 2s/epoch - 10ms/step
# Epoch 48/128
# 183/183 - 2s - loss: 0.2576 - auc_1: 0.9590 - val_loss: 0.3037 - val_auc_1: 0.9462 - 2s/epoch - 10ms/step
# Epoch 49/128
# 183/183 - 2s - loss: 0.2540 - auc_1: 0.9603 - val_loss: 0.3034 - val_auc_1: 0.9447 - 2s/epoch - 12ms/step
# Epoch 50/128
# 183/183 - 2s - loss: 0.2586 - auc_1: 0.9587 - val_loss: 0.3120 - val_auc_1: 0.9407 - 2s/epoch - 10ms/step
# Epoch 51/128
# 183/183 - 4s - loss: 0.2556 - auc_1: 0.9595 - val_loss: 0.2913 - val_auc_1: 0.9484 - 4s/epoch - 20ms/step
# Epoch 52/128
# 183/183 - 4s - loss: 0.2500 - auc_1: 0.9616 - val_loss: 0.2944 - val_auc_1: 0.9485 - 4s/epoch - 23ms/step
# Epoch 53/128
# 183/183 - 5s - loss: 0.2495 - auc_1: 0.9618 - val_loss: 0.2849 - val_auc_1: 0.9516 - 5s/epoch - 26ms/step
# Epoch 54/128
# 183/183 - 4s - loss: 0.2517 - auc_1: 0.9612 - val_loss: 0.3025 - val_auc_1: 0.9464 - 4s/epoch - 20ms/step
# Epoch 55/128
# 183/183 - 3s - loss: 0.2491 - auc_1: 0.9616 - val_loss: 0.3020 - val_auc_1: 0.9480 - 3s/epoch - 16ms/step
# Epoch 56/128
# 183/183 - 4s - loss: 0.2526 - auc_1: 0.9604 - val_loss: 0.2927 - val_auc_1: 0.9486 - 4s/epoch - 20ms/step
# Epoch 57/128
# 183/183 - 3s - loss: 0.2486 - auc_1: 0.9619 - val_loss: 0.3016 - val_auc_1: 0.9475 - 3s/epoch - 16ms/step
# Epoch 58/128
# 183/183 - 2s - loss: 0.2458 - auc_1: 0.9628 - val_loss: 0.3026 - val_auc_1: 0.9474 - 2s/epoch - 13ms/step
# Epoch 59/128
# 183/183 - 2s - loss: 0.2504 - auc_1: 0.9612 - val_loss: 0.2982 - val_auc_1: 0.9465 - 2s/epoch - 10ms/step
# Epoch 60/128
# 183/183 - 2s - loss: 0.2413 - auc_1: 0.9641 - val_loss: 0.2934 - val_auc_1: 0.9477 - 2s/epoch - 13ms/step
# Epoch 61/128
# 183/183 - 2s - loss: 0.2523 - auc_1: 0.9609 - val_loss: 0.2892 - val_auc_1: 0.9494 - 2s/epoch - 11ms/step
# Epoch 62/128
# 183/183 - 2s - loss: 0.2414 - auc_1: 0.9637 - val_loss: 0.2920 - val_auc_1: 0.9496 - 2s/epoch - 10ms/step
# Epoch 63/128
# 183/183 - 2s - loss: 0.2397 - auc_1: 0.9646 - val_loss: 0.2879 - val_auc_1: 0.9495 - 2s/epoch - 10ms/step
# Epoch 64/128
# 183/183 - 2s - loss: 0.2383 - auc_1: 0.9650 - val_loss: 0.3108 - val_auc_1: 0.9434 - 2s/epoch - 10ms/step
# Epoch 65/128
# 183/183 - 2s - loss: 0.2410 - auc_1: 0.9641 - val_loss: 0.2991 - val_auc_1: 0.9496 - 2s/epoch - 10ms/step
# Epoch 66/128
# 183/183 - 2s - loss: 0.2386 - auc_1: 0.9650 - val_loss: 0.3066 - val_auc_1: 0.9472 - 2s/epoch - 13ms/step
# Epoch 67/128
# 183/183 - 2s - loss: 0.2378 - auc_1: 0.9650 - val_loss: 0.2893 - val_auc_1: 0.9515 - 2s/epoch - 11ms/step
# Epoch 68/128
# 183/183 - 2s - loss: 0.2360 - auc_1: 0.9653 - val_loss: 0.2997 - val_auc_1: 0.9466 - 2s/epoch - 10ms/step
# Epoch 69/128
# 183/183 - 2s - loss: 0.2415 - auc_1: 0.9642 - val_loss: 0.2916 - val_auc_1: 0.9487 - 2s/epoch - 10ms/step
# Epoch 70/128
# 183/183 - 2s - loss: 0.2368 - auc_1: 0.9655 - val_loss: 0.2812 - val_auc_1: 0.9540 - 2s/epoch - 10ms/step
# Epoch 71/128
# 183/183 - 2s - loss: 0.2346 - auc_1: 0.9657 - val_loss: 0.3048 - val_auc_1: 0.9479 - 2s/epoch - 10ms/step
# Epoch 72/128
# 183/183 - 2s - loss: 0.2381 - auc_1: 0.9647 - val_loss: 0.2911 - val_auc_1: 0.9494 - 2s/epoch - 12ms/step
# Epoch 73/128
# 183/183 - 2s - loss: 0.2383 - auc_1: 0.9650 - val_loss: 0.2991 - val_auc_1: 0.9479 - 2s/epoch - 11ms/step
# Epoch 74/128
# 183/183 - 2s - loss: 0.2290 - auc_1: 0.9675 - val_loss: 0.3054 - val_auc_1: 0.9498 - 2s/epoch - 10ms/step
# Epoch 75/128
# 183/183 - 2s - loss: 0.2368 - auc_1: 0.9656 - val_loss: 0.2893 - val_auc_1: 0.9504 - 2s/epoch - 10ms/step
# Epoch 76/128
# 183/183 - 2s - loss: 0.2336 - auc_1: 0.9662 - val_loss: 0.2994 - val_auc_1: 0.9465 - 2s/epoch - 10ms/step
# Epoch 77/128
# 183/183 - 2s - loss: 0.2312 - auc_1: 0.9668 - val_loss: 0.3026 - val_auc_1: 0.9482 - 2s/epoch - 10ms/step
# Epoch 78/128
# 183/183 - 2s - loss: 0.2245 - auc_1: 0.9686 - val_loss: 0.3041 - val_auc_1: 0.9473 - 2s/epoch - 13ms/step
# Epoch 79/128
# 183/183 - 2s - loss: 0.2374 - auc_1: 0.9651 - val_loss: 0.3049 - val_auc_1: 0.9432 - 2s/epoch - 10ms/step
# Epoch 80/128
# 183/183 - 2s - loss: 0.2302 - auc_1: 0.9673 - val_loss: 0.2815 - val_auc_1: 0.9533 - 2s/epoch - 10ms/step
# Epoch 81/128
# 183/183 - 2s - loss: 0.2326 - auc_1: 0.9664 - val_loss: 0.2948 - val_auc_1: 0.9493 - 2s/epoch - 10ms/step
# Epoch 82/128
# 183/183 - 2s - loss: 0.2261 - auc_1: 0.9683 - val_loss: 0.2861 - val_auc_1: 0.9546 - 2s/epoch - 10ms/step
# Epoch 83/128
# 183/183 - 2s - loss: 0.2360 - auc_1: 0.9656 - val_loss: 0.2899 - val_auc_1: 0.9500 - 2s/epoch - 10ms/step
# Epoch 84/128
# 183/183 - 2s - loss: 0.2258 - auc_1: 0.9686 - val_loss: 0.3131 - val_auc_1: 0.9463 - 2s/epoch - 12ms/step
# Epoch 85/128
# 183/183 - 2s - loss: 0.2269 - auc_1: 0.9683 - val_loss: 0.2828 - val_auc_1: 0.9526 - 2s/epoch - 11ms/step
# Epoch 86/128
# 183/183 - 2s - loss: 0.2248 - auc_1: 0.9686 - val_loss: 0.3098 - val_auc_1: 0.9450 - 2s/epoch - 12ms/step
# Epoch 87/128
# 183/183 - 2s - loss: 0.2273 - auc_1: 0.9682 - val_loss: 0.3024 - val_auc_1: 0.9483 - 2s/epoch - 11ms/step
# Epoch 88/128
# 183/183 - 2s - loss: 0.2222 - auc_1: 0.9696 - val_loss: 0.3169 - val_auc_1: 0.9414 - 2s/epoch - 10ms/step
# Epoch 89/128
# 183/183 - 2s - loss: 0.2215 - auc_1: 0.9695 - val_loss: 0.2895 - val_auc_1: 0.9516 - 2s/epoch - 10ms/step
# Epoch 90/128
# 183/183 - 3s - loss: 0.2236 - auc_1: 0.9690 - val_loss: 0.3064 - val_auc_1: 0.9448 - 3s/epoch - 14ms/step
# Epoch 91/128
# 183/183 - 2s - loss: 0.2209 - auc_1: 0.9698 - val_loss: 0.3021 - val_auc_1: 0.9490 - 2s/epoch - 10ms/step
# Epoch 92/128
# 183/183 - 2s - loss: 0.2216 - auc_1: 0.9699 - val_loss: 0.3015 - val_auc_1: 0.9457 - 2s/epoch - 10ms/step
# Epoch 93/128
# 183/183 - 2s - loss: 0.2320 - auc_1: 0.9666 - val_loss: 0.2961 - val_auc_1: 0.9504 - 2s/epoch - 10ms/step
# Epoch 94/128
# 183/183 - 2s - loss: 0.2211 - auc_1: 0.9699 - val_loss: 0.3085 - val_auc_1: 0.9433 - 2s/epoch - 10ms/step
# Epoch 95/128
# 183/183 - 2s - loss: 0.2184 - auc_1: 0.9704 - val_loss: 0.2925 - val_auc_1: 0.9522 - 2s/epoch - 10ms/step
# Epoch 96/128
# 183/183 - 2s - loss: 0.2209 - auc_1: 0.9697 - val_loss: 0.3039 - val_auc_1: 0.9461 - 2s/epoch - 12ms/step
# Epoch 97/128
# 183/183 - 2s - loss: 0.2138 - auc_1: 0.9716 - val_loss: 0.3104 - val_auc_1: 0.9459 - 2s/epoch - 10ms/step
# Epoch 98/128
# 183/183 - 2s - loss: 0.2219 - auc_1: 0.9695 - val_loss: 0.2977 - val_auc_1: 0.9494 - 2s/epoch - 10ms/step
# Epoch 99/128
# 183/183 - 2s - loss: 0.2138 - auc_1: 0.9716 - val_loss: 0.3179 - val_auc_1: 0.9435 - 2s/epoch - 10ms/step
# Epoch 100/128
# 183/183 - 2s - loss: 0.2180 - auc_1: 0.9708 - val_loss: 0.2959 - val_auc_1: 0.9490 - 2s/epoch - 10ms/step
# Epoch 101/128
# 183/183 - 2s - loss: 0.2186 - auc_1: 0.9704 - val_loss: 0.3119 - val_auc_1: 0.9489 - 2s/epoch - 10ms/step
# Epoch 102/128
# 183/183 - 3s - loss: 0.2144 - auc_1: 0.9714 - val_loss: 0.3083 - val_auc_1: 0.9468 - 3s/epoch - 14ms/step
# Epoch 103/128
# 183/183 - 2s - loss: 0.2124 - auc_1: 0.9719 - val_loss: 0.2973 - val_auc_1: 0.9493 - 2s/epoch - 10ms/step
# Epoch 104/128
# 183/183 - 2s - loss: 0.2160 - auc_1: 0.9710 - val_loss: 0.2999 - val_auc_1: 0.9472 - 2s/epoch - 10ms/step
# Epoch 105/128
# 183/183 - 2s - loss: 0.2146 - auc_1: 0.9717 - val_loss: 0.3093 - val_auc_1: 0.9484 - 2s/epoch - 10ms/step
# Epoch 106/128
# 183/183 - 2s - loss: 0.2141 - auc_1: 0.9716 - val_loss: 0.3064 - val_auc_1: 0.9473 - 2s/epoch - 10ms/step
# Epoch 107/128
# 183/183 - 2s - loss: 0.2141 - auc_1: 0.9718 - val_loss: 0.3051 - val_auc_1: 0.9491 - 2s/epoch - 10ms/step
# Epoch 108/128
# 183/183 - 2s - loss: 0.2107 - auc_1: 0.9727 - val_loss: 0.3007 - val_auc_1: 0.9478 - 2s/epoch - 12ms/step
# Epoch 109/128
# 183/183 - 2s - loss: 0.2162 - auc_1: 0.9711 - val_loss: 0.3230 - val_auc_1: 0.9418 - 2s/epoch - 10ms/step
# Epoch 110/128
# 183/183 - 2s - loss: 0.2118 - auc_1: 0.9725 - val_loss: 0.3502 - val_auc_1: 0.9330 - 2s/epoch - 10ms/step
# Epoch 111/128
# 183/183 - 2s - loss: 0.2060 - auc_1: 0.9738 - val_loss: 0.3746 - val_auc_1: 0.9420 - 2s/epoch - 10ms/step
# Epoch 112/128
# 183/183 - 2s - loss: 0.2114 - auc_1: 0.9723 - val_loss: 0.3266 - val_auc_1: 0.9411 - 2s/epoch - 12ms/step
# Epoch 113/128
# 183/183 - 2s - loss: 0.2059 - auc_1: 0.9740 - val_loss: 0.3191 - val_auc_1: 0.9450 - 2s/epoch - 10ms/step
# Epoch 114/128
# 183/183 - 2s - loss: 0.2070 - auc_1: 0.9733 - val_loss: 0.3150 - val_auc_1: 0.9437 - 2s/epoch - 12ms/step
# Epoch 115/128
# 183/183 - 2s - loss: 0.2140 - auc_1: 0.9719 - val_loss: 0.3222 - val_auc_1: 0.9423 - 2s/epoch - 10ms/step
# Epoch 116/128
# 183/183 - 2s - loss: 0.2008 - auc_1: 0.9753 - val_loss: 0.3343 - val_auc_1: 0.9400 - 2s/epoch - 13ms/step
# Epoch 117/128
# 183/183 - 2s - loss: 0.2151 - auc_1: 0.9715 - val_loss: 0.3194 - val_auc_1: 0.9419 - 2s/epoch - 11ms/step
# Epoch 118/128
# 183/183 - 2s - loss: 0.2136 - auc_1: 0.9720 - val_loss: 0.3221 - val_auc_1: 0.9461 - 2s/epoch - 10ms/step
# Epoch 119/128
# 183/183 - 3s - loss: 0.2027 - auc_1: 0.9746 - val_loss: 0.3084 - val_auc_1: 0.9469 - 3s/epoch - 15ms/step
# Epoch 120/128
# 183/183 - 3s - loss: 0.2058 - auc_1: 0.9736 - val_loss: 0.3144 - val_auc_1: 0.9444 - 3s/epoch - 17ms/step
# Epoch 121/128
# 183/183 - 3s - loss: 0.2055 - auc_1: 0.9739 - val_loss: 0.3236 - val_auc_1: 0.9449 - 3s/epoch - 15ms/step
# Epoch 122/128
# 183/183 - 3s - loss: 0.2053 - auc_1: 0.9741 - val_loss: 0.2998 - val_auc_1: 0.9464 - 3s/epoch - 19ms/step
# Epoch 123/128
# 183/183 - 4s - loss: 0.2050 - auc_1: 0.9739 - val_loss: 0.3140 - val_auc_1: 0.9431 - 4s/epoch - 20ms/step
# Epoch 124/128
# 183/183 - 3s - loss: 0.2039 - auc_1: 0.9743 - val_loss: 0.2990 - val_auc_1: 0.9505 - 3s/epoch - 15ms/step
# Epoch 125/128
# 183/183 - 2s - loss: 0.2044 - auc_1: 0.9741 - val_loss: 0.3028 - val_auc_1: 0.9461 - 2s/epoch - 10ms/step
# Epoch 126/128
# 183/183 - 2s - loss: 0.2082 - auc_1: 0.9732 - val_loss: 0.3216 - val_auc_1: 0.9445 - 2s/epoch - 10ms/step
# Epoch 127/128
# 183/183 - 2s - loss: 0.2014 - auc_1: 0.9749 - val_loss: 0.3350 - val_auc_1: 0.9438 - 2s/epoch - 10ms/step
# Epoch 128/128
# 183/183 - 2s - loss: 0.2003 - auc_1: 0.9752 - val_loss: 0.3143 - val_auc_1: 0.9473 - 2s/epoch - 12ms/step
# 46/46 [==============================] - 1s 6ms/step
#
# Training on Fold 3...
# Epoch 1/128
# 183/183 - 8s - loss: 0.4879 - auc_2: 0.8308 - val_loss: 0.4233 - val_auc_2: 0.9058 - 8s/epoch - 45ms/step
# Epoch 2/128
# 183/183 - 2s - loss: 0.3931 - auc_2: 0.9013 - val_loss: 0.3612 - val_auc_2: 0.9178 - 2s/epoch - 13ms/step
# Epoch 3/128
# 183/183 - 2s - loss: 0.3590 - auc_2: 0.9199 - val_loss: 0.3717 - val_auc_2: 0.9207 - 2s/epoch - 11ms/step
# Epoch 4/128
# 183/183 - 2s - loss: 0.3506 - auc_2: 0.9236 - val_loss: 0.3552 - val_auc_2: 0.9219 - 2s/epoch - 11ms/step
# Epoch 5/128
# 183/183 - 2s - loss: 0.3438 - auc_2: 0.9271 - val_loss: 0.3490 - val_auc_2: 0.9241 - 2s/epoch - 10ms/step
# Epoch 6/128
# 183/183 - 2s - loss: 0.3427 - auc_2: 0.9270 - val_loss: 0.3504 - val_auc_2: 0.9242 - 2s/epoch - 10ms/step
# Epoch 7/128
# 183/183 - 2s - loss: 0.3407 - auc_2: 0.9282 - val_loss: 0.3506 - val_auc_2: 0.9258 - 2s/epoch - 11ms/step
# Epoch 8/128
# 183/183 - 2s - loss: 0.3342 - auc_2: 0.9309 - val_loss: 0.3433 - val_auc_2: 0.9265 - 2s/epoch - 13ms/step
# Epoch 9/128
# 183/183 - 2s - loss: 0.3275 - auc_2: 0.9339 - val_loss: 0.3422 - val_auc_2: 0.9275 - 2s/epoch - 10ms/step
# Epoch 10/128
# 183/183 - 2s - loss: 0.3244 - auc_2: 0.9351 - val_loss: 0.3613 - val_auc_2: 0.9203 - 2s/epoch - 10ms/step
# Epoch 11/128
# 183/183 - 2s - loss: 0.3251 - auc_2: 0.9349 - val_loss: 0.3425 - val_auc_2: 0.9307 - 2s/epoch - 10ms/step
# Epoch 12/128
# 183/183 - 2s - loss: 0.3205 - auc_2: 0.9364 - val_loss: 0.3424 - val_auc_2: 0.9310 - 2s/epoch - 10ms/step
# Epoch 13/128
# 183/183 - 2s - loss: 0.3180 - auc_2: 0.9374 - val_loss: 0.3378 - val_auc_2: 0.9305 - 2s/epoch - 12ms/step
# Epoch 14/128
# 183/183 - 2s - loss: 0.3186 - auc_2: 0.9370 - val_loss: 0.3455 - val_auc_2: 0.9293 - 2s/epoch - 12ms/step
# Epoch 15/128
# 183/183 - 2s - loss: 0.3095 - auc_2: 0.9410 - val_loss: 0.3364 - val_auc_2: 0.9324 - 2s/epoch - 10ms/step
# Epoch 16/128
# 183/183 - 2s - loss: 0.3100 - auc_2: 0.9406 - val_loss: 0.3352 - val_auc_2: 0.9343 - 2s/epoch - 10ms/step
# Epoch 17/128
# 183/183 - 2s - loss: 0.3113 - auc_2: 0.9406 - val_loss: 0.3350 - val_auc_2: 0.9311 - 2s/epoch - 10ms/step
# Epoch 18/128
# 183/183 - 2s - loss: 0.3026 - auc_2: 0.9431 - val_loss: 0.3289 - val_auc_2: 0.9350 - 2s/epoch - 10ms/step
# Epoch 19/128
# 183/183 - 2s - loss: 0.3030 - auc_2: 0.9433 - val_loss: 0.3223 - val_auc_2: 0.9370 - 2s/epoch - 10ms/step
# Epoch 20/128
# 183/183 - 2s - loss: 0.3015 - auc_2: 0.9442 - val_loss: 0.3374 - val_auc_2: 0.9355 - 2s/epoch - 13ms/step
# Epoch 21/128
# 183/183 - 2s - loss: 0.3013 - auc_2: 0.9444 - val_loss: 0.3254 - val_auc_2: 0.9367 - 2s/epoch - 10ms/step
# Epoch 22/128
# 183/183 - 2s - loss: 0.3020 - auc_2: 0.9440 - val_loss: 0.3192 - val_auc_2: 0.9380 - 2s/epoch - 10ms/step
# Epoch 23/128
# 183/183 - 2s - loss: 0.2961 - auc_2: 0.9460 - val_loss: 0.3270 - val_auc_2: 0.9359 - 2s/epoch - 10ms/step
# Epoch 24/128
# 183/183 - 2s - loss: 0.2973 - auc_2: 0.9458 - val_loss: 0.3202 - val_auc_2: 0.9377 - 2s/epoch - 10ms/step
# Epoch 25/128
# 183/183 - 2s - loss: 0.2948 - auc_2: 0.9467 - val_loss: 0.3339 - val_auc_2: 0.9327 - 2s/epoch - 10ms/step
# Epoch 26/128
# 183/183 - 2s - loss: 0.2972 - auc_2: 0.9457 - val_loss: 0.3287 - val_auc_2: 0.9349 - 2s/epoch - 12ms/step
# Epoch 27/128
# 183/183 - 2s - loss: 0.2939 - auc_2: 0.9471 - val_loss: 0.3174 - val_auc_2: 0.9396 - 2s/epoch - 10ms/step
# Epoch 28/128
# 183/183 - 2s - loss: 0.2918 - auc_2: 0.9477 - val_loss: 0.3301 - val_auc_2: 0.9345 - 2s/epoch - 13ms/step
# Epoch 29/128
# 183/183 - 2s - loss: 0.2903 - auc_2: 0.9484 - val_loss: 0.3149 - val_auc_2: 0.9411 - 2s/epoch - 11ms/step
# Epoch 30/128
# 183/183 - 2s - loss: 0.2909 - auc_2: 0.9482 - val_loss: 0.3211 - val_auc_2: 0.9396 - 2s/epoch - 10ms/step
# Epoch 31/128
# 183/183 - 2s - loss: 0.2847 - auc_2: 0.9504 - val_loss: 0.3254 - val_auc_2: 0.9370 - 2s/epoch - 10ms/step
# Epoch 32/128
# 183/183 - 2s - loss: 0.2860 - auc_2: 0.9499 - val_loss: 0.3269 - val_auc_2: 0.9352 - 2s/epoch - 12ms/step
# Epoch 33/128
# 183/183 - 2s - loss: 0.2846 - auc_2: 0.9503 - val_loss: 0.3581 - val_auc_2: 0.9232 - 2s/epoch - 10ms/step
# Epoch 34/128
# 183/183 - 2s - loss: 0.2867 - auc_2: 0.9497 - val_loss: 0.3124 - val_auc_2: 0.9414 - 2s/epoch - 10ms/step
# Epoch 35/128
# 183/183 - 2s - loss: 0.2803 - auc_2: 0.9519 - val_loss: 0.3334 - val_auc_2: 0.9371 - 2s/epoch - 10ms/step
# Epoch 36/128
# 183/183 - 2s - loss: 0.2819 - auc_2: 0.9514 - val_loss: 0.3201 - val_auc_2: 0.9384 - 2s/epoch - 10ms/step
# Epoch 37/128
# 183/183 - 2s - loss: 0.2803 - auc_2: 0.9520 - val_loss: 0.3149 - val_auc_2: 0.9399 - 2s/epoch - 10ms/step
# Epoch 38/128
# 183/183 - 2s - loss: 0.2819 - auc_2: 0.9515 - val_loss: 0.3114 - val_auc_2: 0.9411 - 2s/epoch - 12ms/step
# Epoch 39/128
# 183/183 - 2s - loss: 0.2802 - auc_2: 0.9519 - val_loss: 0.3102 - val_auc_2: 0.9432 - 2s/epoch - 10ms/step
# Epoch 40/128
# 183/183 - 2s - loss: 0.2773 - auc_2: 0.9530 - val_loss: 0.3172 - val_auc_2: 0.9392 - 2s/epoch - 10ms/step
# Epoch 41/128
# 183/183 - 2s - loss: 0.2761 - auc_2: 0.9536 - val_loss: 0.3107 - val_auc_2: 0.9409 - 2s/epoch - 10ms/step
# Epoch 42/128
# 183/183 - 2s - loss: 0.2770 - auc_2: 0.9531 - val_loss: 0.3170 - val_auc_2: 0.9399 - 2s/epoch - 10ms/step
# Epoch 43/128
# 183/183 - 2s - loss: 0.2726 - auc_2: 0.9546 - val_loss: 0.3135 - val_auc_2: 0.9402 - 2s/epoch - 10ms/step
# Epoch 44/128
# 183/183 - 2s - loss: 0.2702 - auc_2: 0.9554 - val_loss: 0.3170 - val_auc_2: 0.9413 - 2s/epoch - 13ms/step
# Epoch 45/128
# 183/183 - 2s - loss: 0.2694 - auc_2: 0.9557 - val_loss: 0.3180 - val_auc_2: 0.9406 - 2s/epoch - 10ms/step
# Epoch 46/128
# 183/183 - 2s - loss: 0.2684 - auc_2: 0.9561 - val_loss: 0.3173 - val_auc_2: 0.9421 - 2s/epoch - 10ms/step
# Epoch 47/128
# 183/183 - 2s - loss: 0.2679 - auc_2: 0.9561 - val_loss: 0.3086 - val_auc_2: 0.9439 - 2s/epoch - 10ms/step
# Epoch 48/128
# 183/183 - 2s - loss: 0.2712 - auc_2: 0.9550 - val_loss: 0.3043 - val_auc_2: 0.9437 - 2s/epoch - 10ms/step
# Epoch 49/128
# 183/183 - 2s - loss: 0.2682 - auc_2: 0.9561 - val_loss: 0.3211 - val_auc_2: 0.9378 - 2s/epoch - 10ms/step
# Epoch 50/128
# 183/183 - 2s - loss: 0.2707 - auc_2: 0.9552 - val_loss: 0.3152 - val_auc_2: 0.9410 - 2s/epoch - 14ms/step
# Epoch 51/128
# 183/183 - 2s - loss: 0.2679 - auc_2: 0.9561 - val_loss: 0.3158 - val_auc_2: 0.9397 - 2s/epoch - 10ms/step
# Epoch 52/128
# 183/183 - 2s - loss: 0.2622 - auc_2: 0.9580 - val_loss: 0.3103 - val_auc_2: 0.9431 - 2s/epoch - 10ms/step
# Epoch 53/128
# 183/183 - 2s - loss: 0.2611 - auc_2: 0.9584 - val_loss: 0.3048 - val_auc_2: 0.9446 - 2s/epoch - 10ms/step
# Epoch 54/128
# 183/183 - 2s - loss: 0.2674 - auc_2: 0.9563 - val_loss: 0.3021 - val_auc_2: 0.9450 - 2s/epoch - 10ms/step
# Epoch 55/128
# 183/183 - 2s - loss: 0.2577 - auc_2: 0.9595 - val_loss: 0.3047 - val_auc_2: 0.9450 - 2s/epoch - 10ms/step
# Epoch 56/128
# 183/183 - 2s - loss: 0.2585 - auc_2: 0.9592 - val_loss: 0.3087 - val_auc_2: 0.9436 - 2s/epoch - 13ms/step
# Epoch 57/128
# 183/183 - 2s - loss: 0.2556 - auc_2: 0.9603 - val_loss: 0.3171 - val_auc_2: 0.9429 - 2s/epoch - 10ms/step
# Epoch 58/128
# 183/183 - 2s - loss: 0.2620 - auc_2: 0.9579 - val_loss: 0.3073 - val_auc_2: 0.9448 - 2s/epoch - 10ms/step
# Epoch 59/128
# 183/183 - 2s - loss: 0.2587 - auc_2: 0.9591 - val_loss: 0.3135 - val_auc_2: 0.9420 - 2s/epoch - 10ms/step
# Epoch 60/128
# 183/183 - 2s - loss: 0.2542 - auc_2: 0.9605 - val_loss: 0.3098 - val_auc_2: 0.9446 - 2s/epoch - 10ms/step
# Epoch 61/128
# 183/183 - 2s - loss: 0.2606 - auc_2: 0.9585 - val_loss: 0.3278 - val_auc_2: 0.9361 - 2s/epoch - 10ms/step
# Epoch 62/128
# 183/183 - 2s - loss: 0.2585 - auc_2: 0.9591 - val_loss: 0.3136 - val_auc_2: 0.9413 - 2s/epoch - 12ms/step
# Epoch 63/128
# 183/183 - 2s - loss: 0.2557 - auc_2: 0.9601 - val_loss: 0.3101 - val_auc_2: 0.9436 - 2s/epoch - 11ms/step
# Epoch 64/128
# 183/183 - 2s - loss: 0.2479 - auc_2: 0.9625 - val_loss: 0.3609 - val_auc_2: 0.9288 - 2s/epoch - 10ms/step
# Epoch 65/128
# 183/183 - 2s - loss: 0.2597 - auc_2: 0.9589 - val_loss: 0.3108 - val_auc_2: 0.9434 - 2s/epoch - 10ms/step
# Epoch 66/128
# 183/183 - 2s - loss: 0.2494 - auc_2: 0.9619 - val_loss: 0.3331 - val_auc_2: 0.9398 - 2s/epoch - 10ms/step
# Epoch 67/128
# 183/183 - 2s - loss: 0.2528 - auc_2: 0.9609 - val_loss: 0.3037 - val_auc_2: 0.9466 - 2s/epoch - 10ms/step
# Epoch 68/128
# 183/183 - 2s - loss: 0.2509 - auc_2: 0.9616 - val_loss: 0.3134 - val_auc_2: 0.9406 - 2s/epoch - 12ms/step
# Epoch 69/128
# 183/183 - 2s - loss: 0.2461 - auc_2: 0.9631 - val_loss: 0.3190 - val_auc_2: 0.9404 - 2s/epoch - 11ms/step
# Epoch 70/128
# 183/183 - 2s - loss: 0.2468 - auc_2: 0.9630 - val_loss: 0.3266 - val_auc_2: 0.9390 - 2s/epoch - 10ms/step
# Epoch 71/128
# 183/183 - 2s - loss: 0.2504 - auc_2: 0.9617 - val_loss: 0.3105 - val_auc_2: 0.9433 - 2s/epoch - 10ms/step
# Epoch 72/128
# 183/183 - 2s - loss: 0.2477 - auc_2: 0.9625 - val_loss: 0.3107 - val_auc_2: 0.9447 - 2s/epoch - 10ms/step
# Epoch 73/128
# 183/183 - 2s - loss: 0.2414 - auc_2: 0.9645 - val_loss: 0.3319 - val_auc_2: 0.9403 - 2s/epoch - 10ms/step
# Epoch 74/128
# 183/183 - 2s - loss: 0.2458 - auc_2: 0.9631 - val_loss: 0.3123 - val_auc_2: 0.9452 - 2s/epoch - 13ms/step
# Epoch 75/128
# 183/183 - 2s - loss: 0.2438 - auc_2: 0.9637 - val_loss: 0.3139 - val_auc_2: 0.9442 - 2s/epoch - 11ms/step
# Epoch 76/128
# 183/183 - 2s - loss: 0.2439 - auc_2: 0.9637 - val_loss: 0.3115 - val_auc_2: 0.9442 - 2s/epoch - 10ms/step
# Epoch 77/128
# 183/183 - 2s - loss: 0.2496 - auc_2: 0.9621 - val_loss: 0.2963 - val_auc_2: 0.9479 - 2s/epoch - 10ms/step
# Epoch 78/128
# 183/183 - 2s - loss: 0.2438 - auc_2: 0.9638 - val_loss: 0.3105 - val_auc_2: 0.9438 - 2s/epoch - 10ms/step
# Epoch 79/128
# 183/183 - 2s - loss: 0.2380 - auc_2: 0.9654 - val_loss: 0.3058 - val_auc_2: 0.9469 - 2s/epoch - 10ms/step
# Epoch 80/128
# 183/183 - 2s - loss: 0.2439 - auc_2: 0.9637 - val_loss: 0.3078 - val_auc_2: 0.9457 - 2s/epoch - 13ms/step
# Epoch 81/128
# 183/183 - 2s - loss: 0.2395 - auc_2: 0.9650 - val_loss: 0.3294 - val_auc_2: 0.9385 - 2s/epoch - 10ms/step
# Epoch 82/128
# 183/183 - 2s - loss: 0.2381 - auc_2: 0.9654 - val_loss: 0.3023 - val_auc_2: 0.9462 - 2s/epoch - 10ms/step
# Epoch 83/128
# 183/183 - 2s - loss: 0.2372 - auc_2: 0.9657 - val_loss: 0.3117 - val_auc_2: 0.9481 - 2s/epoch - 10ms/step
# Epoch 84/128
# 183/183 - 2s - loss: 0.2355 - auc_2: 0.9662 - val_loss: 0.3141 - val_auc_2: 0.9441 - 2s/epoch - 10ms/step
# Epoch 85/128
# 183/183 - 2s - loss: 0.2393 - auc_2: 0.9649 - val_loss: 0.3277 - val_auc_2: 0.9406 - 2s/epoch - 10ms/step
# Epoch 86/128
# 183/183 - 2s - loss: 0.2380 - auc_2: 0.9654 - val_loss: 0.3147 - val_auc_2: 0.9423 - 2s/epoch - 13ms/step
# Epoch 87/128
# 183/183 - 2s - loss: 0.2307 - auc_2: 0.9674 - val_loss: 0.3218 - val_auc_2: 0.9420 - 2s/epoch - 10ms/step
# Epoch 88/128
# 183/183 - 2s - loss: 0.2324 - auc_2: 0.9670 - val_loss: 0.3379 - val_auc_2: 0.9382 - 2s/epoch - 10ms/step
# Epoch 89/128
# 183/183 - 2s - loss: 0.2283 - auc_2: 0.9681 - val_loss: 0.3295 - val_auc_2: 0.9399 - 2s/epoch - 10ms/step
# Epoch 90/128
# 183/183 - 2s - loss: 0.2324 - auc_2: 0.9671 - val_loss: 0.3170 - val_auc_2: 0.9453 - 2s/epoch - 10ms/step
# Epoch 91/128
# 183/183 - 2s - loss: 0.2356 - auc_2: 0.9662 - val_loss: 0.3176 - val_auc_2: 0.9423 - 2s/epoch - 10ms/step
# Epoch 92/128
# 183/183 - 2s - loss: 0.2294 - auc_2: 0.9680 - val_loss: 0.3119 - val_auc_2: 0.9467 - 2s/epoch - 12ms/step
# Epoch 93/128
# 183/183 - 2s - loss: 0.2324 - auc_2: 0.9671 - val_loss: 0.3224 - val_auc_2: 0.9403 - 2s/epoch - 10ms/step
# Epoch 94/128
# 183/183 - 2s - loss: 0.2289 - auc_2: 0.9680 - val_loss: 0.3260 - val_auc_2: 0.9405 - 2s/epoch - 10ms/step
# Epoch 95/128
# 183/183 - 2s - loss: 0.2268 - auc_2: 0.9686 - val_loss: 0.3215 - val_auc_2: 0.9425 - 2s/epoch - 10ms/step
# Epoch 96/128
# 183/183 - 2s - loss: 0.2275 - auc_2: 0.9685 - val_loss: 0.3362 - val_auc_2: 0.9424 - 2s/epoch - 10ms/step
# Epoch 97/128
# 183/183 - 2s - loss: 0.2281 - auc_2: 0.9682 - val_loss: 0.3079 - val_auc_2: 0.9463 - 2s/epoch - 10ms/step
# Epoch 98/128
# 183/183 - 2s - loss: 0.2232 - auc_2: 0.9695 - val_loss: 0.3032 - val_auc_2: 0.9476 - 2s/epoch - 13ms/step
# Epoch 99/128
# 183/183 - 2s - loss: 0.2274 - auc_2: 0.9685 - val_loss: 0.3235 - val_auc_2: 0.9395 - 2s/epoch - 10ms/step
# Epoch 100/128
# 183/183 - 2s - loss: 0.2293 - auc_2: 0.9679 - val_loss: 0.3204 - val_auc_2: 0.9425 - 2s/epoch - 10ms/step
# Epoch 101/128
# 183/183 - 2s - loss: 0.2331 - auc_2: 0.9669 - val_loss: 0.3095 - val_auc_2: 0.9465 - 2s/epoch - 10ms/step
# Epoch 102/128
# 183/183 - 2s - loss: 0.2192 - auc_2: 0.9706 - val_loss: 0.3476 - val_auc_2: 0.9438 - 2s/epoch - 10ms/step
# Epoch 103/128
# 183/183 - 2s - loss: 0.2198 - auc_2: 0.9706 - val_loss: 0.3157 - val_auc_2: 0.9445 - 2s/epoch - 10ms/step
# Epoch 104/128
# 183/183 - 2s - loss: 0.2258 - auc_2: 0.9688 - val_loss: 0.3094 - val_auc_2: 0.9458 - 2s/epoch - 12ms/step
# Epoch 105/128
# 183/183 - 2s - loss: 0.2203 - auc_2: 0.9704 - val_loss: 0.3375 - val_auc_2: 0.9395 - 2s/epoch - 10ms/step
# Epoch 106/128
# 183/183 - 2s - loss: 0.2243 - auc_2: 0.9691 - val_loss: 0.3136 - val_auc_2: 0.9486 - 2s/epoch - 10ms/step
# Epoch 107/128
# 183/183 - 2s - loss: 0.2195 - auc_2: 0.9707 - val_loss: 0.3218 - val_auc_2: 0.9450 - 2s/epoch - 10ms/step
# Epoch 108/128
# 183/183 - 2s - loss: 0.2224 - auc_2: 0.9699 - val_loss: 0.3338 - val_auc_2: 0.9413 - 2s/epoch - 10ms/step
# Epoch 109/128
# 183/183 - 2s - loss: 0.2204 - auc_2: 0.9703 - val_loss: 0.3179 - val_auc_2: 0.9474 - 2s/epoch - 10ms/step
# Epoch 110/128
# 183/183 - 2s - loss: 0.2166 - auc_2: 0.9712 - val_loss: 0.3197 - val_auc_2: 0.9434 - 2s/epoch - 12ms/step
# Epoch 111/128
# 183/183 - 2s - loss: 0.2162 - auc_2: 0.9714 - val_loss: 0.3307 - val_auc_2: 0.9428 - 2s/epoch - 10ms/step
# Epoch 112/128
# 183/183 - 2s - loss: 0.2212 - auc_2: 0.9701 - val_loss: 0.3223 - val_auc_2: 0.9462 - 2s/epoch - 10ms/step
# Epoch 113/128
# 183/183 - 2s - loss: 0.2215 - auc_2: 0.9699 - val_loss: 0.2936 - val_auc_2: 0.9494 - 2s/epoch - 10ms/step
# Epoch 114/128
# 183/183 - 2s - loss: 0.2143 - auc_2: 0.9719 - val_loss: 0.3196 - val_auc_2: 0.9459 - 2s/epoch - 10ms/step
# Epoch 115/128
# 183/183 - 2s - loss: 0.2152 - auc_2: 0.9717 - val_loss: 0.3450 - val_auc_2: 0.9360 - 2s/epoch - 10ms/step
# Epoch 116/128
# 183/183 - 2s - loss: 0.2227 - auc_2: 0.9696 - val_loss: 0.3138 - val_auc_2: 0.9442 - 2s/epoch - 13ms/step
# Epoch 117/128
# 183/183 - 2s - loss: 0.2202 - auc_2: 0.9705 - val_loss: 0.3163 - val_auc_2: 0.9441 - 2s/epoch - 11ms/step
# Epoch 118/128
# 183/183 - 2s - loss: 0.2166 - auc_2: 0.9713 - val_loss: 0.3221 - val_auc_2: 0.9457 - 2s/epoch - 10ms/step
# Epoch 119/128
# 183/183 - 2s - loss: 0.2201 - auc_2: 0.9704 - val_loss: 0.3198 - val_auc_2: 0.9465 - 2s/epoch - 10ms/step
# Epoch 120/128
# 183/183 - 2s - loss: 0.2083 - auc_2: 0.9735 - val_loss: 0.3144 - val_auc_2: 0.9468 - 2s/epoch - 10ms/step
# Epoch 121/128
# 183/183 - 2s - loss: 0.2111 - auc_2: 0.9729 - val_loss: 0.3094 - val_auc_2: 0.9497 - 2s/epoch - 10ms/step
# Epoch 122/128
# 183/183 - 2s - loss: 0.2119 - auc_2: 0.9726 - val_loss: 0.3230 - val_auc_2: 0.9470 - 2s/epoch - 12ms/step
# Epoch 123/128
# 183/183 - 2s - loss: 0.2122 - auc_2: 0.9725 - val_loss: 0.3165 - val_auc_2: 0.9450 - 2s/epoch - 10ms/step
# Epoch 124/128
# 183/183 - 2s - loss: 0.2145 - auc_2: 0.9720 - val_loss: 0.3156 - val_auc_2: 0.9476 - 2s/epoch - 10ms/step
# Epoch 125/128
# 183/183 - 2s - loss: 0.2134 - auc_2: 0.9721 - val_loss: 0.3192 - val_auc_2: 0.9476 - 2s/epoch - 10ms/step
# Epoch 126/128
# 183/183 - 2s - loss: 0.2149 - auc_2: 0.9718 - val_loss: 0.3278 - val_auc_2: 0.9420 - 2s/epoch - 10ms/step
# Epoch 127/128
# 183/183 - 2s - loss: 0.2126 - auc_2: 0.9724 - val_loss: 0.3297 - val_auc_2: 0.9436 - 2s/epoch - 10ms/step
# Epoch 128/128
# 183/183 - 3s - loss: 0.2124 - auc_2: 0.9723 - val_loss: 0.3241 - val_auc_2: 0.9454 - 3s/epoch - 14ms/step
# 46/46 [==============================] - 1s 8ms/step
#
# Training on Fold 4...
# Epoch 1/128
# 183/183 - 8s - loss: 0.4436 - auc_3: 0.8727 - val_loss: 0.3746 - val_auc_3: 0.9165 - 8s/epoch - 44ms/step
# Epoch 2/128
# 183/183 - 2s - loss: 0.3686 - auc_3: 0.9149 - val_loss: 0.3637 - val_auc_3: 0.9202 - 2s/epoch - 11ms/step
# Epoch 3/128
# 183/183 - 2s - loss: 0.3443 - auc_3: 0.9268 - val_loss: 0.3568 - val_auc_3: 0.9231 - 2s/epoch - 12ms/step
# Epoch 4/128
# 183/183 - 2s - loss: 0.3453 - auc_3: 0.9260 - val_loss: 0.3503 - val_auc_3: 0.9243 - 2s/epoch - 10ms/step
# Epoch 5/128
# 183/183 - 2s - loss: 0.3420 - auc_3: 0.9277 - val_loss: 0.3507 - val_auc_3: 0.9229 - 2s/epoch - 11ms/step
# Epoch 6/128
# 183/183 - 2s - loss: 0.3316 - auc_3: 0.9322 - val_loss: 0.3471 - val_auc_3: 0.9254 - 2s/epoch - 11ms/step
# Epoch 7/128
# 183/183 - 2s - loss: 0.3345 - auc_3: 0.9309 - val_loss: 0.3768 - val_auc_3: 0.9257 - 2s/epoch - 10ms/step
# Epoch 8/128
# 183/183 - 2s - loss: 0.3269 - auc_3: 0.9340 - val_loss: 0.3381 - val_auc_3: 0.9293 - 2s/epoch - 10ms/step
# Epoch 9/128
# 183/183 - 3s - loss: 0.3188 - auc_3: 0.9375 - val_loss: 0.3448 - val_auc_3: 0.9318 - 3s/epoch - 14ms/step
# Epoch 10/128
# 183/183 - 2s - loss: 0.3164 - auc_3: 0.9384 - val_loss: 0.3305 - val_auc_3: 0.9327 - 2s/epoch - 10ms/step
# Epoch 11/128
# 183/183 - 2s - loss: 0.3094 - auc_3: 0.9412 - val_loss: 0.3350 - val_auc_3: 0.9327 - 2s/epoch - 10ms/step
# Epoch 12/128
# 183/183 - 2s - loss: 0.3114 - auc_3: 0.9401 - val_loss: 0.3312 - val_auc_3: 0.9332 - 2s/epoch - 10ms/step
# Epoch 13/128
# 183/183 - 2s - loss: 0.3065 - auc_3: 0.9423 - val_loss: 0.3390 - val_auc_3: 0.9298 - 2s/epoch - 10ms/step
# Epoch 14/128
# 183/183 - 2s - loss: 0.3045 - auc_3: 0.9430 - val_loss: 0.3241 - val_auc_3: 0.9360 - 2s/epoch - 10ms/step
# Epoch 15/128
# 183/183 - 3s - loss: 0.3002 - auc_3: 0.9446 - val_loss: 0.3276 - val_auc_3: 0.9357 - 3s/epoch - 14ms/step
# Epoch 16/128
# 183/183 - 2s - loss: 0.3007 - auc_3: 0.9443 - val_loss: 0.3286 - val_auc_3: 0.9344 - 2s/epoch - 10ms/step
# Epoch 17/128
# 183/183 - 2s - loss: 0.2981 - auc_3: 0.9451 - val_loss: 0.3333 - val_auc_3: 0.9327 - 2s/epoch - 10ms/step
# Epoch 18/128
# 183/183 - 2s - loss: 0.2957 - auc_3: 0.9463 - val_loss: 0.3367 - val_auc_3: 0.9325 - 2s/epoch - 10ms/step
# Epoch 19/128
# 183/183 - 2s - loss: 0.2930 - auc_3: 0.9473 - val_loss: 0.3269 - val_auc_3: 0.9332 - 2s/epoch - 10ms/step
# Epoch 20/128
# 183/183 - 2s - loss: 0.2930 - auc_3: 0.9472 - val_loss: 0.3307 - val_auc_3: 0.9337 - 2s/epoch - 10ms/step
# Epoch 21/128
# 183/183 - 2s - loss: 0.2900 - auc_3: 0.9484 - val_loss: 0.3249 - val_auc_3: 0.9353 - 2s/epoch - 12ms/step
# Epoch 22/128
# ...
# Epoch 128/128
# 183/183 - 2s - loss: 0.2041 - auc_3: 0.9744 - val_loss: 0.3321 - val_auc_3: 0.9400 - 2s/epoch - 10ms/step
# 46/46 [==============================] - 1s 7ms/step
#
# Training on Fold 5...
# Epoch 1/128
# 183/183 - 8s - loss: 0.4011 - auc_4: 0.8959 - val_loss: 0.3647 - val_auc_4: 0.9266 - 8s/epoch - 45ms/step
# Epoch 2/128
# 183/183 - 2s - loss: 0.3570 - auc_4: 0.9206 - val_loss: 0.3482 - val_auc_4: 0.9290 - 2s/epoch - 10ms/step
# Epoch 3/128
# 183/183 - 2s - loss: 0.3512 - auc_4: 0.9234 - val_loss: 0.3363 - val_auc_4: 0.9299 - 2s/epoch - 12ms/step
# Epoch 4/128
# 183/183 - 2s - loss: 0.3452 - auc_4: 0.9258 - val_loss: 0.3342 - val_auc_4: 0.9317 - 2s/epoch - 10ms/step
# Epoch 5/128
# 183/183 - 2s - loss: 0.3378 - auc_4: 0.9291 - val_loss: 0.3282 - val_auc_4: 0.9337 - 2s/epoch - 11ms/step
# Epoch 6/128
# 183/183 - 2s - loss: 0.3378 - auc_4: 0.9292 - val_loss: 0.3292 - val_auc_4: 0.9336 - 2s/epoch - 10ms/step
# Epoch 7/128
# 183/183 - 2s - loss: 0.3292 - auc_4: 0.9328 - val_loss: 0.3248 - val_auc_4: 0.9352 - 2s/epoch - 11ms/step
# Epoch 8/128
# 183/183 - 2s - loss: 0.3288 - auc_4: 0.9332 - val_loss: 0.3238 - val_auc_4: 0.9367 - 2s/epoch - 10ms/step
# Epoch 9/128
# 183/183 - 2s - loss: 0.3260 - auc_4: 0.9343 - val_loss: 0.3408 - val_auc_4: 0.9357 - 2s/epoch - 13ms/step
# Epoch 10/128
# 183/183 - 2s - loss: 0.3212 - auc_4: 0.9363 - val_loss: 0.3228 - val_auc_4: 0.9363 - 2s/epoch - 11ms/step
# Epoch 11/128
# 183/183 - 2s - loss: 0.3187 - auc_4: 0.9371 - val_loss: 0.3477 - val_auc_4: 0.9350 - 2s/epoch - 10ms/step
# Epoch 12/128
# 183/183 - 2s - loss: 0.3175 - auc_4: 0.9373 - val_loss: 0.3464 - val_auc_4: 0.9330 - 2s/epoch - 10ms/step
# Epoch 13/128
# 183/183 - 2s - loss: 0.3177 - auc_4: 0.9374 - val_loss: 0.3218 - val_auc_4: 0.9357 - 2s/epoch - 11ms/step
# Epoch 14/128
# 183/183 - 2s - loss: 0.3117 - auc_4: 0.9398 - val_loss: 0.3218 - val_auc_4: 0.9393 - 2s/epoch - 10ms/step
# Epoch 15/128
# 183/183 - 2s - loss: 0.3139 - auc_4: 0.9390 - val_loss: 0.3199 - val_auc_4: 0.9366 - 2s/epoch - 12ms/step
# Epoch 16/128
# 183/183 - 2s - loss: 0.3108 - auc_4: 0.9401 - val_loss: 0.3367 - val_auc_4: 0.9328 - 2s/epoch - 10ms/step
# Epoch 17/128
# 183/183 - 2s - loss: 0.3119 - auc_4: 0.9399 - val_loss: 0.3160 - val_auc_4: 0.9387 - 2s/epoch - 10ms/step
# Epoch 18/128
# 183/183 - 2s - loss: 0.3046 - auc_4: 0.9424 - val_loss: 0.3126 - val_auc_4: 0.9406 - 2s/epoch - 10ms/step
# Epoch 19/128
# 183/183 - 2s - loss: 0.3031 - auc_4: 0.9432 - val_loss: 0.3130 - val_auc_4: 0.9390 - 2s/epoch - 10ms/step
# Epoch 20/128
# 183/183 - 2s - loss: 0.2990 - auc_4: 0.9444 - val_loss: 0.3138 - val_auc_4: 0.9392 - 2s/epoch - 10ms/step
# Epoch 21/128
# 183/183 - 2s - loss: 0.3009 - auc_4: 0.9435 - val_loss: 0.3192 - val_auc_4: 0.9384 - 2s/epoch - 12ms/step
# Epoch 22/128
# 183/183 - 2s - loss: 0.2994 - auc_4: 0.9443 - val_loss: 0.3077 - val_auc_4: 0.9415 - 2s/epoch - 10ms/step
# Epoch 23/128
# 183/183 - 2s - loss: 0.2945 - auc_4: 0.9460 - val_loss: 0.3190 - val_auc_4: 0.9378 - 2s/epoch - 10ms/step
# Epoch 24/128
# 183/183 - 2s - loss: 0.2931 - auc_4: 0.9468 - val_loss: 0.3259 - val_auc_4: 0.9378 - 2s/epoch - 10ms/step
# Epoch 25/128
# 183/183 - 2s - loss: 0.2930 - auc_4: 0.9470 - val_loss: 0.3059 - val_auc_4: 0.9426 - 2s/epoch - 10ms/step
# Epoch 26/128
# 183/183 - 2s - loss: 0.2889 - auc_4: 0.9484 - val_loss: 0.3127 - val_auc_4: 0.9440 - 2s/epoch - 10ms/step
# Epoch 27/128
# 183/183 - 2s - loss: 0.2892 - auc_4: 0.9484 - val_loss: 0.3094 - val_auc_4: 0.9447 - 2s/epoch - 12ms/step
# Epoch 28/128
# 183/183 - 2s - loss: 0.2846 - auc_4: 0.9499 - val_loss: 0.3074 - val_auc_4: 0.9427 - 2s/epoch - 10ms/step
# Epoch 29/128
# 183/183 - 2s - loss: 0.2890 - auc_4: 0.9479 - val_loss: 0.3128 - val_auc_4: 0.9411 - 2s/epoch - 10ms/step
# Epoch 30/128
# 183/183 - 2s - loss: 0.2806 - auc_4: 0.9515 - val_loss: 0.3059 - val_auc_4: 0.9438 - 2s/epoch - 10ms/step
# Epoch 31/128
# 183/183 - 2s - loss: 0.2811 - auc_4: 0.9511 - val_loss: 0.2976 - val_auc_4: 0.9464 - 2s/epoch - 10ms/step
# Epoch 32/128
# 183/183 - 2s - loss: 0.2821 - auc_4: 0.9505 - val_loss: 0.3130 - val_auc_4: 0.9453 - 2s/epoch - 10ms/step
# Epoch 33/128
# 183/183 - 2s - loss: 0.2823 - auc_4: 0.9508 - val_loss: 0.3134 - val_auc_4: 0.9409 - 2s/epoch - 12ms/step
# Epoch 34/128
# 183/183 - 2s - loss: 0.2774 - auc_4: 0.9525 - val_loss: 0.2996 - val_auc_4: 0.9447 - 2s/epoch - 10ms/step
# Epoch 35/128
# 183/183 - 2s - loss: 0.2774 - auc_4: 0.9529 - val_loss: 0.2988 - val_auc_4: 0.9455 - 2s/epoch - 10ms/step
# Epoch 36/128
# 183/183 - 2s - loss: 0.2765 - auc_4: 0.9529 - val_loss: 0.3019 - val_auc_4: 0.9452 - 2s/epoch - 10ms/step
# Epoch 37/128
# 183/183 - 2s - loss: 0.2780 - auc_4: 0.9525 - val_loss: 0.3048 - val_auc_4: 0.9452 - 2s/epoch - 10ms/step
# Epoch 38/128
# 183/183 - 2s - loss: 0.2701 - auc_4: 0.9550 - val_loss: 0.3003 - val_auc_4: 0.9453 - 2s/epoch - 10ms/step
# Epoch 39/128
# 183/183 - 2s - loss: 0.2700 - auc_4: 0.9554 - val_loss: 0.3017 - val_auc_4: 0.9450 - 2s/epoch - 12ms/step
# Epoch 40/128
# 183/183 - 2s - loss: 0.2711 - auc_4: 0.9546 - val_loss: 0.3101 - val_auc_4: 0.9442 - 2s/epoch - 10ms/step
# Epoch 41/128
# 183/183 - 2s - loss: 0.2687 - auc_4: 0.9555 - val_loss: 0.2954 - val_auc_4: 0.9478 - 2s/epoch - 10ms/step
# Epoch 42/128
# 183/183 - 2s - loss: 0.2702 - auc_4: 0.9551 - val_loss: 0.2953 - val_auc_4: 0.9471 - 2s/epoch - 10ms/step
# Epoch 43/128
# 183/183 - 2s - loss: 0.2708 - auc_4: 0.9549 - val_loss: 0.2969 - val_auc_4: 0.9475 - 2s/epoch - 10ms/step
# Epoch 44/128
# 183/183 - 2s - loss: 0.2649 - auc_4: 0.9570 - val_loss: 0.2974 - val_auc_4: 0.9468 - 2s/epoch - 10ms/step
# Epoch 45/128
# 183/183 - 2s - loss: 0.2661 - auc_4: 0.9566 - val_loss: 0.2939 - val_auc_4: 0.9480 - 2s/epoch - 12ms/step
# Epoch 46/128
# 183/183 - 2s - loss: 0.2616 - auc_4: 0.9580 - val_loss: 0.2960 - val_auc_4: 0.9479 - 2s/epoch - 10ms/step
# Epoch 47/128
# 183/183 - 2s - loss: 0.2559 - auc_4: 0.9599 - val_loss: 0.2978 - val_auc_4: 0.9493 - 2s/epoch - 10ms/step
# Epoch 48/128
# 183/183 - 2s - loss: 0.2595 - auc_4: 0.9587 - val_loss: 0.2881 - val_auc_4: 0.9503 - 2s/epoch - 10ms/step
# Epoch 49/128
# 183/183 - 2s - loss: 0.2600 - auc_4: 0.9585 - val_loss: 0.2896 - val_auc_4: 0.9504 - 2s/epoch - 10ms/step
# Epoch 50/128
# 183/183 - 2s - loss: 0.2629 - auc_4: 0.9578 - val_loss: 0.2856 - val_auc_4: 0.9501 - 2s/epoch - 10ms/step
# Epoch 51/128
# 183/183 - 2s - loss: 0.2569 - auc_4: 0.9596 - val_loss: 0.2983 - val_auc_4: 0.9489 - 2s/epoch - 12ms/step
# Epoch 52/128
# 183/183 - 2s - loss: 0.2546 - auc_4: 0.9603 - val_loss: 0.2916 - val_auc_4: 0.9495 - 2s/epoch - 10ms/step
# Epoch 53/128
# 183/183 - 2s - loss: 0.2561 - auc_4: 0.9600 - val_loss: 0.2991 - val_auc_4: 0.9502 - 2s/epoch - 10ms/step
# Epoch 54/128
# 183/183 - 2s - loss: 0.2522 - auc_4: 0.9611 - val_loss: 0.2946 - val_auc_4: 0.9479 - 2s/epoch - 10ms/step
# Epoch 55/128
# 183/183 - 2s - loss: 0.2560 - auc_4: 0.9600 - val_loss: 0.2804 - val_auc_4: 0.9528 - 2s/epoch - 10ms/step
# Epoch 56/128
# 183/183 - 2s - loss: 0.2499 - auc_4: 0.9619 - val_loss: 0.2916 - val_auc_4: 0.9510 - 2s/epoch - 10ms/step
# Epoch 57/128
# 183/183 - 2s - loss: 0.2495 - auc_4: 0.9619 - val_loss: 0.2870 - val_auc_4: 0.9513 - 2s/epoch - 12ms/step
# Epoch 58/128
# 183/183 - 2s - loss: 0.2526 - auc_4: 0.9610 - val_loss: 0.2804 - val_auc_4: 0.9524 - 2s/epoch - 10ms/step
# Epoch 59/128
# 183/183 - 2s - loss: 0.2509 - auc_4: 0.9614 - val_loss: 0.2813 - val_auc_4: 0.9526 - 2s/epoch - 10ms/step
# Epoch 60/128
# 183/183 - 2s - loss: 0.2497 - auc_4: 0.9617 - val_loss: 0.2894 - val_auc_4: 0.9529 - 2s/epoch - 10ms/step
# Epoch 61/128
# 183/183 - 2s - loss: 0.2451 - auc_4: 0.9632 - val_loss: 0.2905 - val_auc_4: 0.9495 - 2s/epoch - 10ms/step
# Epoch 62/128
# 183/183 - 2s - loss: 0.2424 - auc_4: 0.9640 - val_loss: 0.2868 - val_auc_4: 0.9517 - 2s/epoch - 10ms/step
# Epoch 63/128
# 183/183 - 2s - loss: 0.2396 - auc_4: 0.9649 - val_loss: 0.2947 - val_auc_4: 0.9519 - 2s/epoch - 13ms/step
# Epoch 64/128
# 183/183 - 2s - loss: 0.2419 - auc_4: 0.9641 - val_loss: 0.3027 - val_auc_4: 0.9452 - 2s/epoch - 10ms/step
# Epoch 65/128
# 183/183 - 2s - loss: 0.2463 - auc_4: 0.9630 - val_loss: 0.2963 - val_auc_4: 0.9516 - 2s/epoch - 10ms/step
# Epoch 66/128
# 183/183 - 2s - loss: 0.2398 - auc_4: 0.9649 - val_loss: 0.2878 - val_auc_4: 0.9512 - 2s/epoch - 10ms/step
# Epoch 67/128
# 183/183 - 2s - loss: 0.2425 - auc_4: 0.9642 - val_loss: 0.2898 - val_auc_4: 0.9516 - 2s/epoch - 10ms/step
# Epoch 68/128
# 183/183 - 2s - loss: 0.2392 - auc_4: 0.9651 - val_loss: 0.2954 - val_auc_4: 0.9525 - 2s/epoch - 10ms/step
# Epoch 69/128
# 183/183 - 2s - loss: 0.2379 - auc_4: 0.9652 - val_loss: 0.2947 - val_auc_4: 0.9485 - 2s/epoch - 12ms/step
# Epoch 70/128
# 183/183 - 2s - loss: 0.2376 - auc_4: 0.9656 - val_loss: 0.2995 - val_auc_4: 0.9513 - 2s/epoch - 10ms/step
# Epoch 71/128
# 183/183 - 2s - loss: 0.2340 - auc_4: 0.9665 - val_loss: 0.2921 - val_auc_4: 0.9511 - 2s/epoch - 10ms/step
# Epoch 72/128
# 183/183 - 2s - loss: 0.2333 - auc_4: 0.9668 - val_loss: 0.3250 - val_auc_4: 0.9399 - 2s/epoch - 10ms/step
# Epoch 73/128
# 183/183 - 2s - loss: 0.2375 - auc_4: 0.9655 - val_loss: 0.2813 - val_auc_4: 0.9526 - 2s/epoch - 10ms/step
# Epoch 74/128
# 183/183 - 2s - loss: 0.2330 - auc_4: 0.9669 - val_loss: 0.3025 - val_auc_4: 0.9495 - 2s/epoch - 10ms/step
# Epoch 75/128
# 183/183 - 2s - loss: 0.2341 - auc_4: 0.9665 - val_loss: 0.2888 - val_auc_4: 0.9505 - 2s/epoch - 13ms/step
# Epoch 76/128
# 183/183 - 2s - loss: 0.2316 - auc_4: 0.9673 - val_loss: 0.2886 - val_auc_4: 0.9547 - 2s/epoch - 10ms/step
# Epoch 77/128
# 183/183 - 2s - loss: 0.2347 - auc_4: 0.9664 - val_loss: 0.2820 - val_auc_4: 0.9526 - 2s/epoch - 10ms/step
# Epoch 78/128
# 183/183 - 2s - loss: 0.2286 - auc_4: 0.9681 - val_loss: 0.2885 - val_auc_4: 0.9536 - 2s/epoch - 10ms/step
# Epoch 79/128
# 183/183 - 2s - loss: 0.2250 - auc_4: 0.9690 - val_loss: 0.2837 - val_auc_4: 0.9527 - 2s/epoch - 10ms/step
# Epoch 80/128
# 183/183 - 2s - loss: 0.2283 - auc_4: 0.9682 - val_loss: 0.2899 - val_auc_4: 0.9505 - 2s/epoch - 10ms/step
# Epoch 81/128
# 183/183 - 2s - loss: 0.2303 - auc_4: 0.9676 - val_loss: 0.2903 - val_auc_4: 0.9511 - 2s/epoch - 12ms/step
# Epoch 82/128
# 183/183 - 2s - loss: 0.2292 - auc_4: 0.9680 - val_loss: 0.2861 - val_auc_4: 0.9523 - 2s/epoch - 10ms/step
# Epoch 83/128
# 183/183 - 2s - loss: 0.2264 - auc_4: 0.9686 - val_loss: 0.2870 - val_auc_4: 0.9530 - 2s/epoch - 10ms/step
# Epoch 84/128
# 183/183 - 2s - loss: 0.2247 - auc_4: 0.9692 - val_loss: 0.2895 - val_auc_4: 0.9501 - 2s/epoch - 10ms/step
# Epoch 85/128
# 183/183 - 2s - loss: 0.2317 - auc_4: 0.9671 - val_loss: 0.2776 - val_auc_4: 0.9539 - 2s/epoch - 10ms/step
# Epoch 86/128
# 183/183 - 2s - loss: 0.2223 - auc_4: 0.9697 - val_loss: 0.2748 - val_auc_4: 0.9550 - 2s/epoch - 10ms/step
# Epoch 87/128
# 183/183 - 2s - loss: 0.2236 - auc_4: 0.9695 - val_loss: 0.3086 - val_auc_4: 0.9515 - 2s/epoch - 13ms/step
# Epoch 88/128
# 183/183 - 2s - loss: 0.2316 - auc_4: 0.9673 - val_loss: 0.2697 - val_auc_4: 0.9564 - 2s/epoch - 10ms/step
# Epoch 89/128
# 183/183 - 2s - loss: 0.2202 - auc_4: 0.9705 - val_loss: 0.2910 - val_auc_4: 0.9517 - 2s/epoch - 10ms/step
# Epoch 90/128
# 183/183 - 2s - loss: 0.2208 - auc_4: 0.9702 - val_loss: 0.2755 - val_auc_4: 0.9549 - 2s/epoch - 10ms/step
# Epoch 91/128
# 183/183 - 2s - loss: 0.2229 - auc_4: 0.9697 - val_loss: 0.2844 - val_auc_4: 0.9534 - 2s/epoch - 10ms/step
# Epoch 92/128
# 183/183 - 2s - loss: 0.2197 - auc_4: 0.9706 - val_loss: 0.3079 - val_auc_4: 0.9491 - 2s/epoch - 10ms/step
# Epoch 93/128
# 183/183 - 2s - loss: 0.2169 - auc_4: 0.9711 - val_loss: 0.2984 - val_auc_4: 0.9533 - 2s/epoch - 12ms/step
# Epoch 94/128
# 183/183 - 2s - loss: 0.2224 - auc_4: 0.9698 - val_loss: 0.2924 - val_auc_4: 0.9532 - 2s/epoch - 10ms/step
# Epoch 95/128
# 183/183 - 2s - loss: 0.2224 - auc_4: 0.9699 - val_loss: 0.2802 - val_auc_4: 0.9551 - 2s/epoch - 10ms/step
# Epoch 96/128
# 183/183 - 2s - loss: 0.2199 - auc_4: 0.9703 - val_loss: 0.3087 - val_auc_4: 0.9501 - 2s/epoch - 10ms/step
# Epoch 97/128
# 183/183 - 2s - loss: 0.2152 - auc_4: 0.9718 - val_loss: 0.2982 - val_auc_4: 0.9482 - 2s/epoch - 10ms/step
# Epoch 98/128
# 183/183 - 2s - loss: 0.2180 - auc_4: 0.9710 - val_loss: 0.2906 - val_auc_4: 0.9500 - 2s/epoch - 10ms/step
# Epoch 99/128
# 183/183 - 2s - loss: 0.2108 - auc_4: 0.9729 - val_loss: 0.3225 - val_auc_4: 0.9516 - 2s/epoch - 12ms/step
# Epoch 100/128
# 183/183 - 2s - loss: 0.2142 - auc_4: 0.9720 - val_loss: 0.3120 - val_auc_4: 0.9441 - 2s/epoch - 10ms/step
# Epoch 101/128
# 183/183 - 2s - loss: 0.2146 - auc_4: 0.9719 - val_loss: 0.2885 - val_auc_4: 0.9529 - 2s/epoch - 10ms/step
# Epoch 102/128
# 183/183 - 2s - loss: 0.2169 - auc_4: 0.9713 - val_loss: 0.2862 - val_auc_4: 0.9535 - 2s/epoch - 10ms/step
# Epoch 103/128
# 183/183 - 2s - loss: 0.2103 - auc_4: 0.9730 - val_loss: 0.2891 - val_auc_4: 0.9532 - 2s/epoch - 10ms/step
# Epoch 104/128
# 183/183 - 2s - loss: 0.2130 - auc_4: 0.9723 - val_loss: 0.3002 - val_auc_4: 0.9472 - 2s/epoch - 10ms/step
# Epoch 105/128
# 183/183 - 2s - loss: 0.2035 - auc_4: 0.9748 - val_loss: 0.2962 - val_auc_4: 0.9529 - 2s/epoch - 13ms/step
# Epoch 106/128
# 183/183 - 2s - loss: 0.2100 - auc_4: 0.9731 - val_loss: 0.3101 - val_auc_4: 0.9468 - 2s/epoch - 10ms/step
# Epoch 107/128
# 183/183 - 2s - loss: 0.2080 - auc_4: 0.9736 - val_loss: 0.2944 - val_auc_4: 0.9534 - 2s/epoch - 10ms/step
# Epoch 108/128
# 183/183 - 2s - loss: 0.2121 - auc_4: 0.9726 - val_loss: 0.2768 - val_auc_4: 0.9559 - 2s/epoch - 10ms/step
# Epoch 109/128
# 183/183 - 2s - loss: 0.2078 - auc_4: 0.9735 - val_loss: 0.2855 - val_auc_4: 0.9520 - 2s/epoch - 10ms/step
# Epoch 110/128
# 183/183 - 2s - loss: 0.2169 - auc_4: 0.9712 - val_loss: 0.2925 - val_auc_4: 0.9518 - 2s/epoch - 10ms/step
# Epoch 111/128
# 183/183 - 2s - loss: 0.2023 - auc_4: 0.9750 - val_loss: 0.2969 - val_auc_4: 0.9522 - 2s/epoch - 12ms/step
# Epoch 112/128
# 183/183 - 2s - loss: 0.2082 - auc_4: 0.9735 - val_loss: 0.2950 - val_auc_4: 0.9524 - 2s/epoch - 10ms/step
# Epoch 113/128
# 183/183 - 2s - loss: 0.2028 - auc_4: 0.9750 - val_loss: 0.2992 - val_auc_4: 0.9509 - 2s/epoch - 10ms/step
# Epoch 114/128
# 183/183 - 2s - loss: 0.2012 - auc_4: 0.9753 - val_loss: 0.3032 - val_auc_4: 0.9546 - 2s/epoch - 11ms/step
# Epoch 115/128
# 183/183 - 2s - loss: 0.2051 - auc_4: 0.9742 - val_loss: 0.3047 - val_auc_4: 0.9501 - 2s/epoch - 10ms/step
# Epoch 116/128
# 183/183 - 2s - loss: 0.2003 - auc_4: 0.9756 - val_loss: 0.2946 - val_auc_4: 0.9542 - 2s/epoch - 10ms/step
# Epoch 117/128
# 183/183 - 3s - loss: 0.2099 - auc_4: 0.9732 - val_loss: 0.2966 - val_auc_4: 0.9496 - 3s/epoch - 14ms/step
# Epoch 118/128
# 183/183 - 2s - loss: 0.2024 - auc_4: 0.9750 - val_loss: 0.3221 - val_auc_4: 0.9499 - 2s/epoch - 10ms/step
# Epoch 119/128
# 183/183 - 2s - loss: 0.1994 - auc_4: 0.9758 - val_loss: 0.3087 - val_auc_4: 0.9475 - 2s/epoch - 10ms/step
# Epoch 120/128
# 183/183 - 2s - loss: 0.2004 - auc_4: 0.9754 - val_loss: 0.2983 - val_auc_4: 0.9534 - 2s/epoch - 10ms/step
# Epoch 121/128
# 183/183 - 2s - loss: 0.1977 - auc_4: 0.9760 - val_loss: 0.3136 - val_auc_4: 0.9503 - 2s/epoch - 10ms/step
# Epoch 122/128
# 183/183 - 2s - loss: 0.2053 - auc_4: 0.9743 - val_loss: 0.2953 - val_auc_4: 0.9520 - 2s/epoch - 10ms/step
# Epoch 123/128
# 183/183 - 2s - loss: 0.1941 - auc_4: 0.9770 - val_loss: 0.3365 - val_auc_4: 0.9439 - 2s/epoch - 12ms/step
# Epoch 124/128
# 183/183 - 2s - loss: 0.1904 - auc_4: 0.9780 - val_loss: 0.3045 - val_auc_4: 0.9535 - 2s/epoch - 10ms/step
# Epoch 125/128
# 183/183 - 2s - loss: 0.1889 - auc_4: 0.9783 - val_loss: 0.3094 - val_auc_4: 0.9507 - 2s/epoch - 10ms/step
# Epoch 126/128
# 183/183 - 2s - loss: 0.1935 - auc_4: 0.9772 - val_loss: 0.3139 - val_auc_4: 0.9509 - 2s/epoch - 10ms/step
# Epoch 127/128
# 183/183 - 2s - loss: 0.2099 - auc_4: 0.9730 - val_loss: 0.3125 - val_auc_4: 0.9488 - 2s/epoch - 10ms/step
# Epoch 128/128
# 183/183 - 2s - loss: 0.1944 - auc_4: 0.9769 - val_loss: 0.3265 - val_auc_4: 0.9477 - 2s/epoch - 10ms/step
# 46/46 [==============================] - 1s 7ms/step
#
# Average Classification Report Across Folds:
# {'accuracy': 0.8833333333333334}
# <ipython-input-8-80e24cbb214d>:52: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_report = pd.DataFrame(all_reports).mean().to_dict()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %% [markdown]
# # Save results

# %%
extractorEmb = Model(inputs=model.inputs,outputs=model.get_layer(name="clsTokenEmb").output)

preds = model.predict(x3,batch_size = config.BATCH_SIZE)

dbresults={}
dbresults['pred_emb'] = extractorEmb.predict(x3,batch_size = config.BATCH_SIZE)
dbresults['pred_cls'] = preds
dbresults['y_cls'] = labels
dbresults['formula'] = df['formula']
dbresults['ids'] = df['ids']
dbresults['types'] = types
dbresults['trainidx'] = train_idx
dbresults['testidx'] = val_idx
dbresults['validx'] = val_idx

with open(mname+'_results.pkl', 'wb') as f:
    pickle.dump(dbresults, f)
# Out:
# 229/229 [==============================] - 1s 6ms/step
# 229/229 [==============================] - 1s 5ms/step

# %% [markdown]
# # Postprocessing

# %%
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn import metrics
import seaborn as sns
tsne = TSNE(n_components=2, verbose=0, random_state=123)
z = tsne.fit_transform(dbresults['pred_emb'])

# %%
dfr = pd.DataFrame()
dfr["y"] = np.asarray(dbresults['y_cls'].argmax(axis=-1)).astype('bool')
dfr["yp"] = np.asarray(dbresults['pred_cls'].argmax(axis=-1)).astype('bool')
dfr["tSNE1"] = z[:,0]
dfr["tSNE2"] = z[:,1]

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
fig, axes = plt.subplots(1, 3, figsize=(15, 4.8))
y_pclasses = dbresults['pred_cls'][dbresults['testidx']].argmax(axis=-1).tolist()
y_classes = dbresults['y_cls'][dbresults['testidx']].argmax(axis=-1)
m = tf.keras.metrics.AUC()
m.update_state(dbresults['y_cls'][dbresults['testidx']], dbresults['pred_cls'][dbresults['testidx']])
print(mname,'binary tf-acc:',tf.keras.metrics.binary_accuracy(y_classes, y_pclasses, threshold=0.5).numpy(),'AUC:',m.result().numpy())
confusion_matrix = metrics.confusion_matrix(y_classes, y_pclasses)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix,
                                            display_labels=['False','True'])
cm_display.plot(ax=axes[0],cmap=plt.cm.Blues)

dfr=dfr.sort_values(by=['y'])
sns.scatterplot(ax=axes[1],x="tSNE1", y="tSNE2", hue=dfr.y.tolist(),data=dfr,alpha=0.4)#.set(title=title+" data T-SNE projection")
axes[1].set_xlabel('$tSNE_1$')
axes[1].set_ylabel('$tSNE_2$',labelpad=1)
axes[1].set_title('Reference')
dfr=dfr.sort_values(by=['yp'])
sns.scatterplot(ax=axes[2],x="tSNE1", y="tSNE2", hue=dfr.yp.tolist(),data=dfr,alpha=0.4)#.set(title=title+" data T-SNE projection")
axes[2].set_title('Predicted')
axes[2].set_xlabel('$tSNE_1$')
axes[2].set_ylabel('$tSNE_2$',labelpad=1)
axes[2].legend('',frameon=False)
fig.tight_layout()
plt.savefig(mname+'_tsne.png',format='png',dpi=800,bbox_inches = "tight")
plt.show()
# Out:
# /content/elementsem/models/elembert_toxic_sr-mmp_V1_E_32_H_2_L_2 binary tf-acc: 0.88729507 AUC: 0.9477049
