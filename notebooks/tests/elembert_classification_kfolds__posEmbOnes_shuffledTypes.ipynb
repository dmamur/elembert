# %% [markdown]
# <a href="https://colab.research.google.com/github/dmamur/elembert/blob/main/notebooks/tests/elembert_classification_kfolds__posEmbOnes_shuffledTypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle,random
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Embedding,Dense,Dropout,Input,Lambda
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
import re, glob,os,sys
from collections import defaultdict
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical

def bert_module(query, key, value, i, config):
    # Multi headed self-attention
    attention_output = layers.MultiHeadAttention(
        num_heads=config.NUM_HEAD,
        key_dim=config.EMBED_DIM // config.NUM_HEAD,
        name="encoder_{}/multiheadattention".format(i),
        kernel_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed)
    )(query, key, value)
    attention_output = layers.Dropout(0.1, name="encoder_{}/att_dropout".format(i))(
        attention_output
    )
    attention_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/att_layernormalization".format(i)
    )(query + attention_output)

    # Feed-forward layer
    ffn = tf.keras.Sequential(
        [
            layers.Dense(config.FF_DIM, activation="relu",kernel_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed)),
            layers.Dense(config.EMBED_DIM,kernel_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed)),
        ],
        name="encoder_{}/ffn".format(i),
    )
    ffn_output = ffn(attention_output)
    ffn_output = layers.Dropout(0.1, name="encoder_{}/ffn_dropout".format(i))(
        ffn_output
    )
    sequence_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/ffn_layernormalization".format(i)
    )(attention_output + ffn_output)
    return sequence_output


def get_pos_encoding_matrix(max_len, d_emb):
    pos_enc = np.array(
        [
            [pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)]
            if pos != 0
            else np.zeros(d_emb)
            for pos in range(max_len)
        ]
    )
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2])  # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2])  # dim 2i+1
    return pos_enc

def create_elembert_model(inputs,config):
    word_embeddings = layers.Embedding(config.VOCAB_SIZE, config.EMBED_DIM, mask_zero=True,name="element_embdgs",
                                       embeddings_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed))(inputs)
    position_embeddings = layers.Embedding(input_dim=config.MAX_LEN,output_dim=config.EMBED_DIM,
                                           weights=[get_pos_encoding_matrix(config.MAX_LEN, config.EMBED_DIM)*0+1],
                                           #embeddings_initializer=tf.keras.initializers.GlorotUniform(seed=config.seed),
                                           name="position_embedding",)(tf.range(start=0, limit=config.MAX_LEN, delta=1))
    embeddings = word_embeddings + position_embeddings
    encoder_output = embeddings
    for i in range(config.NUM_LAYERS):
        encoder_output = bert_module(encoder_output, encoder_output, encoder_output, i, config)
    mlm_model = Model(inputs, encoder_output, name="masked_bert_model")

    return mlm_model

# %%
# !git clone https://github.com/dmamur/elementsem.git
# Out:
# Cloning into 'elementsem'...
# remote: Enumerating objects: 1082, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 1082 (delta 93), reused 4 (delta 4), pack-reused 918
# Receiving objects: 100% (1082/1082), 108.90 MiB | 13.06 MiB/s, done.
# Resolving deltas: 100% (552/552), done.
# Updating files: 100% (273/273), done.

# %%
class Config:
    MAX_LEN = 256
    BATCH_SIZE = 32
    LR = 0.001
    VOCAB_SIZE = 128
    EMBED_DIM = 32
    NUM_HEAD = 2 # used in bert model
    FF_DIM = 32 # used in bert model
    NUM_LAYERS = 2
    MNAME = 'elembert_'
    MVER = 'V1'
    DSPATH="/content/elementsem/data/"
    PREPATH="/content/elementsem/models/pretrained/"
    PATH="/content/elementsem/models/"
config = Config()
seed=12345
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
#'sider_1','sider_2','sider_3','sider_4','sider_5', 'sider_6','sider_7', 'sider_8', 'sider_9', 'sider_10', 'sider_11', 'sider_12',
#'sider_13', 'sider_14', 'sider_15','sider_16','sider_17','sider_18','sider_19','sider_20','sider_21','sider_22','sider_23',
#'sider_24','sider_25','sider_26','sider_27','dimensionality','spacegroup','liquid_amorphous','BBBP','bace','clintox','nr-ahr',
#'nr-ar','sr-atad5','nr-er-lbd','sr-p53','nr-ar-lbd','nr-ppar-gamma','sr-hse','nr-er','sr-mmp','nr-aromatase','sr-are','HIV'
ds = 'toxic_sr-mmp'
mname=config.PATH+config.MNAME+ds+'_%s_E_%s_H_%s_L_%s' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS)

# %% [markdown]
# # Load vocabulary and types

# %%
if (ds=='HIV'):
  df = pd.read_csv(config.DSPATH+ds+config.MVER+'_ds.csv')
else:
  df = pd.read_csv(config.DSPATH+ds+'_ds.csv')

types = df['types'+config.MVER].apply(eval).apply(list)
labels  = to_categorical(np.asarray(df['labels']))
uniquelbls=len(np.unique(np.asarray(df['labels'])))

with open(config.PREPATH+'/el2id'+config.MVER+'.pkl', 'rb') as f:
    db = pickle.load(f)

element2id = db['el2id']
el2id = db['el2id']
config.VOCAB_SIZE = len(element2id)
print('vocabSize: ', config.VOCAB_SIZE)
# Out:
# vocabSize:  565

# %% [markdown]
# # Convert types to integers

# %%
[random.shuffle(types[i]) for i in range(len(types))]
types0=[['[CLS]']+i+['[SEP]'] for i in types]
typesNumerical=[]
for i in types0:
    typesNumerical.append([element2id[j] for j in i])

x3 = tf.keras.preprocessing.sequence.pad_sequences(typesNumerical,dtype='int32',padding= 'post',truncating='post',maxlen=config.MAX_LEN)

#z = load_model(config.PREPATH+'/elembert_%s_E_%s_H_%s_L_%s.h5' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS),compile=False)
#z.trainable = True

inputC = Input((config.MAX_LEN), dtype=tf.int32,name='types')

# %%
epochs=2*config.BATCH_SIZE

print('dataLen: ',x3.shape,labels.shape)
# Out:
# dataLen:  (7320, 256) (7320, 2)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report

# Assuming you have loaded your data into x3 and labels variables

# Define the number of folds
num_folds = 5

# Initialize Stratified K-Fold Cross-Validator
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Initialize lists to store results
all_histories = []
all_reports = []

# Iterate over folds
for fold, (train_idx, val_idx) in enumerate(kfold.split(x3, np.argmax(labels, axis=1))):
    print(f"\nTraining on Fold {fold + 1}...")
    config.seed = np.random.randint(10000,99999,1)[0]
    z = create_elembert_model(inputC,config)
    e = Lambda(lambda x: x[:,0],name='clsTokenEmb')(z.output)
    f = Dense(uniquelbls, activation="softmax",name='out_tox',kernel_initializer=tf.keras.initializers.GlorotUniform(config.seed))(e)
    # Create and compile the model (assuming create_elembert_model function is available)
    model = Model(inputs=z.input, outputs=f)

    optimizer = tf.keras.optimizers.Adam(learning_rate=config.LR)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=[tf.keras.metrics.AUC()])

    # Extract training and validation sets
    x_train, x_val = x3[train_idx], x3[val_idx]
    y_train, y_val = labels[train_idx], labels[val_idx]

    # Train the model
    history = model.fit(
        x=x_train,
        y=y_train,
        validation_data=(x_val, y_val),
        epochs=epochs,
        batch_size=config.BATCH_SIZE,
        verbose=2
    )

    # Evaluate the model on the validation set
    val_predictions = model.predict(x_val, batch_size=config.BATCH_SIZE)
    val_report = classification_report(np.argmax(y_val, axis=1), np.argmax(val_predictions, axis=1), output_dict=True)

    # Append results to lists
    all_histories.append(history)
    all_reports.append(val_report)

# Print the average classification report across folds
avg_report = pd.DataFrame(all_reports).mean().to_dict()
print("\nAverage Classification Report Across Folds:")
print(avg_report)
# Out:
# Training on Fold 1...
# Epoch 1/64
# 183/183 - 20s - loss: 0.4476 - auc: 0.8475 - val_loss: 0.4499 - val_auc: 0.8902 - 20s/epoch - 111ms/step
# Epoch 2/64
# 183/183 - 2s - loss: 0.4388 - auc: 0.8513 - val_loss: 0.4422 - val_auc: 0.9174 - 2s/epoch - 11ms/step
# Epoch 3/64
# 183/183 - 2s - loss: 0.4220 - auc: 0.8769 - val_loss: 0.3846 - val_auc: 0.9221 - 2s/epoch - 10ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.3808 - auc: 0.9087 - val_loss: 0.3548 - val_auc: 0.9241 - 2s/epoch - 11ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3692 - auc: 0.9144 - val_loss: 0.3609 - val_auc: 0.9268 - 2s/epoch - 12ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3563 - auc: 0.9209 - val_loss: 0.3422 - val_auc: 0.9289 - 2s/epoch - 11ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3487 - auc: 0.9243 - val_loss: 0.3466 - val_auc: 0.9265 - 2s/epoch - 10ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3429 - auc: 0.9266 - val_loss: 0.3438 - val_auc: 0.9302 - 2s/epoch - 10ms/step
# Epoch 9/64
# 183/183 - 2s - loss: 0.3379 - auc: 0.9294 - val_loss: 0.3350 - val_auc: 0.9325 - 2s/epoch - 10ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3412 - auc: 0.9278 - val_loss: 0.3363 - val_auc: 0.9328 - 2s/epoch - 10ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3394 - auc: 0.9285 - val_loss: 0.3314 - val_auc: 0.9334 - 2s/epoch - 13ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3368 - auc: 0.9295 - val_loss: 0.3424 - val_auc: 0.9279 - 2s/epoch - 10ms/step
# Epoch 13/64
# 183/183 - 2s - loss: 0.3382 - auc: 0.9283 - val_loss: 0.3473 - val_auc: 0.9293 - 2s/epoch - 10ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3245 - auc: 0.9346 - val_loss: 0.3290 - val_auc: 0.9341 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3263 - auc: 0.9341 - val_loss: 0.3244 - val_auc: 0.9355 - 2s/epoch - 11ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3207 - auc: 0.9362 - val_loss: 0.3600 - val_auc: 0.9351 - 2s/epoch - 10ms/step
# Epoch 17/64
# 183/183 - 3s - loss: 0.3246 - auc: 0.9345 - val_loss: 0.3353 - val_auc: 0.9352 - 3s/epoch - 14ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3201 - auc: 0.9362 - val_loss: 0.3312 - val_auc: 0.9356 - 2s/epoch - 10ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3280 - auc: 0.9331 - val_loss: 0.3260 - val_auc: 0.9366 - 2s/epoch - 10ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3193 - auc: 0.9369 - val_loss: 0.3496 - val_auc: 0.9329 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3174 - auc: 0.9375 - val_loss: 0.3439 - val_auc: 0.9362 - 2s/epoch - 10ms/step
# Epoch 22/64
# 183/183 - 2s - loss: 0.3179 - auc: 0.9372 - val_loss: 0.3325 - val_auc: 0.9356 - 2s/epoch - 10ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3160 - auc: 0.9383 - val_loss: 0.3278 - val_auc: 0.9359 - 2s/epoch - 13ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.3173 - auc: 0.9378 - val_loss: 0.3241 - val_auc: 0.9373 - 2s/epoch - 10ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.3134 - auc: 0.9390 - val_loss: 0.3332 - val_auc: 0.9328 - 2s/epoch - 10ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.3096 - auc: 0.9403 - val_loss: 0.3551 - val_auc: 0.9221 - 2s/epoch - 10ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.3077 - auc: 0.9412 - val_loss: 0.3292 - val_auc: 0.9356 - 2s/epoch - 10ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.3080 - auc: 0.9415 - val_loss: 0.3308 - val_auc: 0.9361 - 2s/epoch - 11ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.3147 - auc: 0.9386 - val_loss: 0.3250 - val_auc: 0.9378 - 2s/epoch - 12ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.3084 - auc: 0.9412 - val_loss: 0.3171 - val_auc: 0.9397 - 2s/epoch - 10ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.3095 - auc: 0.9403 - val_loss: 0.3256 - val_auc: 0.9353 - 2s/epoch - 10ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.3055 - auc: 0.9420 - val_loss: 0.3547 - val_auc: 0.9231 - 2s/epoch - 10ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.3095 - auc: 0.9410 - val_loss: 0.3179 - val_auc: 0.9387 - 2s/epoch - 11ms/step
# Epoch 34/64
# 183/183 - 2s - loss: 0.3044 - auc: 0.9428 - val_loss: 0.3482 - val_auc: 0.9295 - 2s/epoch - 10ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.3074 - auc: 0.9414 - val_loss: 0.3303 - val_auc: 0.9345 - 2s/epoch - 13ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.2983 - auc: 0.9450 - val_loss: 0.3124 - val_auc: 0.9413 - 2s/epoch - 10ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.2997 - auc: 0.9444 - val_loss: 0.3219 - val_auc: 0.9398 - 2s/epoch - 10ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.3070 - auc: 0.9415 - val_loss: 0.3149 - val_auc: 0.9400 - 2s/epoch - 10ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.2988 - auc: 0.9449 - val_loss: 0.3198 - val_auc: 0.9387 - 2s/epoch - 10ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.2995 - auc: 0.9446 - val_loss: 0.3275 - val_auc: 0.9359 - 2s/epoch - 10ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.3037 - auc: 0.9430 - val_loss: 0.3246 - val_auc: 0.9370 - 2s/epoch - 12ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.3036 - auc: 0.9429 - val_loss: 0.3142 - val_auc: 0.9408 - 2s/epoch - 13ms/step
# Epoch 43/64
# 183/183 - 3s - loss: 0.3000 - auc: 0.9438 - val_loss: 0.3384 - val_auc: 0.9314 - 3s/epoch - 15ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.2993 - auc: 0.9449 - val_loss: 0.3145 - val_auc: 0.9409 - 2s/epoch - 10ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2984 - auc: 0.9447 - val_loss: 0.3291 - val_auc: 0.9374 - 2s/epoch - 10ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2929 - auc: 0.9471 - val_loss: 0.3242 - val_auc: 0.9364 - 2s/epoch - 12ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.3010 - auc: 0.9441 - val_loss: 0.3165 - val_auc: 0.9409 - 2s/epoch - 11ms/step
# Epoch 48/64
# 183/183 - 2s - loss: 0.2979 - auc: 0.9453 - val_loss: 0.3184 - val_auc: 0.9392 - 2s/epoch - 10ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2897 - auc: 0.9482 - val_loss: 0.3386 - val_auc: 0.9331 - 2s/epoch - 10ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2923 - auc: 0.9470 - val_loss: 0.3258 - val_auc: 0.9376 - 2s/epoch - 10ms/step
# Epoch 51/64
# 183/183 - 2s - loss: 0.2897 - auc: 0.9481 - val_loss: 0.3382 - val_auc: 0.9307 - 2s/epoch - 10ms/step
# Epoch 52/64
# 183/183 - 2s - loss: 0.2982 - auc: 0.9451 - val_loss: 0.3292 - val_auc: 0.9365 - 2s/epoch - 11ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2919 - auc: 0.9478 - val_loss: 0.3294 - val_auc: 0.9338 - 2s/epoch - 12ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2912 - auc: 0.9478 - val_loss: 0.3158 - val_auc: 0.9405 - 2s/epoch - 10ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2903 - auc: 0.9478 - val_loss: 0.3117 - val_auc: 0.9419 - 2s/epoch - 10ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2893 - auc: 0.9483 - val_loss: 0.3286 - val_auc: 0.9354 - 2s/epoch - 10ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2876 - auc: 0.9489 - val_loss: 0.3120 - val_auc: 0.9413 - 2s/epoch - 10ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2877 - auc: 0.9487 - val_loss: 0.3112 - val_auc: 0.9427 - 2s/epoch - 10ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2870 - auc: 0.9492 - val_loss: 0.3091 - val_auc: 0.9437 - 2s/epoch - 13ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2860 - auc: 0.9496 - val_loss: 0.3254 - val_auc: 0.9372 - 2s/epoch - 10ms/step
# Epoch 61/64
# 183/183 - 2s - loss: 0.2873 - auc: 0.9490 - val_loss: 0.3321 - val_auc: 0.9361 - 2s/epoch - 10ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2864 - auc: 0.9492 - val_loss: 0.3132 - val_auc: 0.9437 - 2s/epoch - 10ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2837 - auc: 0.9503 - val_loss: 0.3351 - val_auc: 0.9346 - 2s/epoch - 10ms/step
# Epoch 64/64
# 183/183 - 2s - loss: 0.2825 - auc: 0.9506 - val_loss: 0.3238 - val_auc: 0.9376 - 2s/epoch - 10ms/step
# 46/46 [==============================] - 1s 7ms/step
#
# Training on Fold 2...
# Epoch 1/64
# 183/183 - 8s - loss: 0.4888 - auc_1: 0.8286 - val_loss: 0.4334 - val_auc_1: 0.8706 - 8s/epoch - 45ms/step
# Epoch 2/64
# 183/183 - 2s - loss: 0.4434 - auc_1: 0.8383 - val_loss: 0.4314 - val_auc_1: 0.8957 - 2s/epoch - 12ms/step
# Epoch 3/64
# 183/183 - 2s - loss: 0.4257 - auc_1: 0.8694 - val_loss: 0.4619 - val_auc_1: 0.9168 - 2s/epoch - 13ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.4011 - auc_1: 0.8961 - val_loss: 0.3767 - val_auc_1: 0.9203 - 2s/epoch - 10ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3872 - auc_1: 0.9045 - val_loss: 0.3850 - val_auc_1: 0.9301 - 2s/epoch - 10ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3681 - auc_1: 0.9148 - val_loss: 0.3693 - val_auc_1: 0.9333 - 2s/epoch - 10ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3544 - auc_1: 0.9216 - val_loss: 0.3202 - val_auc_1: 0.9384 - 2s/epoch - 10ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3463 - auc_1: 0.9255 - val_loss: 0.3276 - val_auc_1: 0.9377 - 2s/epoch - 11ms/step
# Epoch 9/64
# 183/183 - 2s - loss: 0.3438 - auc_1: 0.9269 - val_loss: 0.3247 - val_auc_1: 0.9377 - 2s/epoch - 12ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3418 - auc_1: 0.9275 - val_loss: 0.3138 - val_auc_1: 0.9404 - 2s/epoch - 10ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3361 - auc_1: 0.9302 - val_loss: 0.3201 - val_auc_1: 0.9399 - 2s/epoch - 10ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3379 - auc_1: 0.9291 - val_loss: 0.3179 - val_auc_1: 0.9389 - 2s/epoch - 10ms/step
# Epoch 13/64
# 183/183 - 2s - loss: 0.3334 - auc_1: 0.9312 - val_loss: 0.3535 - val_auc_1: 0.9328 - 2s/epoch - 10ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3359 - auc_1: 0.9302 - val_loss: 0.3144 - val_auc_1: 0.9394 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3307 - auc_1: 0.9320 - val_loss: 0.3297 - val_auc_1: 0.9358 - 2s/epoch - 13ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3310 - auc_1: 0.9324 - val_loss: 0.3109 - val_auc_1: 0.9410 - 2s/epoch - 10ms/step
# Epoch 17/64
# 183/183 - 2s - loss: 0.3276 - auc_1: 0.9339 - val_loss: 0.3337 - val_auc_1: 0.9391 - 2s/epoch - 10ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3277 - auc_1: 0.9335 - val_loss: 0.3178 - val_auc_1: 0.9407 - 2s/epoch - 11ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3164 - auc_1: 0.9382 - val_loss: 0.3090 - val_auc_1: 0.9415 - 2s/epoch - 10ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3254 - auc_1: 0.9345 - val_loss: 0.3066 - val_auc_1: 0.9439 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3161 - auc_1: 0.9384 - val_loss: 0.3108 - val_auc_1: 0.9409 - 2s/epoch - 13ms/step
# Epoch 22/64
# 183/183 - 2s - loss: 0.3170 - auc_1: 0.9379 - val_loss: 0.3056 - val_auc_1: 0.9448 - 2s/epoch - 10ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3146 - auc_1: 0.9387 - val_loss: 0.3009 - val_auc_1: 0.9445 - 2s/epoch - 10ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.3150 - auc_1: 0.9386 - val_loss: 0.3039 - val_auc_1: 0.9450 - 2s/epoch - 10ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.3154 - auc_1: 0.9382 - val_loss: 0.3112 - val_auc_1: 0.9417 - 2s/epoch - 10ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.3096 - auc_1: 0.9409 - val_loss: 0.3050 - val_auc_1: 0.9444 - 2s/epoch - 10ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.3149 - auc_1: 0.9390 - val_loss: 0.3147 - val_auc_1: 0.9416 - 2s/epoch - 13ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.3051 - auc_1: 0.9428 - val_loss: 0.3241 - val_auc_1: 0.9417 - 2s/epoch - 11ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.3073 - auc_1: 0.9420 - val_loss: 0.3283 - val_auc_1: 0.9394 - 2s/epoch - 10ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.3054 - auc_1: 0.9426 - val_loss: 0.2924 - val_auc_1: 0.9477 - 2s/epoch - 10ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.3034 - auc_1: 0.9434 - val_loss: 0.2992 - val_auc_1: 0.9461 - 2s/epoch - 10ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.3070 - auc_1: 0.9421 - val_loss: 0.2956 - val_auc_1: 0.9469 - 2s/epoch - 11ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.3006 - auc_1: 0.9443 - val_loss: 0.2961 - val_auc_1: 0.9470 - 2s/epoch - 13ms/step
# Epoch 34/64
# 183/183 - 2s - loss: 0.3048 - auc_1: 0.9431 - val_loss: 0.3084 - val_auc_1: 0.9419 - 2s/epoch - 10ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.3070 - auc_1: 0.9420 - val_loss: 0.2984 - val_auc_1: 0.9462 - 2s/epoch - 10ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.3022 - auc_1: 0.9439 - val_loss: 0.3045 - val_auc_1: 0.9452 - 2s/epoch - 10ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.3022 - auc_1: 0.9437 - val_loss: 0.3155 - val_auc_1: 0.9406 - 2s/epoch - 10ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.2967 - auc_1: 0.9460 - val_loss: 0.2960 - val_auc_1: 0.9468 - 2s/epoch - 10ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.2941 - auc_1: 0.9468 - val_loss: 0.3072 - val_auc_1: 0.9453 - 2s/epoch - 12ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.2995 - auc_1: 0.9448 - val_loss: 0.2960 - val_auc_1: 0.9472 - 2s/epoch - 11ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.2966 - auc_1: 0.9461 - val_loss: 0.3324 - val_auc_1: 0.9366 - 2s/epoch - 10ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.2956 - auc_1: 0.9461 - val_loss: 0.3149 - val_auc_1: 0.9410 - 2s/epoch - 10ms/step
# Epoch 43/64
# 183/183 - 2s - loss: 0.2963 - auc_1: 0.9460 - val_loss: 0.3030 - val_auc_1: 0.9450 - 2s/epoch - 10ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.2945 - auc_1: 0.9467 - val_loss: 0.3048 - val_auc_1: 0.9455 - 2s/epoch - 10ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2926 - auc_1: 0.9474 - val_loss: 0.3051 - val_auc_1: 0.9463 - 2s/epoch - 13ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2920 - auc_1: 0.9476 - val_loss: 0.3101 - val_auc_1: 0.9414 - 2s/epoch - 10ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.2933 - auc_1: 0.9472 - val_loss: 0.3010 - val_auc_1: 0.9461 - 2s/epoch - 10ms/step
# Epoch 48/64
# 183/183 - 2s - loss: 0.2963 - auc_1: 0.9460 - val_loss: 0.3066 - val_auc_1: 0.9446 - 2s/epoch - 10ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2928 - auc_1: 0.9473 - val_loss: 0.3124 - val_auc_1: 0.9401 - 2s/epoch - 10ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2939 - auc_1: 0.9469 - val_loss: 0.3366 - val_auc_1: 0.9310 - 2s/epoch - 10ms/step
# Epoch 51/64
# 183/183 - 3s - loss: 0.2893 - auc_1: 0.9487 - val_loss: 0.3067 - val_auc_1: 0.9425 - 3s/epoch - 14ms/step
# Epoch 52/64
# 183/183 - 2s - loss: 0.2939 - auc_1: 0.9471 - val_loss: 0.3046 - val_auc_1: 0.9446 - 2s/epoch - 10ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2869 - auc_1: 0.9494 - val_loss: 0.2941 - val_auc_1: 0.9481 - 2s/epoch - 10ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2869 - auc_1: 0.9496 - val_loss: 0.2993 - val_auc_1: 0.9456 - 2s/epoch - 10ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2869 - auc_1: 0.9495 - val_loss: 0.3137 - val_auc_1: 0.9421 - 2s/epoch - 10ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2894 - auc_1: 0.9485 - val_loss: 0.2984 - val_auc_1: 0.9469 - 2s/epoch - 10ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2868 - auc_1: 0.9491 - val_loss: 0.2938 - val_auc_1: 0.9482 - 2s/epoch - 12ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2844 - auc_1: 0.9499 - val_loss: 0.3054 - val_auc_1: 0.9432 - 2s/epoch - 10ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2861 - auc_1: 0.9497 - val_loss: 0.3317 - val_auc_1: 0.9327 - 2s/epoch - 10ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2831 - auc_1: 0.9510 - val_loss: 0.3395 - val_auc_1: 0.9339 - 2s/epoch - 10ms/step
# Epoch 61/64
# 183/183 - 2s - loss: 0.2840 - auc_1: 0.9503 - val_loss: 0.3177 - val_auc_1: 0.9395 - 2s/epoch - 10ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2844 - auc_1: 0.9498 - val_loss: 0.3126 - val_auc_1: 0.9407 - 2s/epoch - 10ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2872 - auc_1: 0.9491 - val_loss: 0.3079 - val_auc_1: 0.9442 - 2s/epoch - 13ms/step
# Epoch 64/64
# 183/183 - 2s - loss: 0.2780 - auc_1: 0.9525 - val_loss: 0.3145 - val_auc_1: 0.9398 - 2s/epoch - 10ms/step
# 46/46 [==============================] - 1s 5ms/step
#
# Training on Fold 3...
# Epoch 1/64
# 183/183 - 9s - loss: 0.4535 - auc_2: 0.8452 - val_loss: 0.4348 - val_auc_2: 0.8790 - 9s/epoch - 49ms/step
# Epoch 2/64
# 183/183 - 2s - loss: 0.4394 - auc_2: 0.8498 - val_loss: 0.4190 - val_auc_2: 0.9159 - 2s/epoch - 11ms/step
# Epoch 3/64
# 183/183 - 2s - loss: 0.4059 - auc_2: 0.8924 - val_loss: 0.3649 - val_auc_2: 0.9194 - 2s/epoch - 10ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.3689 - auc_2: 0.9149 - val_loss: 0.3675 - val_auc_2: 0.9224 - 2s/epoch - 11ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3644 - auc_2: 0.9170 - val_loss: 0.3579 - val_auc_2: 0.9239 - 2s/epoch - 10ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3535 - auc_2: 0.9223 - val_loss: 0.3542 - val_auc_2: 0.9247 - 2s/epoch - 10ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3456 - auc_2: 0.9260 - val_loss: 0.3503 - val_auc_2: 0.9258 - 2s/epoch - 13ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3413 - auc_2: 0.9279 - val_loss: 0.3503 - val_auc_2: 0.9248 - 2s/epoch - 11ms/step
# Epoch 9/64
# 183/183 - 2s - loss: 0.3377 - auc_2: 0.9295 - val_loss: 0.3510 - val_auc_2: 0.9267 - 2s/epoch - 10ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3387 - auc_2: 0.9290 - val_loss: 0.3725 - val_auc_2: 0.9170 - 2s/epoch - 11ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3423 - auc_2: 0.9271 - val_loss: 0.3500 - val_auc_2: 0.9256 - 2s/epoch - 10ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3347 - auc_2: 0.9305 - val_loss: 0.3674 - val_auc_2: 0.9274 - 2s/epoch - 10ms/step
# Epoch 13/64
# 183/183 - 2s - loss: 0.3339 - auc_2: 0.9308 - val_loss: 0.3465 - val_auc_2: 0.9261 - 2s/epoch - 13ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3339 - auc_2: 0.9303 - val_loss: 0.3460 - val_auc_2: 0.9279 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3258 - auc_2: 0.9342 - val_loss: 0.3533 - val_auc_2: 0.9271 - 2s/epoch - 10ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3260 - auc_2: 0.9337 - val_loss: 0.3529 - val_auc_2: 0.9288 - 2s/epoch - 10ms/step
# Epoch 17/64
# 183/183 - 2s - loss: 0.3294 - auc_2: 0.9327 - val_loss: 0.3893 - val_auc_2: 0.9132 - 2s/epoch - 10ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3287 - auc_2: 0.9328 - val_loss: 0.3474 - val_auc_2: 0.9282 - 2s/epoch - 10ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3239 - auc_2: 0.9345 - val_loss: 0.3559 - val_auc_2: 0.9240 - 2s/epoch - 13ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3271 - auc_2: 0.9340 - val_loss: 0.3462 - val_auc_2: 0.9286 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3246 - auc_2: 0.9345 - val_loss: 0.3498 - val_auc_2: 0.9271 - 2s/epoch - 10ms/step
# Epoch 22/64
# 183/183 - 2s - loss: 0.3229 - auc_2: 0.9354 - val_loss: 0.3427 - val_auc_2: 0.9297 - 2s/epoch - 10ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3222 - auc_2: 0.9355 - val_loss: 0.3445 - val_auc_2: 0.9290 - 2s/epoch - 10ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.3212 - auc_2: 0.9360 - val_loss: 0.4138 - val_auc_2: 0.8929 - 2s/epoch - 10ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.3183 - auc_2: 0.9371 - val_loss: 0.3361 - val_auc_2: 0.9320 - 2s/epoch - 13ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.3156 - auc_2: 0.9379 - val_loss: 0.3488 - val_auc_2: 0.9270 - 2s/epoch - 10ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.3158 - auc_2: 0.9383 - val_loss: 0.3334 - val_auc_2: 0.9318 - 2s/epoch - 10ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.3131 - auc_2: 0.9392 - val_loss: 0.3641 - val_auc_2: 0.9205 - 2s/epoch - 10ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.3115 - auc_2: 0.9400 - val_loss: 0.3312 - val_auc_2: 0.9325 - 2s/epoch - 10ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.3088 - auc_2: 0.9408 - val_loss: 0.3289 - val_auc_2: 0.9353 - 2s/epoch - 10ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.3037 - auc_2: 0.9429 - val_loss: 0.3324 - val_auc_2: 0.9333 - 2s/epoch - 13ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.3092 - auc_2: 0.9410 - val_loss: 0.3420 - val_auc_2: 0.9287 - 2s/epoch - 10ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.3047 - auc_2: 0.9425 - val_loss: 0.3471 - val_auc_2: 0.9266 - 2s/epoch - 10ms/step
# Epoch 34/64
# 183/183 - 2s - loss: 0.3044 - auc_2: 0.9427 - val_loss: 0.3337 - val_auc_2: 0.9328 - 2s/epoch - 10ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.3067 - auc_2: 0.9418 - val_loss: 0.3335 - val_auc_2: 0.9340 - 2s/epoch - 10ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.3086 - auc_2: 0.9409 - val_loss: 0.3325 - val_auc_2: 0.9322 - 2s/epoch - 10ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.2982 - auc_2: 0.9451 - val_loss: 0.3272 - val_auc_2: 0.9344 - 2s/epoch - 13ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.3068 - auc_2: 0.9418 - val_loss: 0.3311 - val_auc_2: 0.9343 - 2s/epoch - 10ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.3069 - auc_2: 0.9416 - val_loss: 0.3233 - val_auc_2: 0.9360 - 2s/epoch - 10ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.3020 - auc_2: 0.9435 - val_loss: 0.3362 - val_auc_2: 0.9313 - 2s/epoch - 10ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.3006 - auc_2: 0.9442 - val_loss: 0.3237 - val_auc_2: 0.9373 - 2s/epoch - 10ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.3003 - auc_2: 0.9443 - val_loss: 0.3290 - val_auc_2: 0.9346 - 2s/epoch - 11ms/step
# Epoch 43/64
# 183/183 - 2s - loss: 0.3057 - auc_2: 0.9423 - val_loss: 0.3303 - val_auc_2: 0.9350 - 2s/epoch - 12ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.3016 - auc_2: 0.9440 - val_loss: 0.3370 - val_auc_2: 0.9318 - 2s/epoch - 10ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2912 - auc_2: 0.9476 - val_loss: 0.3536 - val_auc_2: 0.9236 - 2s/epoch - 10ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2947 - auc_2: 0.9467 - val_loss: 0.3310 - val_auc_2: 0.9346 - 2s/epoch - 10ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.2960 - auc_2: 0.9459 - val_loss: 0.3326 - val_auc_2: 0.9354 - 2s/epoch - 10ms/step
# Epoch 48/64
# 183/183 - 2s - loss: 0.2935 - auc_2: 0.9467 - val_loss: 0.3383 - val_auc_2: 0.9317 - 2s/epoch - 10ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2937 - auc_2: 0.9467 - val_loss: 0.3243 - val_auc_2: 0.9366 - 2s/epoch - 13ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2949 - auc_2: 0.9462 - val_loss: 0.3323 - val_auc_2: 0.9332 - 2s/epoch - 10ms/step
# Epoch 51/64
# 183/183 - 2s - loss: 0.2923 - auc_2: 0.9472 - val_loss: 0.3225 - val_auc_2: 0.9370 - 2s/epoch - 10ms/step
# Epoch 52/64
# 183/183 - 2s - loss: 0.2946 - auc_2: 0.9464 - val_loss: 0.3432 - val_auc_2: 0.9291 - 2s/epoch - 10ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2928 - auc_2: 0.9474 - val_loss: 0.3239 - val_auc_2: 0.9382 - 2s/epoch - 10ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2928 - auc_2: 0.9472 - val_loss: 0.3231 - val_auc_2: 0.9367 - 2s/epoch - 10ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2911 - auc_2: 0.9477 - val_loss: 0.3302 - val_auc_2: 0.9370 - 2s/epoch - 13ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2937 - auc_2: 0.9467 - val_loss: 0.3301 - val_auc_2: 0.9338 - 2s/epoch - 10ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2914 - auc_2: 0.9476 - val_loss: 0.3261 - val_auc_2: 0.9343 - 2s/epoch - 10ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2920 - auc_2: 0.9474 - val_loss: 0.3210 - val_auc_2: 0.9377 - 2s/epoch - 10ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2896 - auc_2: 0.9482 - val_loss: 0.3386 - val_auc_2: 0.9317 - 2s/epoch - 10ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2947 - auc_2: 0.9465 - val_loss: 0.3378 - val_auc_2: 0.9316 - 2s/epoch - 10ms/step
# Epoch 61/64
# 183/183 - 3s - loss: 0.2871 - auc_2: 0.9492 - val_loss: 0.3479 - val_auc_2: 0.9267 - 3s/epoch - 14ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2878 - auc_2: 0.9493 - val_loss: 0.3241 - val_auc_2: 0.9377 - 2s/epoch - 10ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2830 - auc_2: 0.9509 - val_loss: 0.3391 - val_auc_2: 0.9303 - 2s/epoch - 10ms/step
# Epoch 64/64
# 183/183 - 2s - loss: 0.2860 - auc_2: 0.9498 - val_loss: 0.3575 - val_auc_2: 0.9219 - 2s/epoch - 10ms/step
# 46/46 [==============================] - 1s 7ms/step
#
# Training on Fold 4...
# Epoch 1/64
# 183/183 - 9s - loss: 0.4466 - auc_3: 0.8426 - val_loss: 0.4323 - val_auc_3: 0.8460 - 9s/epoch - 47ms/step
# Epoch 2/64
# 183/183 - 2s - loss: 0.4368 - auc_3: 0.8486 - val_loss: 0.4234 - val_auc_3: 0.9020 - 2s/epoch - 12ms/step
# Epoch 3/64
# 183/183 - 2s - loss: 0.3968 - auc_3: 0.8992 - val_loss: 0.3736 - val_auc_3: 0.9119 - 2s/epoch - 10ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.3774 - auc_3: 0.9106 - val_loss: 0.3667 - val_auc_3: 0.9159 - 2s/epoch - 13ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3689 - auc_3: 0.9150 - val_loss: 0.3949 - val_auc_3: 0.9153 - 2s/epoch - 10ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3499 - auc_3: 0.9241 - val_loss: 0.3589 - val_auc_3: 0.9218 - 2s/epoch - 10ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3502 - auc_3: 0.9236 - val_loss: 0.3681 - val_auc_3: 0.9223 - 2s/epoch - 10ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3409 - auc_3: 0.9279 - val_loss: 0.3519 - val_auc_3: 0.9226 - 2s/epoch - 10ms/step
# Epoch 9/64
# 183/183 - 2s - loss: 0.3339 - auc_3: 0.9313 - val_loss: 0.3770 - val_auc_3: 0.9240 - 2s/epoch - 10ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3386 - auc_3: 0.9292 - val_loss: 0.3652 - val_auc_3: 0.9241 - 2s/epoch - 12ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3278 - auc_3: 0.9338 - val_loss: 0.3443 - val_auc_3: 0.9262 - 2s/epoch - 10ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3336 - auc_3: 0.9310 - val_loss: 0.3560 - val_auc_3: 0.9235 - 2s/epoch - 10ms/step
# Epoch 13/64
# 183/183 - 2s - loss: 0.3247 - auc_3: 0.9350 - val_loss: 0.3468 - val_auc_3: 0.9258 - 2s/epoch - 10ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3274 - auc_3: 0.9336 - val_loss: 0.3469 - val_auc_3: 0.9266 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3252 - auc_3: 0.9351 - val_loss: 0.3596 - val_auc_3: 0.9219 - 2s/epoch - 10ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3219 - auc_3: 0.9361 - val_loss: 0.3484 - val_auc_3: 0.9265 - 2s/epoch - 13ms/step
# Epoch 17/64
# 183/183 - 2s - loss: 0.3252 - auc_3: 0.9349 - val_loss: 0.3712 - val_auc_3: 0.9187 - 2s/epoch - 10ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3194 - auc_3: 0.9370 - val_loss: 0.3560 - val_auc_3: 0.9264 - 2s/epoch - 10ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3184 - auc_3: 0.9372 - val_loss: 0.3407 - val_auc_3: 0.9280 - 2s/epoch - 10ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3154 - auc_3: 0.9387 - val_loss: 0.3442 - val_auc_3: 0.9273 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3158 - auc_3: 0.9381 - val_loss: 0.3354 - val_auc_3: 0.9305 - 2s/epoch - 10ms/step
# Epoch 22/64
# 183/183 - 3s - loss: 0.3123 - auc_3: 0.9398 - val_loss: 0.3565 - val_auc_3: 0.9241 - 3s/epoch - 14ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3101 - auc_3: 0.9408 - val_loss: 0.3612 - val_auc_3: 0.9242 - 2s/epoch - 10ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.3081 - auc_3: 0.9414 - val_loss: 0.3484 - val_auc_3: 0.9258 - 2s/epoch - 10ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.3139 - auc_3: 0.9391 - val_loss: 0.3468 - val_auc_3: 0.9263 - 2s/epoch - 10ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.3083 - auc_3: 0.9413 - val_loss: 0.3581 - val_auc_3: 0.9214 - 2s/epoch - 10ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.3177 - auc_3: 0.9379 - val_loss: 0.3518 - val_auc_3: 0.9248 - 2s/epoch - 11ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.3122 - auc_3: 0.9396 - val_loss: 0.3407 - val_auc_3: 0.9285 - 2s/epoch - 12ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.3087 - auc_3: 0.9415 - val_loss: 0.3624 - val_auc_3: 0.9238 - 2s/epoch - 10ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.3025 - auc_3: 0.9438 - val_loss: 0.3411 - val_auc_3: 0.9290 - 2s/epoch - 10ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.3021 - auc_3: 0.9436 - val_loss: 0.3430 - val_auc_3: 0.9292 - 2s/epoch - 10ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.3048 - auc_3: 0.9427 - val_loss: 0.3616 - val_auc_3: 0.9216 - 2s/epoch - 10ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.3023 - auc_3: 0.9436 - val_loss: 0.3646 - val_auc_3: 0.9194 - 2s/epoch - 10ms/step
# Epoch 34/64
# 183/183 - 3s - loss: 0.2997 - auc_3: 0.9446 - val_loss: 0.3485 - val_auc_3: 0.9280 - 3s/epoch - 14ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.3046 - auc_3: 0.9428 - val_loss: 0.3388 - val_auc_3: 0.9304 - 2s/epoch - 10ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.3078 - auc_3: 0.9418 - val_loss: 0.3594 - val_auc_3: 0.9289 - 2s/epoch - 10ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.3049 - auc_3: 0.9429 - val_loss: 0.3426 - val_auc_3: 0.9295 - 2s/epoch - 10ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.3016 - auc_3: 0.9441 - val_loss: 0.3813 - val_auc_3: 0.9112 - 2s/epoch - 10ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.2979 - auc_3: 0.9455 - val_loss: 0.3401 - val_auc_3: 0.9310 - 2s/epoch - 10ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.3008 - auc_3: 0.9443 - val_loss: 0.3398 - val_auc_3: 0.9309 - 2s/epoch - 13ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.2985 - auc_3: 0.9453 - val_loss: 0.3397 - val_auc_3: 0.9295 - 2s/epoch - 10ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.3001 - auc_3: 0.9447 - val_loss: 0.3434 - val_auc_3: 0.9294 - 2s/epoch - 10ms/step
# Epoch 43/64
# 183/183 - 2s - loss: 0.2968 - auc_3: 0.9459 - val_loss: 0.3489 - val_auc_3: 0.9325 - 2s/epoch - 10ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.3007 - auc_3: 0.9445 - val_loss: 0.3533 - val_auc_3: 0.9256 - 2s/epoch - 10ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2981 - auc_3: 0.9455 - val_loss: 0.3513 - val_auc_3: 0.9272 - 2s/epoch - 10ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2928 - auc_3: 0.9475 - val_loss: 0.3754 - val_auc_3: 0.9191 - 2s/epoch - 13ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.2930 - auc_3: 0.9472 - val_loss: 0.3282 - val_auc_3: 0.9350 - 2s/epoch - 10ms/step
# Epoch 48/64
# 183/183 - 2s - loss: 0.2957 - auc_3: 0.9466 - val_loss: 0.3309 - val_auc_3: 0.9342 - 2s/epoch - 10ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2979 - auc_3: 0.9455 - val_loss: 0.3395 - val_auc_3: 0.9313 - 2s/epoch - 10ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2900 - auc_3: 0.9485 - val_loss: 0.3488 - val_auc_3: 0.9283 - 2s/epoch - 10ms/step
# Epoch 51/64
# 183/183 - 2s - loss: 0.2880 - auc_3: 0.9491 - val_loss: 0.3378 - val_auc_3: 0.9327 - 2s/epoch - 10ms/step
# Epoch 52/64
# 183/183 - 3s - loss: 0.2911 - auc_3: 0.9481 - val_loss: 0.3392 - val_auc_3: 0.9308 - 3s/epoch - 14ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2854 - auc_3: 0.9499 - val_loss: 0.3357 - val_auc_3: 0.9327 - 2s/epoch - 10ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2848 - auc_3: 0.9500 - val_loss: 0.3391 - val_auc_3: 0.9312 - 2s/epoch - 10ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2905 - auc_3: 0.9482 - val_loss: 0.3297 - val_auc_3: 0.9327 - 2s/epoch - 10ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2887 - auc_3: 0.9490 - val_loss: 0.3319 - val_auc_3: 0.9332 - 2s/epoch - 10ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2891 - auc_3: 0.9487 - val_loss: 0.3442 - val_auc_3: 0.9293 - 2s/epoch - 10ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2857 - auc_3: 0.9500 - val_loss: 0.3333 - val_auc_3: 0.9327 - 2s/epoch - 13ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2893 - auc_3: 0.9487 - val_loss: 0.3361 - val_auc_3: 0.9326 - 2s/epoch - 10ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2825 - auc_3: 0.9511 - val_loss: 0.3417 - val_auc_3: 0.9303 - 2s/epoch - 10ms/step
# Epoch 61/64
# 183/183 - 2s - loss: 0.2806 - auc_3: 0.9516 - val_loss: 0.3539 - val_auc_3: 0.9320 - 2s/epoch - 10ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2844 - auc_3: 0.9502 - val_loss: 0.3336 - val_auc_3: 0.9332 - 2s/epoch - 10ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2830 - auc_3: 0.9508 - val_loss: 0.3323 - val_auc_3: 0.9358 - 2s/epoch - 10ms/step
# Epoch 64/64
# 183/183 - 3s - loss: 0.2861 - auc_3: 0.9496 - val_loss: 0.3340 - val_auc_3: 0.9317 - 3s/epoch - 14ms/step
# 46/46 [==============================] - 1s 6ms/step
#
# Training on Fold 5...
# Epoch 1/64
# 183/183 - 9s - loss: 0.4470 - auc_4: 0.8457 - val_loss: 0.4314 - val_auc_4: 0.8955 - 9s/epoch - 48ms/step
# Epoch 2/64
# 183/183 - 2s - loss: 0.4346 - auc_4: 0.8576 - val_loss: 0.3705 - val_auc_4: 0.9214 - 2s/epoch - 10ms/step
# Epoch 3/64
# 183/183 - 2s - loss: 0.4025 - auc_4: 0.8940 - val_loss: 0.3701 - val_auc_4: 0.9258 - 2s/epoch - 10ms/step
# Epoch 4/64
# 183/183 - 2s - loss: 0.3779 - auc_4: 0.9103 - val_loss: 0.3546 - val_auc_4: 0.9299 - 2s/epoch - 10ms/step
# Epoch 5/64
# 183/183 - 2s - loss: 0.3584 - auc_4: 0.9204 - val_loss: 0.3386 - val_auc_4: 0.9307 - 2s/epoch - 11ms/step
# Epoch 6/64
# 183/183 - 2s - loss: 0.3584 - auc_4: 0.9205 - val_loss: 0.3396 - val_auc_4: 0.9295 - 2s/epoch - 12ms/step
# Epoch 7/64
# 183/183 - 2s - loss: 0.3463 - auc_4: 0.9258 - val_loss: 0.3443 - val_auc_4: 0.9321 - 2s/epoch - 11ms/step
# Epoch 8/64
# 183/183 - 2s - loss: 0.3481 - auc_4: 0.9251 - val_loss: 0.3373 - val_auc_4: 0.9314 - 2s/epoch - 11ms/step
# Epoch 9/64
# 183/183 - 2s - loss: 0.3445 - auc_4: 0.9266 - val_loss: 0.3478 - val_auc_4: 0.9290 - 2s/epoch - 10ms/step
# Epoch 10/64
# 183/183 - 2s - loss: 0.3354 - auc_4: 0.9304 - val_loss: 0.3310 - val_auc_4: 0.9320 - 2s/epoch - 10ms/step
# Epoch 11/64
# 183/183 - 2s - loss: 0.3330 - auc_4: 0.9313 - val_loss: 0.3624 - val_auc_4: 0.9303 - 2s/epoch - 10ms/step
# Epoch 12/64
# 183/183 - 2s - loss: 0.3390 - auc_4: 0.9285 - val_loss: 0.3660 - val_auc_4: 0.9307 - 2s/epoch - 13ms/step
# Epoch 13/64
# 183/183 - 2s - loss: 0.3332 - auc_4: 0.9311 - val_loss: 0.3268 - val_auc_4: 0.9348 - 2s/epoch - 11ms/step
# Epoch 14/64
# 183/183 - 2s - loss: 0.3263 - auc_4: 0.9340 - val_loss: 0.3395 - val_auc_4: 0.9334 - 2s/epoch - 10ms/step
# Epoch 15/64
# 183/183 - 2s - loss: 0.3310 - auc_4: 0.9318 - val_loss: 0.3406 - val_auc_4: 0.9316 - 2s/epoch - 10ms/step
# Epoch 16/64
# 183/183 - 2s - loss: 0.3273 - auc_4: 0.9337 - val_loss: 0.3248 - val_auc_4: 0.9366 - 2s/epoch - 10ms/step
# Epoch 17/64
# 183/183 - 2s - loss: 0.3305 - auc_4: 0.9321 - val_loss: 0.3628 - val_auc_4: 0.9290 - 2s/epoch - 10ms/step
# Epoch 18/64
# 183/183 - 2s - loss: 0.3306 - auc_4: 0.9325 - val_loss: 0.3369 - val_auc_4: 0.9319 - 2s/epoch - 13ms/step
# Epoch 19/64
# 183/183 - 2s - loss: 0.3172 - auc_4: 0.9377 - val_loss: 0.3241 - val_auc_4: 0.9356 - 2s/epoch - 10ms/step
# Epoch 20/64
# 183/183 - 2s - loss: 0.3189 - auc_4: 0.9367 - val_loss: 0.3411 - val_auc_4: 0.9326 - 2s/epoch - 10ms/step
# Epoch 21/64
# 183/183 - 2s - loss: 0.3196 - auc_4: 0.9366 - val_loss: 0.3389 - val_auc_4: 0.9360 - 2s/epoch - 10ms/step
# Epoch 22/64
# 183/183 - 2s - loss: 0.3213 - auc_4: 0.9360 - val_loss: 0.3218 - val_auc_4: 0.9363 - 2s/epoch - 10ms/step
# Epoch 23/64
# 183/183 - 2s - loss: 0.3145 - auc_4: 0.9383 - val_loss: 0.3265 - val_auc_4: 0.9377 - 2s/epoch - 10ms/step
# Epoch 24/64
# 183/183 - 2s - loss: 0.3126 - auc_4: 0.9395 - val_loss: 0.3322 - val_auc_4: 0.9363 - 2s/epoch - 12ms/step
# Epoch 25/64
# 183/183 - 2s - loss: 0.3198 - auc_4: 0.9367 - val_loss: 0.3238 - val_auc_4: 0.9383 - 2s/epoch - 10ms/step
# Epoch 26/64
# 183/183 - 2s - loss: 0.3139 - auc_4: 0.9386 - val_loss: 0.3164 - val_auc_4: 0.9416 - 2s/epoch - 10ms/step
# Epoch 27/64
# 183/183 - 2s - loss: 0.3159 - auc_4: 0.9382 - val_loss: 0.3266 - val_auc_4: 0.9357 - 2s/epoch - 10ms/step
# Epoch 28/64
# 183/183 - 2s - loss: 0.3099 - auc_4: 0.9407 - val_loss: 0.3095 - val_auc_4: 0.9414 - 2s/epoch - 10ms/step
# Epoch 29/64
# 183/183 - 2s - loss: 0.3083 - auc_4: 0.9412 - val_loss: 0.3608 - val_auc_4: 0.9273 - 2s/epoch - 10ms/step
# Epoch 30/64
# 183/183 - 2s - loss: 0.3104 - auc_4: 0.9407 - val_loss: 0.3109 - val_auc_4: 0.9420 - 2s/epoch - 12ms/step
# Epoch 31/64
# 183/183 - 2s - loss: 0.3027 - auc_4: 0.9431 - val_loss: 0.3107 - val_auc_4: 0.9421 - 2s/epoch - 11ms/step
# Epoch 32/64
# 183/183 - 2s - loss: 0.3058 - auc_4: 0.9425 - val_loss: 0.3262 - val_auc_4: 0.9366 - 2s/epoch - 10ms/step
# Epoch 33/64
# 183/183 - 2s - loss: 0.2979 - auc_4: 0.9452 - val_loss: 0.3128 - val_auc_4: 0.9430 - 2s/epoch - 10ms/step
# Epoch 34/64
# 183/183 - 2s - loss: 0.3070 - auc_4: 0.9419 - val_loss: 0.3175 - val_auc_4: 0.9386 - 2s/epoch - 10ms/step
# Epoch 35/64
# 183/183 - 2s - loss: 0.3033 - auc_4: 0.9434 - val_loss: 0.3242 - val_auc_4: 0.9356 - 2s/epoch - 10ms/step
# Epoch 36/64
# 183/183 - 2s - loss: 0.2983 - auc_4: 0.9454 - val_loss: 0.3327 - val_auc_4: 0.9332 - 2s/epoch - 12ms/step
# Epoch 37/64
# 183/183 - 2s - loss: 0.3078 - auc_4: 0.9416 - val_loss: 0.3179 - val_auc_4: 0.9385 - 2s/epoch - 11ms/step
# Epoch 38/64
# 183/183 - 2s - loss: 0.3012 - auc_4: 0.9439 - val_loss: 0.3191 - val_auc_4: 0.9392 - 2s/epoch - 10ms/step
# Epoch 39/64
# 183/183 - 2s - loss: 0.2966 - auc_4: 0.9458 - val_loss: 0.3061 - val_auc_4: 0.9429 - 2s/epoch - 10ms/step
# Epoch 40/64
# 183/183 - 2s - loss: 0.2998 - auc_4: 0.9447 - val_loss: 0.3128 - val_auc_4: 0.9404 - 2s/epoch - 10ms/step
# Epoch 41/64
# 183/183 - 2s - loss: 0.2972 - auc_4: 0.9455 - val_loss: 0.3181 - val_auc_4: 0.9396 - 2s/epoch - 10ms/step
# Epoch 42/64
# 183/183 - 2s - loss: 0.3059 - auc_4: 0.9417 - val_loss: 0.3480 - val_auc_4: 0.9305 - 2s/epoch - 11ms/step
# Epoch 43/64
# 183/183 - 2s - loss: 0.2969 - auc_4: 0.9457 - val_loss: 0.3056 - val_auc_4: 0.9445 - 2s/epoch - 11ms/step
# Epoch 44/64
# 183/183 - 2s - loss: 0.2992 - auc_4: 0.9449 - val_loss: 0.3133 - val_auc_4: 0.9421 - 2s/epoch - 10ms/step
# Epoch 45/64
# 183/183 - 2s - loss: 0.2957 - auc_4: 0.9463 - val_loss: 0.3039 - val_auc_4: 0.9452 - 2s/epoch - 11ms/step
# Epoch 46/64
# 183/183 - 2s - loss: 0.2927 - auc_4: 0.9475 - val_loss: 0.3249 - val_auc_4: 0.9363 - 2s/epoch - 10ms/step
# Epoch 47/64
# 183/183 - 2s - loss: 0.2918 - auc_4: 0.9476 - val_loss: 0.3021 - val_auc_4: 0.9452 - 2s/epoch - 10ms/step
# Epoch 48/64
# 183/183 - 2s - loss: 0.2905 - auc_4: 0.9481 - val_loss: 0.3236 - val_auc_4: 0.9369 - 2s/epoch - 12ms/step
# Epoch 49/64
# 183/183 - 2s - loss: 0.2908 - auc_4: 0.9481 - val_loss: 0.3067 - val_auc_4: 0.9439 - 2s/epoch - 11ms/step
# Epoch 50/64
# 183/183 - 2s - loss: 0.2954 - auc_4: 0.9465 - val_loss: 0.3242 - val_auc_4: 0.9373 - 2s/epoch - 10ms/step
# Epoch 51/64
# 183/183 - 2s - loss: 0.2930 - auc_4: 0.9472 - val_loss: 0.3038 - val_auc_4: 0.9435 - 2s/epoch - 10ms/step
# Epoch 52/64
# 183/183 - 2s - loss: 0.2958 - auc_4: 0.9457 - val_loss: 0.3094 - val_auc_4: 0.9439 - 2s/epoch - 10ms/step
# Epoch 53/64
# 183/183 - 2s - loss: 0.2910 - auc_4: 0.9479 - val_loss: 0.3123 - val_auc_4: 0.9412 - 2s/epoch - 10ms/step
# Epoch 54/64
# 183/183 - 2s - loss: 0.2986 - auc_4: 0.9450 - val_loss: 0.2996 - val_auc_4: 0.9452 - 2s/epoch - 13ms/step
# Epoch 55/64
# 183/183 - 2s - loss: 0.2911 - auc_4: 0.9477 - val_loss: 0.3087 - val_auc_4: 0.9421 - 2s/epoch - 10ms/step
# Epoch 56/64
# 183/183 - 2s - loss: 0.2909 - auc_4: 0.9480 - val_loss: 0.3037 - val_auc_4: 0.9438 - 2s/epoch - 10ms/step
# Epoch 57/64
# 183/183 - 2s - loss: 0.2884 - auc_4: 0.9487 - val_loss: 0.3167 - val_auc_4: 0.9396 - 2s/epoch - 10ms/step
# Epoch 58/64
# 183/183 - 2s - loss: 0.2898 - auc_4: 0.9484 - val_loss: 0.2968 - val_auc_4: 0.9466 - 2s/epoch - 10ms/step
# Epoch 59/64
# 183/183 - 2s - loss: 0.2917 - auc_4: 0.9477 - val_loss: 0.3020 - val_auc_4: 0.9446 - 2s/epoch - 10ms/step
# Epoch 60/64
# 183/183 - 2s - loss: 0.2919 - auc_4: 0.9474 - val_loss: 0.3052 - val_auc_4: 0.9444 - 2s/epoch - 11ms/step
# Epoch 61/64
# 183/183 - 2s - loss: 0.2929 - auc_4: 0.9473 - val_loss: 0.3250 - val_auc_4: 0.9363 - 2s/epoch - 11ms/step
# Epoch 62/64
# 183/183 - 2s - loss: 0.2864 - auc_4: 0.9495 - val_loss: 0.3238 - val_auc_4: 0.9367 - 2s/epoch - 10ms/step
# Epoch 63/64
# 183/183 - 2s - loss: 0.2874 - auc_4: 0.9491 - val_loss: 0.2973 - val_auc_4: 0.9465 - 2s/epoch - 10ms/step
# Epoch 64/64
# 183/183 - 2s - loss: 0.2875 - auc_4: 0.9492 - val_loss: 0.3270 - val_auc_4: 0.9361 - 2s/epoch - 10ms/step
# 46/46 [==============================] - 1s 5ms/step
#
# Average Classification Report Across Folds:
# {'accuracy': 0.8647540983606558}
# <ipython-input-8-80e24cbb214d>:52: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_report = pd.DataFrame(all_reports).mean().to_dict()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %% [markdown]
# # Save results

# %%
extractorEmb = Model(inputs=model.inputs,outputs=model.get_layer(name="clsTokenEmb").output)

preds = model.predict(x3,batch_size = config.BATCH_SIZE)

dbresults={}
dbresults['pred_emb'] = extractorEmb.predict(x3,batch_size = config.BATCH_SIZE)
dbresults['pred_cls'] = preds
dbresults['y_cls'] = labels
dbresults['formula'] = df['formula']
dbresults['ids'] = df['ids']
dbresults['types'] = types
dbresults['trainidx'] = train_idx
dbresults['testidx'] = val_idx
dbresults['validx'] = val_idx

with open(mname+'_results.pkl', 'wb') as f:
    pickle.dump(dbresults, f)
# Out:
# 229/229 [==============================] - 1s 5ms/step
# 229/229 [==============================] - 2s 6ms/step

# %% [markdown]
# # Postprocessing

# %%
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn import metrics
import seaborn as sns
tsne = TSNE(n_components=2, verbose=0, random_state=123)
z = tsne.fit_transform(dbresults['pred_emb'])

# %%
dfr = pd.DataFrame()
dfr["y"] = np.asarray(dbresults['y_cls'].argmax(axis=-1)).astype('bool')
dfr["yp"] = np.asarray(dbresults['pred_cls'].argmax(axis=-1)).astype('bool')
dfr["tSNE1"] = z[:,0]
dfr["tSNE2"] = z[:,1]

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
fig, axes = plt.subplots(1, 3, figsize=(15, 4.8))
y_pclasses = dbresults['pred_cls'][dbresults['testidx']].argmax(axis=-1).tolist()
y_classes = dbresults['y_cls'][dbresults['testidx']].argmax(axis=-1)
m = tf.keras.metrics.AUC()
m.update_state(dbresults['y_cls'][dbresults['testidx']], dbresults['pred_cls'][dbresults['testidx']])
print(mname,'binary tf-acc:',tf.keras.metrics.binary_accuracy(y_classes, y_pclasses, threshold=0.5).numpy(),'AUC:',m.result().numpy())
confusion_matrix = metrics.confusion_matrix(y_classes, y_pclasses)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix,
                                            display_labels=['False','True'])
cm_display.plot(ax=axes[0],cmap=plt.cm.Blues)

dfr=dfr.sort_values(by=['y'])
sns.scatterplot(ax=axes[1],x="tSNE1", y="tSNE2", hue=dfr.y.tolist(),data=dfr,alpha=0.4)#.set(title=title+" data T-SNE projection")
axes[1].set_xlabel('$tSNE_1$')
axes[1].set_ylabel('$tSNE_2$',labelpad=1)
axes[1].set_title('Reference')
dfr=dfr.sort_values(by=['yp'])
sns.scatterplot(ax=axes[2],x="tSNE1", y="tSNE2", hue=dfr.yp.tolist(),data=dfr,alpha=0.4)#.set(title=title+" data T-SNE projection")
axes[2].set_title('Predicted')
axes[2].set_xlabel('$tSNE_1$')
axes[2].set_ylabel('$tSNE_2$',labelpad=1)
axes[2].legend('',frameon=False)
fig.tight_layout()
plt.savefig(mname+'_tsne.png',format='png',dpi=800,bbox_inches = "tight")
plt.show()
# Out:
# /content/elementsem/models/elembert_toxic_sr-mmp_V1_E_32_H_2_L_2 binary tf-acc: 0.864071 AUC: 0.9360975
