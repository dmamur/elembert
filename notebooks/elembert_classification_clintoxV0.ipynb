# %% [markdown]
# <a href="https://colab.research.google.com/github/dmamur/elementsem/blob/main/notebooks/elembert_classification_clintoxV0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle,random
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Embedding,Dense,Dropout,Input,Lambda
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
import re, glob,os,sys
from collections import defaultdict
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical

def bert_module(query, key, value, i, config):
    # Multi headed self-attention
    attention_output = layers.MultiHeadAttention(
        num_heads=config.NUM_HEAD,
        key_dim=config.EMBED_DIM // config.NUM_HEAD,
        name="encoder_{}/multiheadattention".format(i),
    )(query, key, value)
    attention_output = layers.Dropout(0.1, name="encoder_{}/att_dropout".format(i))(
        attention_output
    )
    attention_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/att_layernormalization".format(i)
    )(query + attention_output)

    # Feed-forward layer
    ffn = tf.keras.Sequential(
        [
            layers.Dense(config.FF_DIM, activation="relu"),
            layers.Dense(config.EMBED_DIM),
        ],
        name="encoder_{}/ffn".format(i),
    )
    ffn_output = ffn(attention_output)
    ffn_output = layers.Dropout(0.1, name="encoder_{}/ffn_dropout".format(i))(
        ffn_output
    )
    sequence_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/ffn_layernormalization".format(i)
    )(attention_output + ffn_output)
    return sequence_output


def get_pos_encoding_matrix(max_len, d_emb):
    pos_enc = np.array(
        [
            [pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)]
            if pos != 0
            else np.zeros(d_emb)
            for pos in range(max_len)
        ]
    )
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2])  # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2])  # dim 2i+1
    return pos_enc

def create_elembert_model(inputs,config):
    word_embeddings = layers.Embedding(config.VOCAB_SIZE, config.EMBED_DIM, mask_zero=True,name="element_embdgs")(inputs)
    position_embeddings = layers.Embedding(input_dim=config.MAX_LEN,output_dim=config.EMBED_DIM,
                                           weights=[get_pos_encoding_matrix(config.MAX_LEN, config.EMBED_DIM)],
                                           name="position_embedding",)(tf.range(start=0, limit=config.MAX_LEN, delta=1))
    embeddings = word_embeddings + position_embeddings
    encoder_output = embeddings
    for i in range(config.NUM_LAYERS):
        encoder_output = bert_module(encoder_output, encoder_output, encoder_output, i, config)
    mlm_model = Model(inputs, encoder_output, name="masked_bert_model")

    return mlm_model

# %%
# !pip install ase
# !git clone https://github.com/dmamur/elementsem.git
# !pip install rdkit
# Out:
# Collecting ase
#   Downloading ase-3.22.1-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from ase) (3.7.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from ase) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from ase) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.0->ase) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->ase) (1.16.0)
# Installing collected packages: ase
# Successfully installed ase-3.22.1
# Cloning into 'elementsem'...
# remote: Enumerating objects: 575, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 575 (delta 72), reused 1 (delta 1), pack-reused 445
# Receiving objects: 100% (575/575), 94.10 MiB | 10.61 MiB/s, done.
# Resolving deltas: 100% (289/289), done.
# Updating files: 100% (267/267), done.
# Collecting rdkit
#   Downloading rdkit-2023.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.3.3

# %%
class Config:
    MAX_LEN = 256
    BATCH_SIZE = 128
    LR = 0.001
    VOCAB_SIZE = 128
    EMBED_DIM = 32
    NUM_HEAD = 2 # used in bert model
    FF_DIM = 32 # used in bert model
    NUM_LAYERS = 2
    MNAME = 'elembertR_'
    MVER = 'V0'
    DSPATH="/content/elementsem/data/"
    PREPATH="/content/elementsem/models/pretrained/"
    PATH="/content/elementsem/models/"
config = Config()
seed=12345
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
! wget https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/clintox.csv.gz
# Out:
# --2023-09-05 21:45:06--  https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/clintox.csv.gz
# Resolving deepchemdata.s3-us-west-1.amazonaws.com (deepchemdata.s3-us-west-1.amazonaws.com)... 52.219.112.65, 52.219.117.146, 52.219.220.202, ...
# Connecting to deepchemdata.s3-us-west-1.amazonaws.com (deepchemdata.s3-us-west-1.amazonaws.com)|52.219.112.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19870 (19K) [application/x-gzip]
# Saving to: ‘clintox.csv.gz’
#
# clintox.csv.gz      100%[===================>]  19.40K  --.-KB/s    in 0s
#
# 2023-09-05 21:45:07 (43.7 MB/s) - ‘clintox.csv.gz’ saved [19870/19870]

# %%
ds = 'clintox'
mname=config.PATH+config.MNAME+ds+'_%s_E_%s_H_%s_L_%s_bert.h5' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS)

# %% [markdown]
# # Load vocabulary and types

# %%
from rdkit import Chem
import gzip
with gzip.open('clintox.csv.gz', 'rb') as file:
    df = pd.read_csv(file)
print(df.head())
types,labels=[],[]
for i,j in zip(df['smiles'],df['CT_TOX']):
  try:
    m = Chem.MolFromSmiles(i)
    m2 = Chem.AddHs(m)
    types.append([atom.GetSymbol() for atom in m2.GetAtoms()])
    labels.append(j)
  except:
    pass
labels  = to_categorical(np.asarray(labels))
uniquelbls=len(np.unique(np.asarray(df['CT_TOX'])))

with open(config.PREPATH+'/el2id'+config.MVER+'.pkl', 'rb') as f:
    db = pickle.load(f)

element2id = db['el2id']
el2id = db['el2id']
config.VOCAB_SIZE = len(element2id)
print('vocabSize: ', config.VOCAB_SIZE)
# Out:
#                                               smiles  FDA_APPROVED  CT_TOX
# 0            *C(=O)[C@H](CCCCNC(=O)OCCOC)NC(=O)OCCOC             1       0
# 1  [C@@H]1([C@@H]([C@@H]([C@H]([C@@H]([C@@H]1Cl)C...             1       0
# 2  [C@H]([C@@H]([C@@H](C(=O)[O-])O)O)([C@H](C(=O)...             1       0
# 3  [H]/[NH+]=C(/C1=CC(=O)/C(=C\C=c2ccc(=C([NH3+])...             1       0
# 4  [H]/[NH+]=C(\N)/c1ccc(cc1)OCCCCCOc2ccc(cc2)/C(...             1       0
# [21:45:07] Explicit valence for atom # 0 N, 5, is greater than permitted
# [21:45:07] Can't kekulize mol.  Unkekulized atoms: 9
# vocabSize:  101
# [21:45:07] Explicit valence for atom # 10 N, 4, is greater than permitted
# [21:45:07] Explicit valence for atom # 10 N, 4, is greater than permitted
# [21:45:07] Can't kekulize mol.  Unkekulized atoms: 4
# [21:45:07] Can't kekulize mol.  Unkekulized atoms: 4

# %%
print('dataLen: ', len(types), '   OriginalDataLen: ', len(df['smiles']))
# Out:
# dataLen:  1478    OriginalDataLen:  1484

# %% [markdown]
# # Convert types to integers

# %%
from collections import defaultdict
element2id = defaultdict(lambda: 1, element2id)
types0=[['[CLS]']+i+['[SEP]'] for i in types]
typesNumerical=[]
for i in types0:
    typesNumerical.append([element2id[j] for j in i])

x3 = tf.keras.preprocessing.sequence.pad_sequences(typesNumerical,dtype='int32',padding= 'post',truncating='post',maxlen=config.MAX_LEN)

#z = load_model(config.PREPATH+'/embert'+'_%s_E_%s_H_%s_L_%s_bert.h5' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS),compile=False)
#z = load_model(config.PREPATH+'/elEmBERT'+'_%s_E_%s_H_%s_L_%s_bert.h5' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS),compile=False)
#z.trainable = True

inputC = Input((config.MAX_LEN), dtype=tf.int32,name='types')
z = create_elembert_model(inputC,config)

e = Lambda(lambda x: x[:,0],name='clsTokenEmb')(z.output)
f = Dense(uniquelbls, activation="softmax",name='out_tox')(e)

model = Model(inputs=z.input, outputs=f)

#plot_model(model, show_shapes=True, show_layer_names=True,to_file=mname+".png")

optimizer = tf.keras.optimizers.Adam(learning_rate=config.LR)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=[tf.keras.metrics.AUC()])

model.summary()

csv_logger = tf.keras.callbacks.CSVLogger(mname+"_log.csv", append=True)

checkpoint = tf.keras.callbacks.ModelCheckpoint(mname+".h5",verbose=2, mode='min',save_freq=20000,)

callbacks_list = [checkpoint,csv_logger]

print('dataLen: ',x3.shape,labels.shape)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  types (InputLayer)             [(None, 256)]        0           []
#
#  element_embdgs (Embedding)     (None, 256, 32)      3232        ['types[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 256, 32)     0           ['element_embdgs[0][0]']
#  da)
#
#  encoder_0/multiheadattention (  (None, 256, 32)     4224        ['tf.__operators__.add[0][0]',
#  MultiHeadAttention)                                              'tf.__operators__.add[0][0]',
#                                                                   'tf.__operators__.add[0][0]']
#
#  encoder_0/att_dropout (Dropout  (None, 256, 32)     0           ['encoder_0/multiheadattention[0]
#  )                                                               [0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 256, 32)     0           ['tf.__operators__.add[0][0]',
#  mbda)                                                            'encoder_0/att_dropout[0][0]']
#
#  encoder_0/att_layernormalizati  (None, 256, 32)     64          ['tf.__operators__.add_1[0][0]']
#  on (LayerNormalization)
#
#  encoder_0/ffn (Sequential)     (None, 256, 32)      2112        ['encoder_0/att_layernormalizatio
#                                                                  n[0][0]']
#
#  encoder_0/ffn_dropout (Dropout  (None, 256, 32)     0           ['encoder_0/ffn[0][0]']
#  )
#
#  tf.__operators__.add_2 (TFOpLa  (None, 256, 32)     0           ['encoder_0/att_layernormalizatio
#  mbda)                                                           n[0][0]',
#                                                                   'encoder_0/ffn_dropout[0][0]']
#
#  encoder_0/ffn_layernormalizati  (None, 256, 32)     64          ['tf.__operators__.add_2[0][0]']
#  on (LayerNormalization)
#
#  encoder_1/multiheadattention (  (None, 256, 32)     4224        ['encoder_0/ffn_layernormalizatio
#  MultiHeadAttention)                                             n[0][0]',
#                                                                   'encoder_0/ffn_layernormalizatio
#                                                                  n[0][0]',
#                                                                   'encoder_0/ffn_layernormalizatio
#                                                                  n[0][0]']
#
#  encoder_1/att_dropout (Dropout  (None, 256, 32)     0           ['encoder_1/multiheadattention[0]
#  )                                                               [0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 256, 32)     0           ['encoder_0/ffn_layernormalizatio
#  mbda)                                                           n[0][0]',
#                                                                   'encoder_1/att_dropout[0][0]']
#
#  encoder_1/att_layernormalizati  (None, 256, 32)     64          ['tf.__operators__.add_3[0][0]']
#  on (LayerNormalization)
#
#  encoder_1/ffn (Sequential)     (None, 256, 32)      2112        ['encoder_1/att_layernormalizatio
#                                                                  n[0][0]']
#
#  encoder_1/ffn_dropout (Dropout  (None, 256, 32)     0           ['encoder_1/ffn[0][0]']
#  )
#
#  tf.__operators__.add_4 (TFOpLa  (None, 256, 32)     0           ['encoder_1/att_layernormalizatio
#  mbda)                                                           n[0][0]',
#                                                                   'encoder_1/ffn_dropout[0][0]']
#
#  encoder_1/ffn_layernormalizati  (None, 256, 32)     64          ['tf.__operators__.add_4[0][0]']
#  on (LayerNormalization)
#
#  clsTokenEmb (Lambda)           (None, 32)           0           ['encoder_1/ffn_layernormalizatio
#                                                                  n[0][0]']
#
#  out_tox (Dense)                (None, 2)            66          ['clsTokenEmb[0][0]']
#
# ==================================================================================================
# Total params: 16,226
# Trainable params: 16,226
# Non-trainable params: 0
# __________________________________________________________________________________________________
# dataLen:  (1478, 256) (1478, 2)

# %%
epochs=config.BATCH_SIZE*2

p = np.random.RandomState(seed=seed).permutation(len(labels))
n = len(p)

trainidx=p[:int(len(p)*0.8)]
validx = p[int(n*0.8):int(n*0.9)]
testidx = p[int(n*0.9):]

trainlog = model.fit(x=x3[trainidx], y=labels[trainidx],
                     validation_data = (x3[validx],labels[validx]),
                     verbose = 1,epochs = epochs, batch_size = config.BATCH_SIZE,callbacks = callbacks_list)

model.save(mname+".h5")
# Out:
# Epoch 1/256
# 10/10 [==============================] - 27s 400ms/step - loss: 0.2853 - auc: 0.9213 - val_loss: 0.2509 - val_auc: 0.9324
# Epoch 2/256
# 10/10 [==============================] - 1s 96ms/step - loss: 0.2705 - auc: 0.9252 - val_loss: 0.2475 - val_auc: 0.9324
# Epoch 3/256
# 10/10 [==============================] - 1s 82ms/step - loss: 0.2668 - auc: 0.9272 - val_loss: 0.2485 - val_auc: 0.9324
# Epoch 4/256
# 10/10 [==============================] - 0s 45ms/step - loss: 0.2584 - auc: 0.9349 - val_loss: 0.2482 - val_auc: 0.9324
# Epoch 5/256
# 10/10 [==============================] - 1s 54ms/step - loss: 0.2718 - auc: 0.9190 - val_loss: 0.2473 - val_auc: 0.9324
# Epoch 6/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2611 - auc: 0.9315 - val_loss: 0.2478 - val_auc: 0.9329
# Epoch 7/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2639 - auc: 0.9258 - val_loss: 0.2474 - val_auc: 0.9346
# Epoch 8/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2610 - auc: 0.9307 - val_loss: 0.2475 - val_auc: 0.9324
# Epoch 9/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2635 - auc: 0.9255 - val_loss: 0.2477 - val_auc: 0.9324
# Epoch 10/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2665 - auc: 0.9216 - val_loss: 0.2475 - val_auc: 0.9324
# Epoch 11/256
# 10/10 [==============================] - 1s 74ms/step - loss: 0.2596 - auc: 0.9311 - val_loss: 0.2474 - val_auc: 0.9333
# Epoch 12/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2636 - auc: 0.9257 - val_loss: 0.2474 - val_auc: 0.9324
# Epoch 13/256
# 10/10 [==============================] - 0s 41ms/step - loss: 0.2626 - auc: 0.9257 - val_loss: 0.2473 - val_auc: 0.9306
# Epoch 14/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2616 - auc: 0.9248 - val_loss: 0.2474 - val_auc: 0.9301
# Epoch 15/256
# 10/10 [==============================] - 0s 41ms/step - loss: 0.2618 - auc: 0.9247 - val_loss: 0.2474 - val_auc: 0.9292
# Epoch 16/256
# 10/10 [==============================] - 0s 45ms/step - loss: 0.2645 - auc: 0.9239 - val_loss: 0.2479 - val_auc: 0.9283
# Epoch 17/256
# 10/10 [==============================] - 0s 44ms/step - loss: 0.2662 - auc: 0.9169 - val_loss: 0.2477 - val_auc: 0.9324
# Epoch 18/256
# 10/10 [==============================] - 1s 56ms/step - loss: 0.2585 - auc: 0.9379 - val_loss: 0.2474 - val_auc: 0.9342
# Epoch 19/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2619 - auc: 0.9269 - val_loss: 0.2474 - val_auc: 0.9305
# Epoch 20/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2626 - auc: 0.9239 - val_loss: 0.2478 - val_auc: 0.9332
# Epoch 21/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2604 - auc: 0.9308 - val_loss: 0.2473 - val_auc: 0.9301
# Epoch 22/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2593 - auc: 0.9328 - val_loss: 0.2475 - val_auc: 0.9288
# Epoch 23/256
# 10/10 [==============================] - 0s 36ms/step - loss: 0.2601 - auc: 0.9316 - val_loss: 0.2476 - val_auc: 0.9347
# Epoch 24/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2634 - auc: 0.9238 - val_loss: 0.2474 - val_auc: 0.9276
# Epoch 25/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2607 - auc: 0.9274 - val_loss: 0.2473 - val_auc: 0.9333
# Epoch 26/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2649 - auc: 0.9163 - val_loss: 0.2473 - val_auc: 0.9329
# Epoch 27/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2649 - auc: 0.9236 - val_loss: 0.2491 - val_auc: 0.9279
# Epoch 28/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2616 - auc: 0.9244 - val_loss: 0.2490 - val_auc: 0.9337
# Epoch 29/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2600 - auc: 0.9310 - val_loss: 0.2475 - val_auc: 0.9283
# Epoch 30/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2588 - auc: 0.9315 - val_loss: 0.2473 - val_auc: 0.9320
# Epoch 31/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2600 - auc: 0.9278 - val_loss: 0.2476 - val_auc: 0.9307
# Epoch 32/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2594 - auc: 0.9282 - val_loss: 0.2474 - val_auc: 0.9293
# Epoch 33/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2601 - auc: 0.9285 - val_loss: 0.2474 - val_auc: 0.9354
# Epoch 34/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2586 - auc: 0.9330 - val_loss: 0.2476 - val_auc: 0.9326
# Epoch 35/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2609 - auc: 0.9254 - val_loss: 0.2478 - val_auc: 0.9404
# Epoch 36/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2602 - auc: 0.9291 - val_loss: 0.2476 - val_auc: 0.9356
# Epoch 37/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2592 - auc: 0.9304 - val_loss: 0.2475 - val_auc: 0.9386
# Epoch 38/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2597 - auc: 0.9280 - val_loss: 0.2475 - val_auc: 0.9433
# Epoch 39/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2647 - auc: 0.9238 - val_loss: 0.2475 - val_auc: 0.9279
# Epoch 40/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2597 - auc: 0.9318 - val_loss: 0.2477 - val_auc: 0.9374
# Epoch 41/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2592 - auc: 0.9299 - val_loss: 0.2479 - val_auc: 0.9348
# Epoch 42/256
# 10/10 [==============================] - 1s 54ms/step - loss: 0.2608 - auc: 0.9287 - val_loss: 0.2491 - val_auc: 0.9358
# Epoch 43/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2669 - auc: 0.9266 - val_loss: 0.2476 - val_auc: 0.9317
# Epoch 44/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2592 - auc: 0.9332 - val_loss: 0.2477 - val_auc: 0.9328
# Epoch 45/256
# 10/10 [==============================] - 0s 44ms/step - loss: 0.2585 - auc: 0.9299 - val_loss: 0.2479 - val_auc: 0.9388
# Epoch 46/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2595 - auc: 0.9301 - val_loss: 0.2481 - val_auc: 0.9393
# Epoch 47/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2585 - auc: 0.9349 - val_loss: 0.2479 - val_auc: 0.9349
# Epoch 48/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2573 - auc: 0.9373 - val_loss: 0.2479 - val_auc: 0.9383
# Epoch 49/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2574 - auc: 0.9377 - val_loss: 0.2484 - val_auc: 0.9350
# Epoch 50/256
# 10/10 [==============================] - 0s 45ms/step - loss: 0.2573 - auc: 0.9372 - val_loss: 0.2489 - val_auc: 0.9411
# Epoch 51/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2567 - auc: 0.9419 - val_loss: 0.2489 - val_auc: 0.9410
# Epoch 52/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2559 - auc: 0.9413 - val_loss: 0.2490 - val_auc: 0.9406
# Epoch 53/256
# 10/10 [==============================] - 0s 45ms/step - loss: 0.2563 - auc: 0.9402 - val_loss: 0.2488 - val_auc: 0.9395
# Epoch 54/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2547 - auc: 0.9419 - val_loss: 0.2487 - val_auc: 0.9411
# Epoch 55/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2578 - auc: 0.9449 - val_loss: 0.2490 - val_auc: 0.9398
# Epoch 56/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2570 - auc: 0.9438 - val_loss: 0.2532 - val_auc: 0.9417
# Epoch 57/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2569 - auc: 0.9435 - val_loss: 0.2513 - val_auc: 0.9402
# Epoch 58/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2494 - auc: 0.9498 - val_loss: 0.2481 - val_auc: 0.9416
# Epoch 59/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2452 - auc: 0.9540 - val_loss: 0.2502 - val_auc: 0.9415
# Epoch 60/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2472 - auc: 0.9530 - val_loss: 0.2563 - val_auc: 0.9407
# Epoch 61/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2483 - auc: 0.9490 - val_loss: 0.2474 - val_auc: 0.9422
# Epoch 62/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2429 - auc: 0.9555 - val_loss: 0.2523 - val_auc: 0.9430
# Epoch 63/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2394 - auc: 0.9563 - val_loss: 0.2519 - val_auc: 0.9414
# Epoch 64/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2392 - auc: 0.9570 - val_loss: 0.2564 - val_auc: 0.9428
# Epoch 65/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2424 - auc: 0.9545 - val_loss: 0.2540 - val_auc: 0.9434
# Epoch 66/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2428 - auc: 0.9538 - val_loss: 0.2525 - val_auc: 0.9410
# Epoch 67/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2387 - auc: 0.9566 - val_loss: 0.2634 - val_auc: 0.9422
# Epoch 68/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2387 - auc: 0.9568 - val_loss: 0.2553 - val_auc: 0.9420
# Epoch 69/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2374 - auc: 0.9567 - val_loss: 0.2629 - val_auc: 0.9417
# Epoch 70/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2382 - auc: 0.9580 - val_loss: 0.2568 - val_auc: 0.9421
# Epoch 71/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2479 - auc: 0.9574 - val_loss: 0.2579 - val_auc: 0.9432
# Epoch 72/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2412 - auc: 0.9589 - val_loss: 0.2477 - val_auc: 0.9432
# Epoch 73/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2417 - auc: 0.9561 - val_loss: 0.2508 - val_auc: 0.9433
# Epoch 74/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2412 - auc: 0.9566 - val_loss: 0.2511 - val_auc: 0.9427
# Epoch 75/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2344 - auc: 0.9586 - val_loss: 0.2620 - val_auc: 0.9446
# Epoch 76/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2362 - auc: 0.9587 - val_loss: 0.2498 - val_auc: 0.9456
# Epoch 77/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2325 - auc: 0.9606 - val_loss: 0.2551 - val_auc: 0.9451
# Epoch 78/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2328 - auc: 0.9614 - val_loss: 0.2531 - val_auc: 0.9460
# Epoch 79/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2364 - auc: 0.9583 - val_loss: 0.2567 - val_auc: 0.9456
# Epoch 80/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2318 - auc: 0.9600 - val_loss: 0.2552 - val_auc: 0.9460
# Epoch 81/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2343 - auc: 0.9591 - val_loss: 0.2532 - val_auc: 0.9455
# Epoch 82/256
# 10/10 [==============================] - 0s 37ms/step - loss: 0.2338 - auc: 0.9578 - val_loss: 0.2558 - val_auc: 0.9456
# Epoch 83/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2326 - auc: 0.9586 - val_loss: 0.2579 - val_auc: 0.9474
# Epoch 84/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2314 - auc: 0.9609 - val_loss: 0.2513 - val_auc: 0.9459
# Epoch 85/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2305 - auc: 0.9613 - val_loss: 0.2502 - val_auc: 0.9460
# Epoch 86/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2334 - auc: 0.9581 - val_loss: 0.2571 - val_auc: 0.9474
# Epoch 87/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2316 - auc: 0.9591 - val_loss: 0.2526 - val_auc: 0.9465
# Epoch 88/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2298 - auc: 0.9606 - val_loss: 0.2585 - val_auc: 0.9473
# Epoch 89/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2300 - auc: 0.9615 - val_loss: 0.2530 - val_auc: 0.9462
# Epoch 90/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2268 - auc: 0.9608 - val_loss: 0.2614 - val_auc: 0.9484
# Epoch 91/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2285 - auc: 0.9610 - val_loss: 0.2530 - val_auc: 0.9487
# Epoch 92/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2275 - auc: 0.9627 - val_loss: 0.2550 - val_auc: 0.9482
# Epoch 93/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2259 - auc: 0.9626 - val_loss: 0.2535 - val_auc: 0.9485
# Epoch 94/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2247 - auc: 0.9629 - val_loss: 0.2563 - val_auc: 0.9497
# Epoch 95/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2274 - auc: 0.9607 - val_loss: 0.2855 - val_auc: 0.9458
# Epoch 96/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2377 - auc: 0.9602 - val_loss: 0.2519 - val_auc: 0.9485
# Epoch 97/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2391 - auc: 0.9622 - val_loss: 0.2421 - val_auc: 0.9490
# Epoch 98/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2310 - auc: 0.9635 - val_loss: 0.2489 - val_auc: 0.9488
# Epoch 99/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2254 - auc: 0.9627 - val_loss: 0.2569 - val_auc: 0.9503
# Epoch 100/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2226 - auc: 0.9645 - val_loss: 0.2626 - val_auc: 0.9493
# Epoch 101/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2206 - auc: 0.9646 - val_loss: 0.2578 - val_auc: 0.9498
# Epoch 102/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2212 - auc: 0.9645 - val_loss: 0.2563 - val_auc: 0.9485
# Epoch 103/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2190 - auc: 0.9655 - val_loss: 0.2597 - val_auc: 0.9491
# Epoch 104/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2226 - auc: 0.9651 - val_loss: 0.2567 - val_auc: 0.9501
# Epoch 105/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2234 - auc: 0.9651 - val_loss: 0.2576 - val_auc: 0.9488
# Epoch 106/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2268 - auc: 0.9658 - val_loss: 0.2525 - val_auc: 0.9506
# Epoch 107/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2280 - auc: 0.9656 - val_loss: 0.2501 - val_auc: 0.9507
# Epoch 108/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2211 - auc: 0.9652 - val_loss: 0.2561 - val_auc: 0.9504
# Epoch 109/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.2183 - auc: 0.9656 - val_loss: 0.2619 - val_auc: 0.9512
# Epoch 110/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2184 - auc: 0.9656 - val_loss: 0.2642 - val_auc: 0.9502
# Epoch 111/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2181 - auc: 0.9656 - val_loss: 0.2617 - val_auc: 0.9514
# Epoch 112/256
# 10/10 [==============================] - 0s 44ms/step - loss: 0.2189 - auc: 0.9649 - val_loss: 0.2515 - val_auc: 0.9513
# Epoch 113/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2191 - auc: 0.9661 - val_loss: 0.2513 - val_auc: 0.9510
# Epoch 114/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2185 - auc: 0.9658 - val_loss: 0.2656 - val_auc: 0.9504
# Epoch 115/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2174 - auc: 0.9662 - val_loss: 0.2538 - val_auc: 0.9504
# Epoch 116/256
# 10/10 [==============================] - 0s 45ms/step - loss: 0.2186 - auc: 0.9658 - val_loss: 0.2570 - val_auc: 0.9508
# Epoch 117/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2157 - auc: 0.9673 - val_loss: 0.2575 - val_auc: 0.9511
# Epoch 118/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2173 - auc: 0.9665 - val_loss: 0.2586 - val_auc: 0.9508
# Epoch 119/256
# 10/10 [==============================] - 0s 41ms/step - loss: 0.2161 - auc: 0.9662 - val_loss: 0.2565 - val_auc: 0.9505
# Epoch 120/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2158 - auc: 0.9661 - val_loss: 0.2576 - val_auc: 0.9524
# Epoch 121/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2164 - auc: 0.9661 - val_loss: 0.2560 - val_auc: 0.9519
# Epoch 122/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2135 - auc: 0.9678 - val_loss: 0.2624 - val_auc: 0.9528
# Epoch 123/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2138 - auc: 0.9674 - val_loss: 0.2608 - val_auc: 0.9526
# Epoch 124/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2161 - auc: 0.9672 - val_loss: 0.2451 - val_auc: 0.9516
# Epoch 125/256
# 10/10 [==============================] - 0s 41ms/step - loss: 0.2195 - auc: 0.9666 - val_loss: 0.2531 - val_auc: 0.9523
# Epoch 126/256
# 10/10 [==============================] - 0s 44ms/step - loss: 0.2134 - auc: 0.9678 - val_loss: 0.2555 - val_auc: 0.9524
# Epoch 127/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2130 - auc: 0.9674 - val_loss: 0.2609 - val_auc: 0.9522
# Epoch 128/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2118 - auc: 0.9681 - val_loss: 0.2577 - val_auc: 0.9528
# Epoch 129/256
# 10/10 [==============================] - 0s 37ms/step - loss: 0.2141 - auc: 0.9674 - val_loss: 0.2520 - val_auc: 0.9542
# Epoch 130/256
# 10/10 [==============================] - 0s 36ms/step - loss: 0.2133 - auc: 0.9667 - val_loss: 0.2539 - val_auc: 0.9528
# Epoch 131/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2168 - auc: 0.9662 - val_loss: 0.2562 - val_auc: 0.9540
# Epoch 132/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2132 - auc: 0.9668 - val_loss: 0.2564 - val_auc: 0.9534
# Epoch 133/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2118 - auc: 0.9681 - val_loss: 0.2568 - val_auc: 0.9544
# Epoch 134/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2110 - auc: 0.9684 - val_loss: 0.2522 - val_auc: 0.9536
# Epoch 135/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2126 - auc: 0.9679 - val_loss: 0.2724 - val_auc: 0.9523
# Epoch 136/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2157 - auc: 0.9677 - val_loss: 0.2441 - val_auc: 0.9538
# Epoch 137/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2124 - auc: 0.9676 - val_loss: 0.2507 - val_auc: 0.9552
# Epoch 138/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2115 - auc: 0.9686 - val_loss: 0.2475 - val_auc: 0.9552
# Epoch 139/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2091 - auc: 0.9690 - val_loss: 0.2560 - val_auc: 0.9561
# Epoch 140/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2088 - auc: 0.9689 - val_loss: 0.2562 - val_auc: 0.9553
# Epoch 141/256
# 10/10 [==============================] - 0s 36ms/step - loss: 0.2119 - auc: 0.9676 - val_loss: 0.2525 - val_auc: 0.9543
# Epoch 142/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2137 - auc: 0.9678 - val_loss: 0.2468 - val_auc: 0.9570
# Epoch 143/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2127 - auc: 0.9677 - val_loss: 0.2575 - val_auc: 0.9552
# Epoch 144/256
# 10/10 [==============================] - 1s 55ms/step - loss: 0.2092 - auc: 0.9689 - val_loss: 0.2533 - val_auc: 0.9568
# Epoch 145/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2067 - auc: 0.9698 - val_loss: 0.2482 - val_auc: 0.9558
# Epoch 146/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2074 - auc: 0.9698 - val_loss: 0.2613 - val_auc: 0.9543
# Epoch 147/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2054 - auc: 0.9694 - val_loss: 0.2423 - val_auc: 0.9585
# Epoch 148/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2068 - auc: 0.9709 - val_loss: 0.2467 - val_auc: 0.9576
# Epoch 149/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2068 - auc: 0.9695 - val_loss: 0.2420 - val_auc: 0.9588
# Epoch 150/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2079 - auc: 0.9700 - val_loss: 0.2645 - val_auc: 0.9523
# Epoch 151/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2037 - auc: 0.9710 - val_loss: 0.2453 - val_auc: 0.9596
# Epoch 152/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2046 - auc: 0.9701 - val_loss: 0.2715 - val_auc: 0.9521
# Epoch 153/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2093 - auc: 0.9694 - val_loss: 0.2412 - val_auc: 0.9607
# Epoch 154/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.2073 - auc: 0.9703 - val_loss: 0.2396 - val_auc: 0.9585
# Epoch 155/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2157 - auc: 0.9697 - val_loss: 0.2479 - val_auc: 0.9569
# Epoch 156/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2169 - auc: 0.9701 - val_loss: 0.2485 - val_auc: 0.9567
# Epoch 157/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2113 - auc: 0.9699 - val_loss: 0.2546 - val_auc: 0.9570
# Epoch 158/256
# 10/10 [==============================] - 0s 44ms/step - loss: 0.2066 - auc: 0.9708 - val_loss: 0.2500 - val_auc: 0.9591
# Epoch 159/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.2058 - auc: 0.9702 - val_loss: 0.2597 - val_auc: 0.9564
# Epoch 160/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.1996 - auc: 0.9707 - val_loss: 0.2489 - val_auc: 0.9588
# Epoch 161/256
# 10/10 [==============================] - 0s 43ms/step - loss: 0.2047 - auc: 0.9705 - val_loss: 0.2656 - val_auc: 0.9551
# Epoch 162/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2003 - auc: 0.9724 - val_loss: 0.2464 - val_auc: 0.9589
# Epoch 163/256
# 10/10 [==============================] - 0s 44ms/step - loss: 0.1985 - auc: 0.9724 - val_loss: 0.2431 - val_auc: 0.9552
# Epoch 164/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.2037 - auc: 0.9725 - val_loss: 0.2410 - val_auc: 0.9598
# Epoch 165/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.1957 - auc: 0.9739 - val_loss: 0.2406 - val_auc: 0.9614
# Epoch 166/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.1976 - auc: 0.9731 - val_loss: 0.2417 - val_auc: 0.9596
# Epoch 167/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1942 - auc: 0.9754 - val_loss: 0.2489 - val_auc: 0.9565
# Epoch 168/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1950 - auc: 0.9748 - val_loss: 0.2464 - val_auc: 0.9553
# Epoch 169/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1951 - auc: 0.9728 - val_loss: 0.2458 - val_auc: 0.9614
# Epoch 170/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1971 - auc: 0.9722 - val_loss: 0.2485 - val_auc: 0.9551
# Epoch 171/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1917 - auc: 0.9739 - val_loss: 0.2631 - val_auc: 0.9603
# Epoch 172/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1959 - auc: 0.9760 - val_loss: 0.2838 - val_auc: 0.9490
# Epoch 173/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.2006 - auc: 0.9736 - val_loss: 0.2415 - val_auc: 0.9513
# Epoch 174/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1951 - auc: 0.9746 - val_loss: 0.2735 - val_auc: 0.9519
# Epoch 175/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1904 - auc: 0.9754 - val_loss: 0.2605 - val_auc: 0.9552
# Epoch 176/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1907 - auc: 0.9761 - val_loss: 0.2898 - val_auc: 0.9433
# Epoch 177/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1906 - auc: 0.9764 - val_loss: 0.2760 - val_auc: 0.9461
# Epoch 178/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1970 - auc: 0.9742 - val_loss: 0.2703 - val_auc: 0.9390
# Epoch 179/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1925 - auc: 0.9736 - val_loss: 0.2759 - val_auc: 0.9486
# Epoch 180/256
# 10/10 [==============================] - 1s 34ms/step - loss: 0.1909 - auc: 0.9753 - val_loss: 0.2554 - val_auc: 0.9543
# Epoch 181/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1810 - auc: 0.9787 - val_loss: 0.2850 - val_auc: 0.9454
# Epoch 182/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1789 - auc: 0.9791 - val_loss: 0.2892 - val_auc: 0.9431
# Epoch 183/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1853 - auc: 0.9764 - val_loss: 0.2760 - val_auc: 0.9441
# Epoch 184/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1891 - auc: 0.9765 - val_loss: 0.2669 - val_auc: 0.9543
# Epoch 185/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1792 - auc: 0.9787 - val_loss: 0.3003 - val_auc: 0.9418
# Epoch 186/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1763 - auc: 0.9797 - val_loss: 0.3204 - val_auc: 0.9393
# Epoch 187/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1751 - auc: 0.9793 - val_loss: 0.2890 - val_auc: 0.9449
# Epoch 188/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1804 - auc: 0.9776 - val_loss: 0.3019 - val_auc: 0.9417
# Epoch 189/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1737 - auc: 0.9800 - val_loss: 0.3133 - val_auc: 0.9360
# Epoch 190/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1775 - auc: 0.9798 - val_loss: 0.3279 - val_auc: 0.9371
# Epoch 191/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1765 - auc: 0.9793 - val_loss: 0.3296 - val_auc: 0.9312
# Epoch 192/256
# 10/10 [==============================] - 0s 37ms/step - loss: 0.1797 - auc: 0.9791 - val_loss: 0.2830 - val_auc: 0.9466
# Epoch 193/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1797 - auc: 0.9789 - val_loss: 0.3256 - val_auc: 0.9402
# Epoch 194/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1832 - auc: 0.9788 - val_loss: 0.2864 - val_auc: 0.9424
# Epoch 195/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.1734 - auc: 0.9807 - val_loss: 0.3228 - val_auc: 0.9391
# Epoch 196/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1813 - auc: 0.9782 - val_loss: 0.3735 - val_auc: 0.9264
# Epoch 197/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1805 - auc: 0.9783 - val_loss: 0.3068 - val_auc: 0.9374
# Epoch 198/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1660 - auc: 0.9827 - val_loss: 0.3476 - val_auc: 0.9351
# Epoch 199/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.1708 - auc: 0.9808 - val_loss: 0.3507 - val_auc: 0.9346
# Epoch 200/256
# 10/10 [==============================] - 0s 37ms/step - loss: 0.1665 - auc: 0.9820 - val_loss: 0.3810 - val_auc: 0.9291
# Epoch 201/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.1689 - auc: 0.9814 - val_loss: 0.3284 - val_auc: 0.9391
# Epoch 202/256
# 10/10 [==============================] - 0s 42ms/step - loss: 0.1569 - auc: 0.9845 - val_loss: 0.3392 - val_auc: 0.9427
# Epoch 203/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.1642 - auc: 0.9814 - val_loss: 0.3236 - val_auc: 0.9397
# Epoch 204/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.1682 - auc: 0.9812 - val_loss: 0.3406 - val_auc: 0.9315
# Epoch 205/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1675 - auc: 0.9814 - val_loss: 0.3776 - val_auc: 0.9265
# Epoch 206/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1664 - auc: 0.9820 - val_loss: 0.2823 - val_auc: 0.9494
# Epoch 207/256
# 10/10 [==============================] - 0s 36ms/step - loss: 0.1665 - auc: 0.9824 - val_loss: 0.4195 - val_auc: 0.9262
# Epoch 208/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1676 - auc: 0.9824 - val_loss: 0.3890 - val_auc: 0.9299
# Epoch 209/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1633 - auc: 0.9830 - val_loss: 0.3495 - val_auc: 0.9350
# Epoch 210/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1598 - auc: 0.9838 - val_loss: 0.3311 - val_auc: 0.9430
# Epoch 211/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1539 - auc: 0.9849 - val_loss: 0.3495 - val_auc: 0.9356
# Epoch 212/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1485 - auc: 0.9856 - val_loss: 0.3600 - val_auc: 0.9398
# Epoch 213/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1521 - auc: 0.9851 - val_loss: 0.4224 - val_auc: 0.9261
# Epoch 214/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1618 - auc: 0.9838 - val_loss: 0.3321 - val_auc: 0.9367
# Epoch 215/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1528 - auc: 0.9858 - val_loss: 0.3393 - val_auc: 0.9349
# Epoch 216/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1546 - auc: 0.9852 - val_loss: 0.3275 - val_auc: 0.9452
# Epoch 217/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.2037 - auc: 0.9713 - val_loss: 0.2928 - val_auc: 0.9480
# Epoch 218/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1821 - auc: 0.9758 - val_loss: 0.3604 - val_auc: 0.9394
# Epoch 219/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1551 - auc: 0.9840 - val_loss: 0.3740 - val_auc: 0.9257
# Epoch 220/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1557 - auc: 0.9849 - val_loss: 0.3803 - val_auc: 0.9302
# Epoch 221/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1549 - auc: 0.9835 - val_loss: 0.3256 - val_auc: 0.9503
# Epoch 222/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1556 - auc: 0.9844 - val_loss: 0.3595 - val_auc: 0.9366
# Epoch 223/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1446 - auc: 0.9857 - val_loss: 0.3626 - val_auc: 0.9371
# Epoch 224/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1398 - auc: 0.9878 - val_loss: 0.3627 - val_auc: 0.9404
# Epoch 225/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1500 - auc: 0.9853 - val_loss: 0.3807 - val_auc: 0.9327
# Epoch 226/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1447 - auc: 0.9861 - val_loss: 0.3562 - val_auc: 0.9405
# Epoch 227/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1452 - auc: 0.9867 - val_loss: 0.3306 - val_auc: 0.9438
# Epoch 228/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1410 - auc: 0.9867 - val_loss: 0.3464 - val_auc: 0.9378
# Epoch 229/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1460 - auc: 0.9863 - val_loss: 0.3689 - val_auc: 0.9401
# Epoch 230/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1408 - auc: 0.9876 - val_loss: 0.4226 - val_auc: 0.9240
# Epoch 231/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1333 - auc: 0.9884 - val_loss: 0.3702 - val_auc: 0.9387
# Epoch 232/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1341 - auc: 0.9882 - val_loss: 0.4279 - val_auc: 0.9319
# Epoch 233/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1353 - auc: 0.9882 - val_loss: 0.3811 - val_auc: 0.9401
# Epoch 234/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.1414 - auc: 0.9873 - val_loss: 0.4150 - val_auc: 0.9334
# Epoch 235/256
# 10/10 [==============================] - 0s 37ms/step - loss: 0.1388 - auc: 0.9878 - val_loss: 0.4243 - val_auc: 0.9250
# Epoch 236/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1281 - auc: 0.9898 - val_loss: 0.3852 - val_auc: 0.9373
# Epoch 237/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.1301 - auc: 0.9886 - val_loss: 0.4417 - val_auc: 0.9288
# Epoch 238/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1405 - auc: 0.9871 - val_loss: 0.4416 - val_auc: 0.9245
# Epoch 239/256
# 10/10 [==============================] - 0s 40ms/step - loss: 0.1357 - auc: 0.9882 - val_loss: 0.3586 - val_auc: 0.9421
# Epoch 240/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1388 - auc: 0.9884 - val_loss: 0.3802 - val_auc: 0.9416
# Epoch 241/256
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1404 - auc: 0.9859 - val_loss: 0.4961 - val_auc: 0.9052
# Epoch 242/256
# 10/10 [==============================] - 1s 74ms/step - loss: 0.1292 - auc: 0.9894 - val_loss: 0.3888 - val_auc: 0.9395
# Epoch 243/256
# 10/10 [==============================] - 1s 68ms/step - loss: 0.1238 - auc: 0.9901 - val_loss: 0.5088 - val_auc: 0.9196
# Epoch 244/256
# 10/10 [==============================] - 0s 36ms/step - loss: 0.1259 - auc: 0.9897 - val_loss: 0.3642 - val_auc: 0.9421
# Epoch 245/256
# 10/10 [==============================] - 1s 54ms/step - loss: 0.1337 - auc: 0.9889 - val_loss: 0.3923 - val_auc: 0.9317
# Epoch 246/256
# 10/10 [==============================] - 0s 46ms/step - loss: 0.1305 - auc: 0.9896 - val_loss: 0.4999 - val_auc: 0.9255
# Epoch 247/256
# 10/10 [==============================] - 0s 35ms/step - loss: 0.1234 - auc: 0.9906 - val_loss: 0.3982 - val_auc: 0.9357
# Epoch 248/256
# 10/10 [==============================] - 0s 47ms/step - loss: 0.1168 - auc: 0.9912 - val_loss: 0.4338 - val_auc: 0.9350
# Epoch 249/256
# 10/10 [==============================] - 0s 47ms/step - loss: 0.1234 - auc: 0.9898 - val_loss: 0.4767 - val_auc: 0.9308
# Epoch 250/256
# 10/10 [==============================] - 0s 45ms/step - loss: 0.1224 - auc: 0.9899 - val_loss: 0.4398 - val_auc: 0.9276
# Epoch 251/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1286 - auc: 0.9893 - val_loss: 0.4236 - val_auc: 0.9372
# Epoch 252/256
# 10/10 [==============================] - 0s 39ms/step - loss: 0.1167 - auc: 0.9911 - val_loss: 0.4675 - val_auc: 0.9238
# Epoch 253/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1322 - auc: 0.9893 - val_loss: 0.4213 - val_auc: 0.9397
# Epoch 254/256
# 10/10 [==============================] - 0s 33ms/step - loss: 0.1368 - auc: 0.9883 - val_loss: 0.3976 - val_auc: 0.9272
# Epoch 255/256
# 10/10 [==============================] - 0s 37ms/step - loss: 0.1434 - auc: 0.9872 - val_loss: 0.4307 - val_auc: 0.9186
# Epoch 256/256
# 10/10 [==============================] - 0s 34ms/step - loss: 0.1350 - auc: 0.9882 - val_loss: 0.4258 - val_auc: 0.9399

# %% [markdown]
# # Save results

# %%
extractorEmb = Model(inputs=model.inputs,outputs=model.get_layer(name="clsTokenEmb").output)

preds = model.predict(x3,batch_size = config.BATCH_SIZE)

dbresults={}
dbresults['pred_emb'] = extractorEmb.predict(x3,batch_size = config.BATCH_SIZE)
dbresults['pred_cls'] = preds
dbresults['y_cls'] = labels
dbresults['formula'] = df['smiles']
dbresults['ids'] = df.iloc[:,0]
dbresults['types'] = types
dbresults['trainidx'] = trainidx
dbresults['testidx'] = testidx
dbresults['validx'] = validx

with open(mname+'_results.pkl', 'wb') as f:
    pickle.dump(dbresults, f)
# Out:
# 12/12 [==============================] - 1s 14ms/step
# 12/12 [==============================] - 0s 12ms/step

# %% [markdown]
# # Postprocessing

# %%
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
tsne = TSNE(n_components=2, verbose=0, random_state=123)
z = tsne.fit_transform(dbresults['pred_emb'])

# %%
dfr = pd.DataFrame()
dfr["y"] = np.asarray(dbresults['y_cls'].argmax(axis=-1))
dfr["yp"] = np.asarray(dbresults['pred_cls'].argmax(axis=-1))
dfr["tSNE1"] = z[:,0]
dfr["tSNE2"] = z[:,1]

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})
fig, axes = plt.subplots(1, 3, figsize=(15, 4.8))
y_pclasses = dbresults['pred_cls'][dbresults['testidx']].argmax(axis=-1)
y_classes = dbresults['y_cls'][dbresults['testidx']].argmax(axis=-1)
print('binary tf-acc:',tf.keras.metrics.binary_accuracy(y_classes, y_pclasses, threshold=0.5).numpy())
m = tf.keras.metrics.AUC()
m.update_state(dbresults['y_cls'][dbresults['testidx']], dbresults['pred_cls'][dbresults['testidx']])
print(mname, ' AUC:',m.result().numpy())
confusion_matrix = metrics.confusion_matrix(y_classes, y_pclasses)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)
                                            #display_labels=['False','True'])
cm_display.plot(ax=axes[0],cmap=plt.cm.Blues)

sns.scatterplot(ax=axes[1],x="tSNE1", y="tSNE2", hue=dfr.y.tolist(),data=dfr)#.set(title=title+" data T-SNE projection")
axes[1].set_xlabel('$tSNE_1$')
axes[1].set_ylabel('$tSNE_2$',labelpad=1)
axes[1].set_title('Reference')
#axes[1].legend('',frameon=False)
sns.scatterplot(ax=axes[2],x="tSNE1", y="tSNE2", hue=dfr.yp.tolist(),data=dfr)#.set(title=title+" data T-SNE projection")
axes[2].set_title('Predicted')
axes[2].set_xlabel('$tSNE_1$')
axes[2].set_ylabel('$tSNE_2$',labelpad=1)
axes[2].legend('',frameon=False)
fig.tight_layout()
plt.show()
plt.savefig(mname+'_tsnePaper.jpg',format='jpg',dpi=800,bbox_inches = "tight")
# Out:
# binary tf-acc: 0.8716216
# /content/elementsem/models/elembertR_clintox_V0_E_32_H_2_L_2_bert.h5  AUC: 0.9378652
