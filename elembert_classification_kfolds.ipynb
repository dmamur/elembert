# %% [markdown]
# <a href="https://colab.research.google.com/github/dmamur/elembert/blob/main/elembert_classification_kfolds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle,random
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Embedding,Dense,Dropout,Input,Lambda
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K
import re, glob,os,sys
from collections import defaultdict
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical

def bert_module(query, key, value, i, config):
    # Multi headed self-attention
    attention_output = layers.MultiHeadAttention(
        num_heads=config.NUM_HEAD,
        key_dim=config.EMBED_DIM // config.NUM_HEAD,
        name="encoder_{}/multiheadattention".format(i),
    )(query, key, value)
    attention_output = layers.Dropout(0.1, name="encoder_{}/att_dropout".format(i))(
        attention_output
    )
    attention_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/att_layernormalization".format(i)
    )(query + attention_output)

    # Feed-forward layer
    ffn = tf.keras.Sequential(
        [
            layers.Dense(config.FF_DIM, activation="relu"),
            layers.Dense(config.EMBED_DIM),
        ],
        name="encoder_{}/ffn".format(i),
    )
    ffn_output = ffn(attention_output)
    ffn_output = layers.Dropout(0.1, name="encoder_{}/ffn_dropout".format(i))(
        ffn_output
    )
    sequence_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}/ffn_layernormalization".format(i)
    )(attention_output + ffn_output)
    return sequence_output


def get_pos_encoding_matrix(max_len, d_emb):
    pos_enc = np.array(
        [
            [pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)]
            if pos != 0
            else np.zeros(d_emb)
            for pos in range(max_len)
        ]
    )
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2])  # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2])  # dim 2i+1
    return pos_enc

def create_elembert_model(inputs,config):
    word_embeddings = layers.Embedding(config.VOCAB_SIZE, config.EMBED_DIM, mask_zero=True,name="element_embdgs")(inputs)
    position_embeddings = layers.Embedding(input_dim=config.MAX_LEN,output_dim=config.EMBED_DIM,
                                           weights=[get_pos_encoding_matrix(config.MAX_LEN, config.EMBED_DIM)],
                                           name="position_embedding",)(tf.range(start=0, limit=config.MAX_LEN, delta=1))
    embeddings = word_embeddings + position_embeddings
    encoder_output = embeddings
    for i in range(config.NUM_LAYERS):
        encoder_output = bert_module(encoder_output, encoder_output, encoder_output, i, config)
    mlm_model = Model(inputs, encoder_output, name="masked_bert_model")

    return mlm_model

# %%
# !git clone https://github.com/dmamur/elembert.git
# Out:
# Cloning into 'elembert'...
# remote: Enumerating objects: 1038, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 1038 (delta 73), reused 4 (delta 4), pack-reused 918
# Receiving objects: 100% (1038/1038), 104.35 MiB | 11.50 MiB/s, done.
# Resolving deltas: 100% (532/532), done.
# Updating files: 100% (266/266), done.

# %%
class Config:
    MAX_LEN = 256
    BATCH_SIZE = 32
    LR = 0.001
    VOCAB_SIZE = 128
    EMBED_DIM = 32
    NUM_HEAD = 2 # used in bert model
    FF_DIM = 32 # used in bert model
    NUM_LAYERS = 2
    MNAME = 'elembert_'
    MVER = 'V1'
    DSPATH="/content/elementsem/data/"
    PREPATH="/content/elementsem/models/pretrained/"
    PATH="/content/elementsem/models/"
config = Config()
seed=12345
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
#'sider_1','sider_2','sider_3','sider_4','sider_5', 'sider_6','sider_7', 'sider_8', 'sider_9', 'sider_10', 'sider_11', 'sider_12',
#'sider_13', 'sider_14', 'sider_15','sider_16','sider_17','sider_18','sider_19','sider_20','sider_21','sider_22','sider_23',
#'sider_24','sider_25','sider_26','sider_27','dimensionality','spacegroup','liquid_amorphous','BBBP','bace','clintox','nr-ahr',
#'nr-ar','sr-atad5','nr-er-lbd','sr-p53','nr-ar-lbd','nr-ppar-gamma','sr-hse','nr-er','sr-mmp','nr-aromatase','sr-are','HIV'
ds = 'toxic_sr-mmp'
mname=config.PATH+config.MNAME+ds+'_%s_E_%s_H_%s_L_%s' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS)

# %% [markdown]
# # Load vocabulary and types

# %%
if (ds=='HIV'):
  df = pd.read_csv(config.DSPATH+ds+config.MVER+'_ds.csv')
else:
  df = pd.read_csv(config.DSPATH+ds+'_ds.csv')

types = df['types'+config.MVER].apply(eval).apply(list)
labels  = to_categorical(np.asarray(df['labels']))
uniquelbls=len(np.unique(np.asarray(df['labels'])))

with open(config.PREPATH+'/el2id'+config.MVER+'.pkl', 'rb') as f:
    db = pickle.load(f)

element2id = db['el2id']
el2id = db['el2id']
config.VOCAB_SIZE = len(element2id)
print('vocabSize: ', config.VOCAB_SIZE)
# Out:
# vocabSize:  565

# %% [markdown]
# # Convert types to integers

# %%
types0=[['[CLS]']+i+['[SEP]'] for i in types]
typesNumerical=[]
for i in types0:
    typesNumerical.append([element2id[j] for j in i])

x3 = tf.keras.preprocessing.sequence.pad_sequences(typesNumerical,dtype='int32',padding= 'post',truncating='post',maxlen=config.MAX_LEN)

#z = load_model(config.PREPATH+'/elembert_%s_E_%s_H_%s_L_%s.h5' % (config.MVER,config.EMBED_DIM,config.NUM_HEAD,config.NUM_LAYERS),compile=False)
#z.trainable = True

inputC = Input((config.MAX_LEN), dtype=tf.int32,name='types')
z = create_elembert_model(inputC,config)

e = Lambda(lambda x: x[:,0],name='clsTokenEmb')(z.output)
f = Dense(uniquelbls, activation="softmax",name='out_tox')(e)

model = Model(inputs=z.input, outputs=f)

plot_model(model, show_shapes=True, show_layer_names=True,to_file=mname+".png")

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=config.LR)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=[tf.keras.metrics.AUC()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  types (InputLayer)          [(None, 256)]                0         []
#
#  element_embdgs (Embedding)  (None, 256, 32)              18080     ['types[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 256, 32)              0         ['element_embdgs[0][0]']
#  Lambda)
#
#  encoder_0/multiheadattenti  (None, 256, 32)              4224      ['tf.__operators__.add[0][0]',
#  on (MultiHeadAttention)                                             'tf.__operators__.add[0][0]',
#                                                                      'tf.__operators__.add[0][0]']
#
#  encoder_0/att_dropout (Dro  (None, 256, 32)              0         ['encoder_0/multiheadattention
#  pout)                                                              [0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 256, 32)              0         ['tf.__operators__.add[0][0]',
#  OpLambda)                                                           'encoder_0/att_dropout[0][0]'
#                                                                     ]
#
#  encoder_0/att_layernormali  (None, 256, 32)              64        ['tf.__operators__.add_1[0][0]
#  zation (LayerNormalization                                         ']
#  )
#
#  encoder_0/ffn (Sequential)  (None, 256, 32)              2112      ['encoder_0/att_layernormaliza
#                                                                     tion[0][0]']
#
#  encoder_0/ffn_dropout (Dro  (None, 256, 32)              0         ['encoder_0/ffn[0][0]']
#  pout)
#
#  tf.__operators__.add_2 (TF  (None, 256, 32)              0         ['encoder_0/att_layernormaliza
#  OpLambda)                                                          tion[0][0]',
#                                                                      'encoder_0/ffn_dropout[0][0]'
#                                                                     ]
#
#  encoder_0/ffn_layernormali  (None, 256, 32)              64        ['tf.__operators__.add_2[0][0]
#  zation (LayerNormalization                                         ']
#  )
#
#  encoder_1/multiheadattenti  (None, 256, 32)              4224      ['encoder_0/ffn_layernormaliza
#  on (MultiHeadAttention)                                            tion[0][0]',
#                                                                      'encoder_0/ffn_layernormaliza
#                                                                     tion[0][0]',
#                                                                      'encoder_0/ffn_layernormaliza
#                                                                     tion[0][0]']
#
#  encoder_1/att_dropout (Dro  (None, 256, 32)              0         ['encoder_1/multiheadattention
#  pout)                                                              [0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 256, 32)              0         ['encoder_0/ffn_layernormaliza
#  OpLambda)                                                          tion[0][0]',
#                                                                      'encoder_1/att_dropout[0][0]'
#                                                                     ]
#
#  encoder_1/att_layernormali  (None, 256, 32)              64        ['tf.__operators__.add_3[0][0]
#  zation (LayerNormalization                                         ']
#  )
#
#  encoder_1/ffn (Sequential)  (None, 256, 32)              2112      ['encoder_1/att_layernormaliza
#                                                                     tion[0][0]']
#
#  encoder_1/ffn_dropout (Dro  (None, 256, 32)              0         ['encoder_1/ffn[0][0]']
#  pout)
#
#  tf.__operators__.add_4 (TF  (None, 256, 32)              0         ['encoder_1/att_layernormaliza
#  OpLambda)                                                          tion[0][0]',
#                                                                      'encoder_1/ffn_dropout[0][0]'
#                                                                     ]
#
#  encoder_1/ffn_layernormali  (None, 256, 32)              64        ['tf.__operators__.add_4[0][0]
#  zation (LayerNormalization                                         ']
#  )
#
#  clsTokenEmb (Lambda)        (None, 32)                   0         ['encoder_1/ffn_layernormaliza
#                                                                     tion[0][0]']
#
#  out_tox (Dense)             (None, 2)                    66        ['clsTokenEmb[0][0]']
#
# ==================================================================================================
# Total params: 31074 (121.38 KB)
# Trainable params: 31074 (121.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
epochs=4*config.BATCH_SIZE

print('dataLen: ',x3.shape,labels.shape)
# Out:
# dataLen:  (7320, 256) (7320, 2)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report

# Assuming you have loaded your data into x3 and labels variables

# Define the number of folds
num_folds = 5

# Initialize Stratified K-Fold Cross-Validator
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Initialize lists to store results
all_histories = []
all_reports = []

# Iterate over folds
for fold, (train_idx, val_idx) in enumerate(kfold.split(x3, np.argmax(labels, axis=1))):
    print(f"\nTraining on Fold {fold + 1}...")

    # Create and compile the model (assuming create_elembert_model function is available)
    model = Model(inputs=z.input, outputs=f)
    for layer in model.layers:
      if hasattr(layer, 'kernel_initializer') and layer.trainable:
        layer.kernel_initializer = tf.keras.initializers.GlorotUniform()

    optimizer = tf.keras.optimizers.Adam(learning_rate=config.LR)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=[tf.keras.metrics.AUC()])

    # Extract training and validation sets
    x_train, x_val = x3[train_idx], x3[val_idx]
    y_train, y_val = labels[train_idx], labels[val_idx]

    # Train the model
    history = model.fit(
        x=x_train,
        y=y_train,
        validation_data=(x_val, y_val),
        epochs=epochs,
        batch_size=config.BATCH_SIZE,
        verbose=1
    )

    # Evaluate the model on the validation set
    val_predictions = model.predict(x_val, batch_size=config.BATCH_SIZE)
    val_report = classification_report(np.argmax(y_val, axis=1), np.argmax(val_predictions, axis=1))

    # Append results to lists
    all_histories.append(history)
    all_reports.append(val_report)

# Print the average classification report across folds
avg_report = pd.DataFrame(all_reports).mean().to_dict()
print("\nAverage Classification Report Across Folds:")
print(avg_report)
# Out:
# Training on Fold 1...
# Epoch 1/128
# 183/183 [==============================] - 9s 25ms/step - loss: 0.1960 - auc_1: 0.9754 - val_loss: 0.1755 - val_auc_1: 0.9798
# Epoch 2/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.2005 - auc_1: 0.9748 - val_loss: 0.1833 - val_auc_1: 0.9784
# Epoch 3/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1817 - auc_1: 0.9790 - val_loss: 0.1812 - val_auc_1: 0.9794
# Epoch 4/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1865 - auc_1: 0.9781 - val_loss: 0.1866 - val_auc_1: 0.9783
# Epoch 5/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1789 - auc_1: 0.9795 - val_loss: 0.1795 - val_auc_1: 0.9786
# Epoch 6/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1777 - auc_1: 0.9800 - val_loss: 0.1911 - val_auc_1: 0.9777
# Epoch 7/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1799 - auc_1: 0.9794 - val_loss: 0.2262 - val_auc_1: 0.9716
# Epoch 8/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1726 - auc_1: 0.9811 - val_loss: 0.2010 - val_auc_1: 0.9756
# Epoch 9/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1724 - auc_1: 0.9814 - val_loss: 0.2049 - val_auc_1: 0.9742
# Epoch 10/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1719 - auc_1: 0.9815 - val_loss: 0.2007 - val_auc_1: 0.9765
# Epoch 11/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1725 - auc_1: 0.9814 - val_loss: 0.2009 - val_auc_1: 0.9760
# Epoch 12/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1706 - auc_1: 0.9815 - val_loss: 0.2051 - val_auc_1: 0.9763
# Epoch 13/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1636 - auc_1: 0.9831 - val_loss: 0.2036 - val_auc_1: 0.9762
# Epoch 14/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1655 - auc_1: 0.9826 - val_loss: 0.2253 - val_auc_1: 0.9729
# Epoch 15/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1775 - auc_1: 0.9806 - val_loss: 0.2049 - val_auc_1: 0.9747
# Epoch 16/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1739 - auc_1: 0.9810 - val_loss: 0.2332 - val_auc_1: 0.9698
# Epoch 17/128
# 183/183 [==============================] - 2s 14ms/step - loss: 0.1636 - auc_1: 0.9829 - val_loss: 0.2375 - val_auc_1: 0.9700
# Epoch 18/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1596 - auc_1: 0.9839 - val_loss: 0.2372 - val_auc_1: 0.9696
# Epoch 19/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1654 - auc_1: 0.9826 - val_loss: 0.2085 - val_auc_1: 0.9747
# Epoch 20/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1601 - auc_1: 0.9838 - val_loss: 0.2162 - val_auc_1: 0.9738
# Epoch 21/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1574 - auc_1: 0.9844 - val_loss: 0.2537 - val_auc_1: 0.9663
# Epoch 22/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1600 - auc_1: 0.9839 - val_loss: 0.2174 - val_auc_1: 0.9715
# Epoch 23/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1573 - auc_1: 0.9843 - val_loss: 0.2346 - val_auc_1: 0.9693
# Epoch 24/128
# 183/183 [==============================] - 2s 14ms/step - loss: 0.1550 - auc_1: 0.9844 - val_loss: 0.2276 - val_auc_1: 0.9704
# Epoch 25/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1540 - auc_1: 0.9847 - val_loss: 0.2412 - val_auc_1: 0.9684
# Epoch 26/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1567 - auc_1: 0.9847 - val_loss: 0.2325 - val_auc_1: 0.9708
# Epoch 27/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1584 - auc_1: 0.9842 - val_loss: 0.2281 - val_auc_1: 0.9692
# Epoch 28/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1480 - auc_1: 0.9859 - val_loss: 0.2325 - val_auc_1: 0.9703
# Epoch 29/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1600 - auc_1: 0.9841 - val_loss: 0.2390 - val_auc_1: 0.9679
# Epoch 30/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1565 - auc_1: 0.9844 - val_loss: 0.2404 - val_auc_1: 0.9690
# Epoch 31/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1534 - auc_1: 0.9852 - val_loss: 0.2410 - val_auc_1: 0.9695
# Epoch 32/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1456 - auc_1: 0.9864 - val_loss: 0.2588 - val_auc_1: 0.9670
# Epoch 33/128
# 183/183 [==============================] - 2s 14ms/step - loss: 0.1522 - auc_1: 0.9856 - val_loss: 0.2532 - val_auc_1: 0.9672
# Epoch 34/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1594 - auc_1: 0.9840 - val_loss: 0.2354 - val_auc_1: 0.9676
# Epoch 35/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1507 - auc_1: 0.9855 - val_loss: 0.2335 - val_auc_1: 0.9700
# Epoch 36/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1436 - auc_1: 0.9869 - val_loss: 0.2373 - val_auc_1: 0.9686
# Epoch 37/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1485 - auc_1: 0.9860 - val_loss: 0.2474 - val_auc_1: 0.9655
# Epoch 38/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1492 - auc_1: 0.9855 - val_loss: 0.2495 - val_auc_1: 0.9657
# Epoch 39/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1480 - auc_1: 0.9860 - val_loss: 0.2465 - val_auc_1: 0.9642
# Epoch 40/128
# 183/183 [==============================] - 2s 14ms/step - loss: 0.1489 - auc_1: 0.9853 - val_loss: 0.2348 - val_auc_1: 0.9688
# Epoch 41/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1445 - auc_1: 0.9866 - val_loss: 0.2509 - val_auc_1: 0.9661
# Epoch 42/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1377 - auc_1: 0.9882 - val_loss: 0.2587 - val_auc_1: 0.9669
# Epoch 43/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1463 - auc_1: 0.9865 - val_loss: 0.2730 - val_auc_1: 0.9622
# Epoch 44/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1499 - auc_1: 0.9856 - val_loss: 0.2500 - val_auc_1: 0.9680
# Epoch 45/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1445 - auc_1: 0.9867 - val_loss: 0.2361 - val_auc_1: 0.9682
# Epoch 46/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1455 - auc_1: 0.9866 - val_loss: 0.2454 - val_auc_1: 0.9674
# Epoch 47/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1390 - auc_1: 0.9876 - val_loss: 0.2439 - val_auc_1: 0.9684
# Epoch 48/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1294 - auc_1: 0.9894 - val_loss: 0.2527 - val_auc_1: 0.9668
# Epoch 49/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1472 - auc_1: 0.9863 - val_loss: 0.2443 - val_auc_1: 0.9679
# Epoch 50/128
# 183/183 [==============================] - 2s 14ms/step - loss: 0.1353 - auc_1: 0.9883 - val_loss: 0.2490 - val_auc_1: 0.9682
# Epoch 51/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1365 - auc_1: 0.9884 - val_loss: 0.2347 - val_auc_1: 0.9687
# Epoch 52/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1381 - auc_1: 0.9880 - val_loss: 0.2449 - val_auc_1: 0.9672
# Epoch 53/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1367 - auc_1: 0.9879 - val_loss: 0.2747 - val_auc_1: 0.9626
# Epoch 54/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1329 - auc_1: 0.9889 - val_loss: 0.2986 - val_auc_1: 0.9615
# Epoch 55/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1344 - auc_1: 0.9886 - val_loss: 0.2846 - val_auc_1: 0.9635
# Epoch 56/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1319 - auc_1: 0.9890 - val_loss: 0.2616 - val_auc_1: 0.9634
# Epoch 57/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1347 - auc_1: 0.9884 - val_loss: 0.2619 - val_auc_1: 0.9645
# Epoch 58/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1228 - auc_1: 0.9902 - val_loss: 0.2917 - val_auc_1: 0.9617
# Epoch 59/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1370 - auc_1: 0.9881 - val_loss: 0.2714 - val_auc_1: 0.9633
# Epoch 60/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1387 - auc_1: 0.9881 - val_loss: 0.2730 - val_auc_1: 0.9635
# Epoch 61/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1304 - auc_1: 0.9891 - val_loss: 0.2679 - val_auc_1: 0.9638
# Epoch 62/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1346 - auc_1: 0.9884 - val_loss: 0.2831 - val_auc_1: 0.9622
# Epoch 63/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1262 - auc_1: 0.9899 - val_loss: 0.2791 - val_auc_1: 0.9614
# Epoch 64/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1327 - auc_1: 0.9886 - val_loss: 0.2711 - val_auc_1: 0.9644
# Epoch 65/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1232 - auc_1: 0.9904 - val_loss: 0.2709 - val_auc_1: 0.9619
# Epoch 66/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1292 - auc_1: 0.9892 - val_loss: 0.2640 - val_auc_1: 0.9664
# Epoch 67/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1385 - auc_1: 0.9878 - val_loss: 0.2809 - val_auc_1: 0.9609
# Epoch 68/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1321 - auc_1: 0.9886 - val_loss: 0.2724 - val_auc_1: 0.9644
# Epoch 69/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1216 - auc_1: 0.9907 - val_loss: 0.2813 - val_auc_1: 0.9611
# Epoch 70/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1278 - auc_1: 0.9897 - val_loss: 0.2764 - val_auc_1: 0.9621
# Epoch 71/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1172 - auc_1: 0.9912 - val_loss: 0.2861 - val_auc_1: 0.9614
# Epoch 72/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1229 - auc_1: 0.9903 - val_loss: 0.2915 - val_auc_1: 0.9629
# Epoch 73/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1185 - auc_1: 0.9905 - val_loss: 0.2787 - val_auc_1: 0.9605
# Epoch 74/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1238 - auc_1: 0.9902 - val_loss: 0.2770 - val_auc_1: 0.9650
# Epoch 75/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1155 - auc_1: 0.9912 - val_loss: 0.2747 - val_auc_1: 0.9645
# Epoch 76/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1230 - auc_1: 0.9904 - val_loss: 0.2844 - val_auc_1: 0.9619
# Epoch 77/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1259 - auc_1: 0.9899 - val_loss: 0.2788 - val_auc_1: 0.9626
# Epoch 78/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1281 - auc_1: 0.9896 - val_loss: 0.2795 - val_auc_1: 0.9612
# Epoch 79/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1211 - auc_1: 0.9907 - val_loss: 0.2811 - val_auc_1: 0.9608
# Epoch 80/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1160 - auc_1: 0.9915 - val_loss: 0.2744 - val_auc_1: 0.9635
# Epoch 81/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1224 - auc_1: 0.9901 - val_loss: 0.2670 - val_auc_1: 0.9647
# Epoch 82/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1153 - auc_1: 0.9915 - val_loss: 0.2643 - val_auc_1: 0.9641
# Epoch 83/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1207 - auc_1: 0.9906 - val_loss: 0.2879 - val_auc_1: 0.9594
# Epoch 84/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1173 - auc_1: 0.9907 - val_loss: 0.2840 - val_auc_1: 0.9629
# Epoch 85/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1179 - auc_1: 0.9909 - val_loss: 0.3045 - val_auc_1: 0.9574
# Epoch 86/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1120 - auc_1: 0.9919 - val_loss: 0.2949 - val_auc_1: 0.9578
# Epoch 87/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1047 - auc_1: 0.9931 - val_loss: 0.3209 - val_auc_1: 0.9579
# Epoch 88/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1140 - auc_1: 0.9911 - val_loss: 0.3171 - val_auc_1: 0.9530
# Epoch 89/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1205 - auc_1: 0.9904 - val_loss: 0.2865 - val_auc_1: 0.9620
# Epoch 90/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.1217 - auc_1: 0.9903 - val_loss: 0.2833 - val_auc_1: 0.9619
# Epoch 91/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1114 - auc_1: 0.9920 - val_loss: 0.3243 - val_auc_1: 0.9553
# Epoch 92/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1180 - auc_1: 0.9907 - val_loss: 0.3096 - val_auc_1: 0.9584
# Epoch 93/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1174 - auc_1: 0.9912 - val_loss: 0.2964 - val_auc_1: 0.9590
# Epoch 94/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1139 - auc_1: 0.9917 - val_loss: 0.3092 - val_auc_1: 0.9562
# Epoch 95/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1225 - auc_1: 0.9906 - val_loss: 0.2990 - val_auc_1: 0.9553
# Epoch 96/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1145 - auc_1: 0.9916 - val_loss: 0.2849 - val_auc_1: 0.9614
# Epoch 97/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1077 - auc_1: 0.9923 - val_loss: 0.2769 - val_auc_1: 0.9614
# Epoch 98/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1109 - auc_1: 0.9919 - val_loss: 0.2922 - val_auc_1: 0.9574
# Epoch 99/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1067 - auc_1: 0.9927 - val_loss: 0.3196 - val_auc_1: 0.9555
# Epoch 100/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1128 - auc_1: 0.9920 - val_loss: 0.3074 - val_auc_1: 0.9551
# Epoch 101/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1068 - auc_1: 0.9927 - val_loss: 0.3120 - val_auc_1: 0.9578
# Epoch 102/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1118 - auc_1: 0.9918 - val_loss: 0.2948 - val_auc_1: 0.9596
# Epoch 103/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1111 - auc_1: 0.9921 - val_loss: 0.2723 - val_auc_1: 0.9624
# Epoch 104/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1081 - auc_1: 0.9924 - val_loss: 0.2956 - val_auc_1: 0.9605
# Epoch 105/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1041 - auc_1: 0.9931 - val_loss: 0.3112 - val_auc_1: 0.9584
# Epoch 106/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1079 - auc_1: 0.9924 - val_loss: 0.3209 - val_auc_1: 0.9572
# Epoch 107/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1047 - auc_1: 0.9928 - val_loss: 0.3273 - val_auc_1: 0.9583
# Epoch 108/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0963 - auc_1: 0.9942 - val_loss: 0.3666 - val_auc_1: 0.9497
# Epoch 109/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1081 - auc_1: 0.9924 - val_loss: 0.3205 - val_auc_1: 0.9588
# Epoch 110/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1016 - auc_1: 0.9931 - val_loss: 0.3383 - val_auc_1: 0.9519
# Epoch 111/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1036 - auc_1: 0.9929 - val_loss: 0.3108 - val_auc_1: 0.9593
# Epoch 112/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1071 - auc_1: 0.9926 - val_loss: 0.2916 - val_auc_1: 0.9592
# Epoch 113/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1086 - auc_1: 0.9923 - val_loss: 0.3045 - val_auc_1: 0.9608
# Epoch 114/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1068 - auc_1: 0.9924 - val_loss: 0.3015 - val_auc_1: 0.9567
# Epoch 115/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1099 - auc_1: 0.9924 - val_loss: 0.3163 - val_auc_1: 0.9593
# Epoch 116/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.1024 - auc_1: 0.9932 - val_loss: 0.3298 - val_auc_1: 0.9536
# Epoch 117/128
# 183/183 [==============================] - 2s 11ms/step - loss: 0.0951 - auc_1: 0.9939 - val_loss: 0.3217 - val_auc_1: 0.9589
# Epoch 118/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1035 - auc_1: 0.9929 - val_loss: 0.3139 - val_auc_1: 0.9584
# Epoch 119/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1063 - auc_1: 0.9925 - val_loss: 0.3003 - val_auc_1: 0.9587
# Epoch 120/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0974 - auc_1: 0.9939 - val_loss: 0.3367 - val_auc_1: 0.9556
# Epoch 121/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0975 - auc_1: 0.9935 - val_loss: 0.3322 - val_auc_1: 0.9568
# Epoch 122/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1059 - auc_1: 0.9927 - val_loss: 0.3246 - val_auc_1: 0.9549
# Epoch 123/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0956 - auc_1: 0.9940 - val_loss: 0.3368 - val_auc_1: 0.9563
# Epoch 124/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.1046 - auc_1: 0.9930 - val_loss: 0.3319 - val_auc_1: 0.9561
# Epoch 125/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0935 - auc_1: 0.9941 - val_loss: 0.3691 - val_auc_1: 0.9513
# Epoch 126/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0918 - auc_1: 0.9943 - val_loss: 0.3437 - val_auc_1: 0.9523
# Epoch 127/128
# 183/183 [==============================] - 2s 14ms/step - loss: 0.0985 - auc_1: 0.9937 - val_loss: 0.3276 - val_auc_1: 0.9585
# Epoch 128/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1115 - auc_1: 0.9919 - val_loss: 0.3021 - val_auc_1: 0.9593
# 46/46 [==============================] - 1s 7ms/step
#
# Training on Fold 2...
# Epoch 1/128
# 183/183 [==============================] - 10s 26ms/step - loss: 0.1608 - auc_2: 0.9830 - val_loss: 0.0883 - val_auc_2: 0.9954
# Epoch 2/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1433 - auc_2: 0.9861 - val_loss: 0.0908 - val_auc_2: 0.9950
# Epoch 3/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1298 - auc_2: 0.9887 - val_loss: 0.1059 - val_auc_2: 0.9929
# Epoch 4/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1352 - auc_2: 0.9879 - val_loss: 0.1099 - val_auc_2: 0.9925
# Epoch 5/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1309 - auc_2: 0.9887 - val_loss: 0.1057 - val_auc_2: 0.9930
# Epoch 6/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1367 - auc_2: 0.9875 - val_loss: 0.1351 - val_auc_2: 0.9893
# Epoch 7/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1247 - auc_2: 0.9898 - val_loss: 0.1240 - val_auc_2: 0.9903
# Epoch 8/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1283 - auc_2: 0.9888 - val_loss: 0.1062 - val_auc_2: 0.9926
# Epoch 9/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1250 - auc_2: 0.9898 - val_loss: 0.1177 - val_auc_2: 0.9912
# Epoch 10/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1176 - auc_2: 0.9906 - val_loss: 0.1308 - val_auc_2: 0.9895
# Epoch 11/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1228 - auc_2: 0.9898 - val_loss: 0.1436 - val_auc_2: 0.9872
# Epoch 12/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1229 - auc_2: 0.9900 - val_loss: 0.1295 - val_auc_2: 0.9896
# Epoch 13/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1181 - auc_2: 0.9906 - val_loss: 0.1190 - val_auc_2: 0.9912
# Epoch 14/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1259 - auc_2: 0.9892 - val_loss: 0.1481 - val_auc_2: 0.9868
# Epoch 15/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1219 - auc_2: 0.9901 - val_loss: 0.1651 - val_auc_2: 0.9849
# Epoch 16/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.1240 - auc_2: 0.9897 - val_loss: 0.1617 - val_auc_2: 0.9856
# Epoch 17/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1159 - auc_2: 0.9909 - val_loss: 0.1623 - val_auc_2: 0.9844
# Epoch 18/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1158 - auc_2: 0.9908 - val_loss: 0.1835 - val_auc_2: 0.9811
# Epoch 19/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1161 - auc_2: 0.9909 - val_loss: 0.1497 - val_auc_2: 0.9868
# Epoch 20/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1208 - auc_2: 0.9902 - val_loss: 0.1796 - val_auc_2: 0.9822
# Epoch 21/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1199 - auc_2: 0.9902 - val_loss: 0.1541 - val_auc_2: 0.9859
# Epoch 22/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.1044 - auc_2: 0.9925 - val_loss: 0.1522 - val_auc_2: 0.9860
# Epoch 23/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1169 - auc_2: 0.9906 - val_loss: 0.1616 - val_auc_2: 0.9841
# Epoch 24/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1157 - auc_2: 0.9911 - val_loss: 0.1634 - val_auc_2: 0.9842
# Epoch 25/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1098 - auc_2: 0.9917 - val_loss: 0.1610 - val_auc_2: 0.9858
# Epoch 26/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1025 - auc_2: 0.9925 - val_loss: 0.1624 - val_auc_2: 0.9855
# Epoch 27/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1057 - auc_2: 0.9921 - val_loss: 0.1511 - val_auc_2: 0.9870
# Epoch 28/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1191 - auc_2: 0.9906 - val_loss: 0.1487 - val_auc_2: 0.9869
# Epoch 29/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1077 - auc_2: 0.9924 - val_loss: 0.1506 - val_auc_2: 0.9868
# Epoch 30/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1090 - auc_2: 0.9915 - val_loss: 0.1700 - val_auc_2: 0.9842
# Epoch 31/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1106 - auc_2: 0.9918 - val_loss: 0.1678 - val_auc_2: 0.9847
# Epoch 32/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1098 - auc_2: 0.9917 - val_loss: 0.1629 - val_auc_2: 0.9854
# Epoch 33/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.1064 - auc_2: 0.9919 - val_loss: 0.1673 - val_auc_2: 0.9833
# Epoch 34/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1075 - auc_2: 0.9918 - val_loss: 0.1665 - val_auc_2: 0.9847
# Epoch 35/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1020 - auc_2: 0.9929 - val_loss: 0.1704 - val_auc_2: 0.9841
# Epoch 36/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1123 - auc_2: 0.9914 - val_loss: 0.1633 - val_auc_2: 0.9839
# Epoch 37/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1027 - auc_2: 0.9929 - val_loss: 0.1884 - val_auc_2: 0.9805
# Epoch 38/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1067 - auc_2: 0.9923 - val_loss: 0.1809 - val_auc_2: 0.9830
# Epoch 39/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1076 - auc_2: 0.9920 - val_loss: 0.1688 - val_auc_2: 0.9839
# Epoch 40/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1003 - auc_2: 0.9934 - val_loss: 0.1812 - val_auc_2: 0.9816
# Epoch 41/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0961 - auc_2: 0.9932 - val_loss: 0.1813 - val_auc_2: 0.9822
# Epoch 42/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1015 - auc_2: 0.9927 - val_loss: 0.1889 - val_auc_2: 0.9803
# Epoch 43/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1026 - auc_2: 0.9932 - val_loss: 0.1980 - val_auc_2: 0.9787
# Epoch 44/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.1126 - auc_2: 0.9916 - val_loss: 0.1868 - val_auc_2: 0.9809
# Epoch 45/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0987 - auc_2: 0.9931 - val_loss: 0.2047 - val_auc_2: 0.9786
# Epoch 46/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0975 - auc_2: 0.9937 - val_loss: 0.2084 - val_auc_2: 0.9781
# Epoch 47/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1081 - auc_2: 0.9919 - val_loss: 0.1761 - val_auc_2: 0.9815
# Epoch 48/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1043 - auc_2: 0.9924 - val_loss: 0.1971 - val_auc_2: 0.9805
# Epoch 49/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1039 - auc_2: 0.9926 - val_loss: 0.2147 - val_auc_2: 0.9769
# Epoch 50/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0987 - auc_2: 0.9935 - val_loss: 0.1898 - val_auc_2: 0.9800
# Epoch 51/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0972 - auc_2: 0.9935 - val_loss: 0.1965 - val_auc_2: 0.9781
# Epoch 52/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0983 - auc_2: 0.9936 - val_loss: 0.1805 - val_auc_2: 0.9816
# Epoch 53/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0916 - auc_2: 0.9938 - val_loss: 0.1913 - val_auc_2: 0.9787
# Epoch 54/128
# 183/183 [==============================] - 3s 18ms/step - loss: 0.0952 - auc_2: 0.9934 - val_loss: 0.2037 - val_auc_2: 0.9771
# Epoch 55/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0978 - auc_2: 0.9937 - val_loss: 0.1909 - val_auc_2: 0.9795
# Epoch 56/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1004 - auc_2: 0.9935 - val_loss: 0.2145 - val_auc_2: 0.9741
# Epoch 57/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1047 - auc_2: 0.9925 - val_loss: 0.2153 - val_auc_2: 0.9754
# Epoch 58/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0965 - auc_2: 0.9940 - val_loss: 0.2012 - val_auc_2: 0.9794
# Epoch 59/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0976 - auc_2: 0.9935 - val_loss: 0.1969 - val_auc_2: 0.9796
# Epoch 60/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0929 - auc_2: 0.9945 - val_loss: 0.2091 - val_auc_2: 0.9792
# Epoch 61/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0896 - auc_2: 0.9941 - val_loss: 0.2050 - val_auc_2: 0.9805
# Epoch 62/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0889 - auc_2: 0.9947 - val_loss: 0.2394 - val_auc_2: 0.9737
# Epoch 63/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0873 - auc_2: 0.9949 - val_loss: 0.2197 - val_auc_2: 0.9775
# Epoch 64/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0901 - auc_2: 0.9943 - val_loss: 0.2464 - val_auc_2: 0.9708
# Epoch 65/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0994 - auc_2: 0.9934 - val_loss: 0.2200 - val_auc_2: 0.9743
# Epoch 66/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0972 - auc_2: 0.9938 - val_loss: 0.2106 - val_auc_2: 0.9775
# Epoch 67/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0945 - auc_2: 0.9941 - val_loss: 0.2071 - val_auc_2: 0.9764
# Epoch 68/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0932 - auc_2: 0.9945 - val_loss: 0.2150 - val_auc_2: 0.9775
# Epoch 69/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0976 - auc_2: 0.9934 - val_loss: 0.2203 - val_auc_2: 0.9751
# Epoch 70/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0955 - auc_2: 0.9939 - val_loss: 0.2199 - val_auc_2: 0.9763
# Epoch 71/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0931 - auc_2: 0.9938 - val_loss: 0.2304 - val_auc_2: 0.9731
# Epoch 72/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0925 - auc_2: 0.9944 - val_loss: 0.2270 - val_auc_2: 0.9738
# Epoch 73/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0886 - auc_2: 0.9946 - val_loss: 0.2288 - val_auc_2: 0.9763
# Epoch 74/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0926 - auc_2: 0.9939 - val_loss: 0.2355 - val_auc_2: 0.9725
# Epoch 75/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0908 - auc_2: 0.9941 - val_loss: 0.2390 - val_auc_2: 0.9712
# Epoch 76/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0949 - auc_2: 0.9936 - val_loss: 0.2356 - val_auc_2: 0.9756
# Epoch 77/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0970 - auc_2: 0.9935 - val_loss: 0.2407 - val_auc_2: 0.9704
# Epoch 78/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0961 - auc_2: 0.9933 - val_loss: 0.2379 - val_auc_2: 0.9730
# Epoch 79/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0907 - auc_2: 0.9943 - val_loss: 0.2267 - val_auc_2: 0.9728
# Epoch 80/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0888 - auc_2: 0.9946 - val_loss: 0.2351 - val_auc_2: 0.9742
# Epoch 81/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0890 - auc_2: 0.9946 - val_loss: 0.2342 - val_auc_2: 0.9742
# Epoch 82/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0816 - auc_2: 0.9953 - val_loss: 0.2527 - val_auc_2: 0.9738
# Epoch 83/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0929 - auc_2: 0.9939 - val_loss: 0.2205 - val_auc_2: 0.9749
# Epoch 84/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0848 - auc_2: 0.9953 - val_loss: 0.2351 - val_auc_2: 0.9753
# Epoch 85/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0913 - auc_2: 0.9950 - val_loss: 0.2111 - val_auc_2: 0.9768
# Epoch 86/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0896 - auc_2: 0.9947 - val_loss: 0.2205 - val_auc_2: 0.9766
# Epoch 87/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0868 - auc_2: 0.9951 - val_loss: 0.2524 - val_auc_2: 0.9704
# Epoch 88/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0861 - auc_2: 0.9949 - val_loss: 0.2444 - val_auc_2: 0.9688
# Epoch 89/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0864 - auc_2: 0.9950 - val_loss: 0.2245 - val_auc_2: 0.9766
# Epoch 90/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0858 - auc_2: 0.9952 - val_loss: 0.2389 - val_auc_2: 0.9736
# Epoch 91/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0953 - auc_2: 0.9941 - val_loss: 0.2238 - val_auc_2: 0.9748
# Epoch 92/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0879 - auc_2: 0.9947 - val_loss: 0.2766 - val_auc_2: 0.9680
# Epoch 93/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0937 - auc_2: 0.9942 - val_loss: 0.2463 - val_auc_2: 0.9754
# Epoch 94/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0858 - auc_2: 0.9948 - val_loss: 0.2459 - val_auc_2: 0.9729
# Epoch 95/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0829 - auc_2: 0.9955 - val_loss: 0.2303 - val_auc_2: 0.9732
# Epoch 96/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0802 - auc_2: 0.9961 - val_loss: 0.2578 - val_auc_2: 0.9702
# Epoch 97/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0852 - auc_2: 0.9951 - val_loss: 0.2614 - val_auc_2: 0.9699
# Epoch 98/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0903 - auc_2: 0.9947 - val_loss: 0.2321 - val_auc_2: 0.9749
# Epoch 99/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0814 - auc_2: 0.9957 - val_loss: 0.2325 - val_auc_2: 0.9728
# Epoch 100/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0806 - auc_2: 0.9955 - val_loss: 0.2413 - val_auc_2: 0.9734
# Epoch 101/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0888 - auc_2: 0.9947 - val_loss: 0.2689 - val_auc_2: 0.9698
# Epoch 102/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0867 - auc_2: 0.9947 - val_loss: 0.2389 - val_auc_2: 0.9735
# Epoch 103/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0820 - auc_2: 0.9951 - val_loss: 0.2427 - val_auc_2: 0.9728
# Epoch 104/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0864 - auc_2: 0.9951 - val_loss: 0.2625 - val_auc_2: 0.9688
# Epoch 105/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0835 - auc_2: 0.9952 - val_loss: 0.2551 - val_auc_2: 0.9706
# Epoch 106/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0874 - auc_2: 0.9947 - val_loss: 0.2500 - val_auc_2: 0.9706
# Epoch 107/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0815 - auc_2: 0.9952 - val_loss: 0.2655 - val_auc_2: 0.9676
# Epoch 108/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0820 - auc_2: 0.9954 - val_loss: 0.2810 - val_auc_2: 0.9683
# Epoch 109/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0798 - auc_2: 0.9957 - val_loss: 0.2376 - val_auc_2: 0.9718
# Epoch 110/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0897 - auc_2: 0.9944 - val_loss: 0.2293 - val_auc_2: 0.9722
# Epoch 111/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0749 - auc_2: 0.9958 - val_loss: 0.2612 - val_auc_2: 0.9709
# Epoch 112/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0908 - auc_2: 0.9944 - val_loss: 0.2458 - val_auc_2: 0.9726
# Epoch 113/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0826 - auc_2: 0.9950 - val_loss: 0.2631 - val_auc_2: 0.9666
# Epoch 114/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0867 - auc_2: 0.9949 - val_loss: 0.2553 - val_auc_2: 0.9684
# Epoch 115/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0778 - auc_2: 0.9960 - val_loss: 0.2700 - val_auc_2: 0.9682
# Epoch 116/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0792 - auc_2: 0.9951 - val_loss: 0.2634 - val_auc_2: 0.9689
# Epoch 117/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0853 - auc_2: 0.9950 - val_loss: 0.2615 - val_auc_2: 0.9688
# Epoch 118/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0808 - auc_2: 0.9954 - val_loss: 0.2674 - val_auc_2: 0.9662
# Epoch 119/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0785 - auc_2: 0.9959 - val_loss: 0.2917 - val_auc_2: 0.9634
# Epoch 120/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0812 - auc_2: 0.9958 - val_loss: 0.2817 - val_auc_2: 0.9651
# Epoch 121/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0781 - auc_2: 0.9959 - val_loss: 0.2670 - val_auc_2: 0.9705
# Epoch 122/128
# 183/183 [==============================] - 3s 18ms/step - loss: 0.0760 - auc_2: 0.9962 - val_loss: 0.2851 - val_auc_2: 0.9654
# Epoch 123/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0943 - auc_2: 0.9941 - val_loss: 0.2724 - val_auc_2: 0.9692
# Epoch 124/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0797 - auc_2: 0.9958 - val_loss: 0.2794 - val_auc_2: 0.9652
# Epoch 125/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0721 - auc_2: 0.9966 - val_loss: 0.3101 - val_auc_2: 0.9637
# Epoch 126/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0734 - auc_2: 0.9964 - val_loss: 0.2841 - val_auc_2: 0.9649
# Epoch 127/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0866 - auc_2: 0.9948 - val_loss: 0.2854 - val_auc_2: 0.9672
# Epoch 128/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0770 - auc_2: 0.9961 - val_loss: 0.2986 - val_auc_2: 0.9632
# 46/46 [==============================] - 1s 7ms/step
#
# Training on Fold 3...
# Epoch 1/128
# 183/183 [==============================] - 9s 24ms/step - loss: 0.1292 - auc_3: 0.9883 - val_loss: 0.0562 - val_auc_3: 0.9986
# Epoch 2/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1139 - auc_3: 0.9914 - val_loss: 0.0612 - val_auc_3: 0.9983
# Epoch 3/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1107 - auc_3: 0.9918 - val_loss: 0.0539 - val_auc_3: 0.9983
# Epoch 4/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.1086 - auc_3: 0.9922 - val_loss: 0.0573 - val_auc_3: 0.9984
# Epoch 5/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1087 - auc_3: 0.9922 - val_loss: 0.0766 - val_auc_3: 0.9959
# Epoch 6/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1027 - auc_3: 0.9930 - val_loss: 0.0701 - val_auc_3: 0.9964
# Epoch 7/128
# 183/183 [==============================] - 3s 18ms/step - loss: 0.1101 - auc_3: 0.9919 - val_loss: 0.0777 - val_auc_3: 0.9959
# Epoch 8/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1019 - auc_3: 0.9933 - val_loss: 0.0895 - val_auc_3: 0.9943
# Epoch 9/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1072 - auc_3: 0.9922 - val_loss: 0.0966 - val_auc_3: 0.9938
# Epoch 10/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1076 - auc_3: 0.9925 - val_loss: 0.0753 - val_auc_3: 0.9955
# Epoch 11/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0997 - auc_3: 0.9930 - val_loss: 0.0718 - val_auc_3: 0.9965
# Epoch 12/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0970 - auc_3: 0.9932 - val_loss: 0.0827 - val_auc_3: 0.9956
# Epoch 13/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0936 - auc_3: 0.9942 - val_loss: 0.0816 - val_auc_3: 0.9954
# Epoch 14/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0905 - auc_3: 0.9945 - val_loss: 0.0911 - val_auc_3: 0.9951
# Epoch 15/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0939 - auc_3: 0.9944 - val_loss: 0.0895 - val_auc_3: 0.9952
# Epoch 16/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0879 - auc_3: 0.9951 - val_loss: 0.1019 - val_auc_3: 0.9929
# Epoch 17/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0995 - auc_3: 0.9932 - val_loss: 0.0925 - val_auc_3: 0.9942
# Epoch 18/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0926 - auc_3: 0.9944 - val_loss: 0.0907 - val_auc_3: 0.9940
# Epoch 19/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0970 - auc_3: 0.9940 - val_loss: 0.0999 - val_auc_3: 0.9936
# Epoch 20/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0947 - auc_3: 0.9940 - val_loss: 0.1024 - val_auc_3: 0.9928
# Epoch 21/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0885 - auc_3: 0.9946 - val_loss: 0.1159 - val_auc_3: 0.9917
# Epoch 22/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0954 - auc_3: 0.9936 - val_loss: 0.1043 - val_auc_3: 0.9930
# Epoch 23/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0825 - auc_3: 0.9956 - val_loss: 0.1129 - val_auc_3: 0.9921
# Epoch 24/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0930 - auc_3: 0.9941 - val_loss: 0.1275 - val_auc_3: 0.9894
# Epoch 25/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0847 - auc_3: 0.9954 - val_loss: 0.1089 - val_auc_3: 0.9917
# Epoch 26/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0897 - auc_3: 0.9947 - val_loss: 0.1226 - val_auc_3: 0.9903
# Epoch 27/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.1001 - auc_3: 0.9933 - val_loss: 0.1026 - val_auc_3: 0.9928
# Epoch 28/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0840 - auc_3: 0.9953 - val_loss: 0.1191 - val_auc_3: 0.9914
# Epoch 29/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0871 - auc_3: 0.9947 - val_loss: 0.1087 - val_auc_3: 0.9927
# Epoch 30/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0872 - auc_3: 0.9951 - val_loss: 0.1062 - val_auc_3: 0.9927
# Epoch 31/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0877 - auc_3: 0.9949 - val_loss: 0.1080 - val_auc_3: 0.9919
# Epoch 32/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0858 - auc_3: 0.9951 - val_loss: 0.1142 - val_auc_3: 0.9899
# Epoch 33/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0900 - auc_3: 0.9948 - val_loss: 0.1104 - val_auc_3: 0.9919
# Epoch 34/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0923 - auc_3: 0.9945 - val_loss: 0.1109 - val_auc_3: 0.9913
# Epoch 35/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0852 - auc_3: 0.9951 - val_loss: 0.1472 - val_auc_3: 0.9863
# Epoch 36/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0908 - auc_3: 0.9947 - val_loss: 0.1317 - val_auc_3: 0.9873
# Epoch 37/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0883 - auc_3: 0.9949 - val_loss: 0.1207 - val_auc_3: 0.9899
# Epoch 38/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0837 - auc_3: 0.9955 - val_loss: 0.1519 - val_auc_3: 0.9859
# Epoch 39/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0935 - auc_3: 0.9942 - val_loss: 0.1364 - val_auc_3: 0.9886
# Epoch 40/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0889 - auc_3: 0.9946 - val_loss: 0.1381 - val_auc_3: 0.9862
# Epoch 41/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0848 - auc_3: 0.9949 - val_loss: 0.1478 - val_auc_3: 0.9864
# Epoch 42/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0825 - auc_3: 0.9954 - val_loss: 0.1417 - val_auc_3: 0.9875
# Epoch 43/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0859 - auc_3: 0.9952 - val_loss: 0.1290 - val_auc_3: 0.9896
# Epoch 44/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0789 - auc_3: 0.9957 - val_loss: 0.1598 - val_auc_3: 0.9847
# Epoch 45/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0837 - auc_3: 0.9954 - val_loss: 0.1673 - val_auc_3: 0.9828
# Epoch 46/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0832 - auc_3: 0.9952 - val_loss: 0.1337 - val_auc_3: 0.9871
# Epoch 47/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0746 - auc_3: 0.9960 - val_loss: 0.1437 - val_auc_3: 0.9865
# Epoch 48/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0872 - auc_3: 0.9951 - val_loss: 0.1483 - val_auc_3: 0.9850
# Epoch 49/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0893 - auc_3: 0.9948 - val_loss: 0.1389 - val_auc_3: 0.9868
# Epoch 50/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0833 - auc_3: 0.9954 - val_loss: 0.1493 - val_auc_3: 0.9865
# Epoch 51/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0842 - auc_3: 0.9953 - val_loss: 0.1317 - val_auc_3: 0.9894
# Epoch 52/128
# 183/183 [==============================] - 2s 14ms/step - loss: 0.0760 - auc_3: 0.9959 - val_loss: 0.1339 - val_auc_3: 0.9882
# Epoch 53/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0796 - auc_3: 0.9957 - val_loss: 0.1506 - val_auc_3: 0.9846
# Epoch 54/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0823 - auc_3: 0.9952 - val_loss: 0.1714 - val_auc_3: 0.9832
# Epoch 55/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0853 - auc_3: 0.9946 - val_loss: 0.1357 - val_auc_3: 0.9883
# Epoch 56/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0694 - auc_3: 0.9968 - val_loss: 0.1621 - val_auc_3: 0.9845
# Epoch 57/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0885 - auc_3: 0.9950 - val_loss: 0.1479 - val_auc_3: 0.9868
# Epoch 58/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0751 - auc_3: 0.9964 - val_loss: 0.1367 - val_auc_3: 0.9886
# Epoch 59/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0744 - auc_3: 0.9962 - val_loss: 0.1448 - val_auc_3: 0.9861
# Epoch 60/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0834 - auc_3: 0.9954 - val_loss: 0.1454 - val_auc_3: 0.9862
# Epoch 61/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0741 - auc_3: 0.9959 - val_loss: 0.1658 - val_auc_3: 0.9821
# Epoch 62/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0797 - auc_3: 0.9959 - val_loss: 0.1713 - val_auc_3: 0.9824
# Epoch 63/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0808 - auc_3: 0.9957 - val_loss: 0.1421 - val_auc_3: 0.9870
# Epoch 64/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0838 - auc_3: 0.9951 - val_loss: 0.1563 - val_auc_3: 0.9865
# Epoch 65/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0727 - auc_3: 0.9965 - val_loss: 0.1566 - val_auc_3: 0.9868
# Epoch 66/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0867 - auc_3: 0.9950 - val_loss: 0.1512 - val_auc_3: 0.9860
# Epoch 67/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0811 - auc_3: 0.9955 - val_loss: 0.1889 - val_auc_3: 0.9810
# Epoch 68/128
# 183/183 [==============================] - 3s 18ms/step - loss: 0.0736 - auc_3: 0.9965 - val_loss: 0.1583 - val_auc_3: 0.9843
# Epoch 69/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0749 - auc_3: 0.9962 - val_loss: 0.1647 - val_auc_3: 0.9852
# Epoch 70/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0790 - auc_3: 0.9956 - val_loss: 0.1561 - val_auc_3: 0.9840
# Epoch 71/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0813 - auc_3: 0.9957 - val_loss: 0.1717 - val_auc_3: 0.9833
# Epoch 72/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0785 - auc_3: 0.9955 - val_loss: 0.1529 - val_auc_3: 0.9864
# Epoch 73/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0792 - auc_3: 0.9960 - val_loss: 0.1660 - val_auc_3: 0.9832
# Epoch 74/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0724 - auc_3: 0.9965 - val_loss: 0.1729 - val_auc_3: 0.9841
# Epoch 75/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0763 - auc_3: 0.9958 - val_loss: 0.1741 - val_auc_3: 0.9817
# Epoch 76/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0712 - auc_3: 0.9967 - val_loss: 0.1596 - val_auc_3: 0.9836
# Epoch 77/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0791 - auc_3: 0.9958 - val_loss: 0.1950 - val_auc_3: 0.9782
# Epoch 78/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0785 - auc_3: 0.9957 - val_loss: 0.1628 - val_auc_3: 0.9841
# Epoch 79/128
# 183/183 [==============================] - 4s 23ms/step - loss: 0.0795 - auc_3: 0.9956 - val_loss: 0.1451 - val_auc_3: 0.9861
# Epoch 80/128
# 183/183 [==============================] - 4s 19ms/step - loss: 0.0759 - auc_3: 0.9962 - val_loss: 0.1917 - val_auc_3: 0.9825
# Epoch 81/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0796 - auc_3: 0.9959 - val_loss: 0.1817 - val_auc_3: 0.9814
# Epoch 82/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0805 - auc_3: 0.9956 - val_loss: 0.1726 - val_auc_3: 0.9818
# Epoch 83/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0871 - auc_3: 0.9949 - val_loss: 0.1592 - val_auc_3: 0.9843
# Epoch 84/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0672 - auc_3: 0.9972 - val_loss: 0.1555 - val_auc_3: 0.9852
# Epoch 85/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0875 - auc_3: 0.9952 - val_loss: 0.1626 - val_auc_3: 0.9839
# Epoch 86/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0758 - auc_3: 0.9960 - val_loss: 0.1733 - val_auc_3: 0.9831
# Epoch 87/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0672 - auc_3: 0.9966 - val_loss: 0.1748 - val_auc_3: 0.9839
# Epoch 88/128
# ...
# Epoch 18/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0667 - auc_5: 0.9967 - val_loss: 0.0928 - val_auc_5: 0.9941
# Epoch 19/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0686 - auc_5: 0.9964 - val_loss: 0.0860 - val_auc_5: 0.9947
# Epoch 20/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0701 - auc_5: 0.9967 - val_loss: 0.0857 - val_auc_5: 0.9953
# Epoch 21/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0641 - auc_5: 0.9974 - val_loss: 0.0801 - val_auc_5: 0.9949
# Epoch 22/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0606 - auc_5: 0.9975 - val_loss: 0.0803 - val_auc_5: 0.9954
# Epoch 23/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0667 - auc_5: 0.9969 - val_loss: 0.0870 - val_auc_5: 0.9936
# Epoch 24/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0677 - auc_5: 0.9966 - val_loss: 0.1123 - val_auc_5: 0.9898
# Epoch 25/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0815 - auc_5: 0.9954 - val_loss: 0.0769 - val_auc_5: 0.9959
# Epoch 26/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0601 - auc_5: 0.9976 - val_loss: 0.0935 - val_auc_5: 0.9936
# Epoch 27/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0737 - auc_5: 0.9967 - val_loss: 0.1004 - val_auc_5: 0.9929
# Epoch 28/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0631 - auc_5: 0.9972 - val_loss: 0.0873 - val_auc_5: 0.9954
# Epoch 29/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0663 - auc_5: 0.9970 - val_loss: 0.0822 - val_auc_5: 0.9955
# Epoch 30/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0573 - auc_5: 0.9977 - val_loss: 0.1189 - val_auc_5: 0.9896
# Epoch 31/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0646 - auc_5: 0.9970 - val_loss: 0.1106 - val_auc_5: 0.9902
# Epoch 32/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0596 - auc_5: 0.9973 - val_loss: 0.1036 - val_auc_5: 0.9929
# Epoch 33/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0663 - auc_5: 0.9969 - val_loss: 0.1131 - val_auc_5: 0.9917
# Epoch 34/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0603 - auc_5: 0.9971 - val_loss: 0.1162 - val_auc_5: 0.9899
# Epoch 35/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0594 - auc_5: 0.9973 - val_loss: 0.1056 - val_auc_5: 0.9922
# Epoch 36/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0605 - auc_5: 0.9975 - val_loss: 0.1171 - val_auc_5: 0.9896
# Epoch 37/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0665 - auc_5: 0.9967 - val_loss: 0.0948 - val_auc_5: 0.9940
# Epoch 38/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0570 - auc_5: 0.9978 - val_loss: 0.1512 - val_auc_5: 0.9875
# Epoch 39/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0689 - auc_5: 0.9969 - val_loss: 0.0974 - val_auc_5: 0.9931
# Epoch 40/128
# 183/183 [==============================] - 2s 14ms/step - loss: 0.0657 - auc_5: 0.9974 - val_loss: 0.1228 - val_auc_5: 0.9903
# Epoch 41/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0655 - auc_5: 0.9970 - val_loss: 0.1238 - val_auc_5: 0.9914
# Epoch 42/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0611 - auc_5: 0.9975 - val_loss: 0.1268 - val_auc_5: 0.9883
# Epoch 43/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0614 - auc_5: 0.9972 - val_loss: 0.1315 - val_auc_5: 0.9884
# Epoch 44/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0570 - auc_5: 0.9981 - val_loss: 0.1670 - val_auc_5: 0.9856
# Epoch 45/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0671 - auc_5: 0.9970 - val_loss: 0.1211 - val_auc_5: 0.9911
# Epoch 46/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0650 - auc_5: 0.9969 - val_loss: 0.1187 - val_auc_5: 0.9888
# Epoch 47/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0590 - auc_5: 0.9975 - val_loss: 0.1253 - val_auc_5: 0.9904
# Epoch 48/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0665 - auc_5: 0.9971 - val_loss: 0.1161 - val_auc_5: 0.9906
# Epoch 49/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0566 - auc_5: 0.9979 - val_loss: 0.1325 - val_auc_5: 0.9886
# Epoch 50/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0668 - auc_5: 0.9967 - val_loss: 0.1432 - val_auc_5: 0.9874
# Epoch 51/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0582 - auc_5: 0.9976 - val_loss: 0.1458 - val_auc_5: 0.9874
# Epoch 52/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0557 - auc_5: 0.9977 - val_loss: 0.1503 - val_auc_5: 0.9867
# Epoch 53/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0640 - auc_5: 0.9970 - val_loss: 0.1443 - val_auc_5: 0.9858
# Epoch 54/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0710 - auc_5: 0.9967 - val_loss: 0.1542 - val_auc_5: 0.9861
# Epoch 55/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0594 - auc_5: 0.9977 - val_loss: 0.2257 - val_auc_5: 0.9761
# Epoch 56/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0636 - auc_5: 0.9969 - val_loss: 0.1515 - val_auc_5: 0.9846
# Epoch 57/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0598 - auc_5: 0.9974 - val_loss: 0.1786 - val_auc_5: 0.9838
# Epoch 58/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0618 - auc_5: 0.9972 - val_loss: 0.1714 - val_auc_5: 0.9848
# Epoch 59/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0586 - auc_5: 0.9978 - val_loss: 0.1491 - val_auc_5: 0.9873
# Epoch 60/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0562 - auc_5: 0.9981 - val_loss: 0.1603 - val_auc_5: 0.9852
# Epoch 61/128
# 183/183 [==============================] - 3s 18ms/step - loss: 0.0488 - auc_5: 0.9984 - val_loss: 0.1431 - val_auc_5: 0.9896
# Epoch 62/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0626 - auc_5: 0.9971 - val_loss: 0.1477 - val_auc_5: 0.9870
# Epoch 63/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0578 - auc_5: 0.9975 - val_loss: 0.1575 - val_auc_5: 0.9849
# Epoch 64/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0550 - auc_5: 0.9975 - val_loss: 0.1517 - val_auc_5: 0.9871
# Epoch 65/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0502 - auc_5: 0.9983 - val_loss: 0.1538 - val_auc_5: 0.9848
# Epoch 66/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0567 - auc_5: 0.9977 - val_loss: 0.1548 - val_auc_5: 0.9845
# Epoch 67/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0581 - auc_5: 0.9977 - val_loss: 0.1533 - val_auc_5: 0.9861
# Epoch 68/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0644 - auc_5: 0.9967 - val_loss: 0.1387 - val_auc_5: 0.9876
# Epoch 69/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0541 - auc_5: 0.9975 - val_loss: 0.1613 - val_auc_5: 0.9842
# Epoch 70/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0637 - auc_5: 0.9973 - val_loss: 0.1362 - val_auc_5: 0.9884
# Epoch 71/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0573 - auc_5: 0.9979 - val_loss: 0.1296 - val_auc_5: 0.9892
# Epoch 72/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0495 - auc_5: 0.9985 - val_loss: 0.1681 - val_auc_5: 0.9842
# Epoch 73/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0492 - auc_5: 0.9984 - val_loss: 0.1543 - val_auc_5: 0.9868
# Epoch 74/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0583 - auc_5: 0.9976 - val_loss: 0.1590 - val_auc_5: 0.9843
# Epoch 75/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0703 - auc_5: 0.9968 - val_loss: 0.1621 - val_auc_5: 0.9833
# Epoch 76/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0579 - auc_5: 0.9976 - val_loss: 0.1913 - val_auc_5: 0.9792
# Epoch 77/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0602 - auc_5: 0.9972 - val_loss: 0.1870 - val_auc_5: 0.9817
# Epoch 78/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0562 - auc_5: 0.9978 - val_loss: 0.1863 - val_auc_5: 0.9797
# Epoch 79/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0664 - auc_5: 0.9968 - val_loss: 0.1455 - val_auc_5: 0.9870
# Epoch 80/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0501 - auc_5: 0.9983 - val_loss: 0.2258 - val_auc_5: 0.9749
# Epoch 81/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0545 - auc_5: 0.9978 - val_loss: 0.1899 - val_auc_5: 0.9804
# Epoch 82/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0536 - auc_5: 0.9980 - val_loss: 0.1868 - val_auc_5: 0.9835
# Epoch 83/128
# 183/183 [==============================] - 3s 18ms/step - loss: 0.0632 - auc_5: 0.9969 - val_loss: 0.1596 - val_auc_5: 0.9837
# Epoch 84/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0472 - auc_5: 0.9986 - val_loss: 0.1727 - val_auc_5: 0.9828
# Epoch 85/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0613 - auc_5: 0.9971 - val_loss: 0.1612 - val_auc_5: 0.9817
# Epoch 86/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0657 - auc_5: 0.9973 - val_loss: 0.1883 - val_auc_5: 0.9800
# Epoch 87/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0606 - auc_5: 0.9976 - val_loss: 0.2132 - val_auc_5: 0.9778
# Epoch 88/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0489 - auc_5: 0.9985 - val_loss: 0.1796 - val_auc_5: 0.9826
# Epoch 89/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0471 - auc_5: 0.9981 - val_loss: 0.1784 - val_auc_5: 0.9819
# Epoch 90/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0528 - auc_5: 0.9982 - val_loss: 0.1829 - val_auc_5: 0.9831
# Epoch 91/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0593 - auc_5: 0.9977 - val_loss: 0.1746 - val_auc_5: 0.9821
# Epoch 92/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0634 - auc_5: 0.9970 - val_loss: 0.1819 - val_auc_5: 0.9838
# Epoch 93/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0554 - auc_5: 0.9979 - val_loss: 0.2479 - val_auc_5: 0.9737
# Epoch 94/128
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0682 - auc_5: 0.9959 - val_loss: 0.1955 - val_auc_5: 0.9799
# Epoch 95/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0606 - auc_5: 0.9972 - val_loss: 0.1744 - val_auc_5: 0.9831
# Epoch 96/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0419 - auc_5: 0.9988 - val_loss: 0.2361 - val_auc_5: 0.9744
# Epoch 97/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0616 - auc_5: 0.9970 - val_loss: 0.1856 - val_auc_5: 0.9837
# Epoch 98/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0598 - auc_5: 0.9977 - val_loss: 0.1896 - val_auc_5: 0.9798
# Epoch 99/128
# 183/183 [==============================] - 3s 18ms/step - loss: 0.0468 - auc_5: 0.9979 - val_loss: 0.1945 - val_auc_5: 0.9789
# Epoch 100/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0542 - auc_5: 0.9976 - val_loss: 0.1923 - val_auc_5: 0.9800
# Epoch 101/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0642 - auc_5: 0.9969 - val_loss: 0.1935 - val_auc_5: 0.9796
# Epoch 102/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0486 - auc_5: 0.9983 - val_loss: 0.1819 - val_auc_5: 0.9823
# Epoch 103/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0443 - auc_5: 0.9987 - val_loss: 0.2682 - val_auc_5: 0.9719
# Epoch 104/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0580 - auc_5: 0.9976 - val_loss: 0.1946 - val_auc_5: 0.9801
# Epoch 105/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0592 - auc_5: 0.9970 - val_loss: 0.2383 - val_auc_5: 0.9723
# Epoch 106/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0610 - auc_5: 0.9972 - val_loss: 0.1826 - val_auc_5: 0.9809
# Epoch 107/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0478 - auc_5: 0.9984 - val_loss: 0.2223 - val_auc_5: 0.9770
# Epoch 108/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0649 - auc_5: 0.9968 - val_loss: 0.2128 - val_auc_5: 0.9779
# Epoch 109/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0509 - auc_5: 0.9979 - val_loss: 0.2080 - val_auc_5: 0.9767
# Epoch 110/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0541 - auc_5: 0.9981 - val_loss: 0.2026 - val_auc_5: 0.9780
# Epoch 111/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0542 - auc_5: 0.9976 - val_loss: 0.1958 - val_auc_5: 0.9798
# Epoch 112/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0541 - auc_5: 0.9978 - val_loss: 0.2561 - val_auc_5: 0.9716
# Epoch 113/128
# 183/183 [==============================] - 2s 12ms/step - loss: 0.0456 - auc_5: 0.9985 - val_loss: 0.2414 - val_auc_5: 0.9749
# Epoch 114/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0558 - auc_5: 0.9978 - val_loss: 0.2193 - val_auc_5: 0.9759
# Epoch 115/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0688 - auc_5: 0.9961 - val_loss: 0.1978 - val_auc_5: 0.9791
# Epoch 116/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0530 - auc_5: 0.9982 - val_loss: 0.2186 - val_auc_5: 0.9769
# Epoch 117/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0557 - auc_5: 0.9976 - val_loss: 0.1961 - val_auc_5: 0.9789
# Epoch 118/128
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0442 - auc_5: 0.9988 - val_loss: 0.2148 - val_auc_5: 0.9766
# Epoch 119/128
# 183/183 [==============================] - 6s 34ms/step - loss: 0.0570 - auc_5: 0.9978 - val_loss: 0.1852 - val_auc_5: 0.9792
# Epoch 120/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0492 - auc_5: 0.9980 - val_loss: 0.1924 - val_auc_5: 0.9789
# Epoch 121/128
# 183/183 [==============================] - 3s 15ms/step - loss: 0.0464 - auc_5: 0.9981 - val_loss: 0.2167 - val_auc_5: 0.9754
# Epoch 122/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0620 - auc_5: 0.9963 - val_loss: 0.2341 - val_auc_5: 0.9760
# Epoch 123/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0601 - auc_5: 0.9976 - val_loss: 0.2158 - val_auc_5: 0.9774
# Epoch 124/128
# 183/183 [==============================] - 3s 17ms/step - loss: 0.0505 - auc_5: 0.9982 - val_loss: 0.2039 - val_auc_5: 0.9790
# Epoch 125/128
# 183/183 [==============================] - 3s 14ms/step - loss: 0.0409 - auc_5: 0.9990 - val_loss: 0.2291 - val_auc_5: 0.9753
# Epoch 126/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0656 - auc_5: 0.9970 - val_loss: 0.2132 - val_auc_5: 0.9772
# Epoch 127/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0566 - auc_5: 0.9978 - val_loss: 0.2091 - val_auc_5: 0.9773
# Epoch 128/128
# 183/183 [==============================] - 2s 13ms/step - loss: 0.0478 - auc_5: 0.9983 - val_loss: 0.2151 - val_auc_5: 0.9784
# 46/46 [==============================] - 1s 7ms/step
#
# Average Classification Report Across Folds:
# {}
# <ipython-input-9-e501c00cf810>:52: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_report = pd.DataFrame(all_reports).mean().to_dict()

# %% [markdown]
# # Save results

# %%
extractorEmb = Model(inputs=model.inputs,outputs=model.get_layer(name="clsTokenEmb").output)

preds = model.predict(x3,batch_size = config.BATCH_SIZE)

dbresults={}
dbresults['pred_emb'] = extractorEmb.predict(x3,batch_size = config.BATCH_SIZE)
dbresults['pred_cls'] = preds
dbresults['y_cls'] = labels
dbresults['formula'] = df['formula']
dbresults['ids'] = df['ids']
dbresults['types'] = types
dbresults['trainidx'] = trainidx
dbresults['testidx'] = validx
dbresults['validx'] = validx

with open(mname+'_results.pkl', 'wb') as f:
    pickle.dump(dbresults, f)
# Out:
# 229/229 [==============================] - 2s 7ms/step
# 229/229 [==============================] - 2s 6ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(trainlog.history['loss'])
plt.plot(trainlog.history['val_loss'])

# %% [markdown]
# # Postprocessing

# %%
from matplotlib import cm
from sklearn.manifold import TSNE
from sklearn import metrics
import seaborn as sns
tsne = TSNE(n_components=2, verbose=0, random_state=123)
z = tsne.fit_transform(dbresults['pred_emb'])

# %%
dfr = pd.DataFrame()
dfr["y"] = np.asarray(dbresults['y_cls'].argmax(axis=-1)).astype('bool')
dfr["yp"] = np.asarray(dbresults['pred_cls'].argmax(axis=-1)).astype('bool')
dfr["tSNE1"] = z[:,0]
dfr["tSNE2"] = z[:,1]

# %%
plt.rcParams.update({'font.size': 16})
fig, axes = plt.subplots(1, 3, figsize=(15, 4.8))
y_pclasses = dbresults['pred_cls'][dbresults['testidx']].argmax(axis=-1).tolist()
y_classes = dbresults['y_cls'][dbresults['testidx']].argmax(axis=-1)
m = tf.keras.metrics.AUC()
m.update_state(dbresults['y_cls'][dbresults['testidx']], dbresults['pred_cls'][dbresults['testidx']])
print(mname,'binary tf-acc:',tf.keras.metrics.binary_accuracy(y_classes, y_pclasses, threshold=0.5).numpy(),'AUC:',m.result().numpy())
confusion_matrix = metrics.confusion_matrix(y_classes, y_pclasses)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix,
                                            display_labels=['False','True'])
cm_display.plot(ax=axes[0],cmap=plt.cm.Blues)

sns.scatterplot(ax=axes[1],x="tSNE1", y="tSNE2", hue=dfr.y.tolist(),data=dfr)#.set(title=title+" data T-SNE projection")
axes[1].set_xlabel('$tSNE_1$')
axes[1].set_ylabel('$tSNE_2$',labelpad=1)
axes[1].set_title('Reference')
sns.scatterplot(ax=axes[2],x="tSNE1", y="tSNE2", hue=dfr.yp.tolist(),data=dfr)#.set(title=title+" data T-SNE projection")
axes[2].set_title('Predicted')
axes[2].set_xlabel('$tSNE_1$')
axes[2].set_ylabel('$tSNE_2$',labelpad=1)
axes[2].legend('',frameon=False)
fig.tight_layout()
plt.savefig(mname+'_tsne.png',format='png',dpi=800,bbox_inches = "tight")
plt.show()
# Out:
# /content/elementsem/models/elembert_toxic_sr-mmp_V1_E_32_H_2_L_2 binary tf-acc: 0.98497266 AUC: 0.9964018

# %% [markdown]
# /content/elementsem/models/elembert_toxic_sr-p53_V0_E_32_H_2_L_2 binary tf-acc: 0.96871376 AUC: 0.98945105
# /content/elementsem/models/elembert_toxic_sr-p53_V1_E_32_H_2_L_2 binary tf-acc: 0.9571263  AUC: 0.9820951
# /content/elementsem/models/elembert_toxic_sr-mmp_V0_E_32_H_2_L_2 binary tf-acc: 0.8920765 AUC: 0.9487883
# /content/elementsem/models/elembert_toxic_sr-mmp_V1_E_32_H_2_L_2 binary tf-acc: 0.90163934 AUC: 0.94474494
# /content/elementsem/models/elembert_toxic_sr-hse_V0_E_32_H_2_L_2 binary tf-acc: 0.94969326 AUC: 0.95752335
# /content/elementsem/models/elembert_toxic_sr-hse_V1_E_32_H_2_L_2 binary tf-acc: 0.9190184 AUC: 0.9508389
# /content/elementsem/models/elembert_toxic_sr-atad5_V0_E_32_H_2_L_2 binary tf-acc: 0.9570957 AUC: 0.9825725
# /content/elementsem/models/elembert_toxic_sr-atad5_V1_E_32_H_2_L_2 binary tf-acc: 0.9537954 AUC: 0.9790919
# /content/elementsem/models/elembert_toxic_sr-are_V0_E_32_H_2_L_2 binary tf-acc: 0.8563459 AUC: 0.90734774
# /content/elementsem/models/elembert_toxic_sr-are_V1_E_32_H_2_L_2 binary tf-acc: 0.83682007 AUC: 0.9020403
# /content/elementsem/models/elembert_toxic_nr-ppar-gamma_V0_E_32_H_2_L_2 binary tf-acc: 0.9767726 AUC: 0.9827267
# /content/elementsem/models/elembert_toxic_nr-ppar-gamma_V1_E_32_H_2_L_2 binary tf-acc: 0.97310513 AUC: 0.98619694
# /content/elementsem/models/elembert_toxic_nr-er_V0_E_32_H_2_L_2 binary tf-acc: 0.9103896 AUC: 0.92926294
# /content/elementsem/models/elembert_toxic_nr-er_V1_E_32_H_2_L_2 binary tf-acc: 0.8922078 AUC: 0.9366631
# /content/elementsem/models/elembert_toxic_nr-er-lbd_V0_E_32_H_2_L_2 binary tf-acc: 0.9565714 AUC: 0.97466516
# /content/elementsem/models/elembert_toxic_nr-er-lbd_V1_E_32_H_2_L_2 binary tf-acc: 0.9497143 AUC: 0.97794485
# /content/elementsem/models/elembert_toxic_nr-ar_V0_E_32_H_2_L_2 binary tf-acc: 0.9604701 AUC: 0.9732301
# /content/elementsem/models/elembert_toxic_nr-ar_V1_E_32_H_2_L_2 binary tf-acc: 0.9583333 AUC: 0.96689063
# /content/elementsem/models/elembert_toxic_nr-aromatase_V0_E_32_H_2_L_2 binary tf-acc: 0.9626556 AUC: 0.9822728
# /content/elementsem/models/elembert_toxic_nr-aromatase_V1_E_32_H_2_L_2 binary tf-acc: 0.9585062 AUC: 0.9869759
#
# /content/elementsem/models/elembert_toxic_nr-aromatase_V1_E_32_H_2_L_2 binary tf-acc: 0.9515906 AUC: 0.9795726
